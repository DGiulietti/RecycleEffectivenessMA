# %% [markdown]
# # Recycling Effectiveness in MA
#
# ### *Part 3: Baseline Regressions for Recycling Rate in Total Population Based on Service Attributes of Each Municipality*

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.graph_objs import *

# %% [markdown]
# ## Importing and Inspection of Data

# %%
# Import the 2019 municipal survey results into a df
# usecols is just trimming off additional columns that had to do with special/hazardous recyclables

serv19 = pd.read_csv('data/MA_MSW_Collection_Data/serv19cleaned.csv', index_col='Municipality Name')
serv19.head()
# Out:
#                        Contact Name  Total Number of Households  \
# Municipality Name
# Abington           Angela Dahlstrom                      6558.0
# Acton                    Corey York                      9800.0
# Acushnet                 Dan Menard                      4304.0
# Adams                  Linda Cernik                      3867.0
# Agawam                 Tracy DeMaio                     12031.0
#
#                    Households Served by Municipal Trash Program  \
# Municipality Name
# Abington                                                 4486.0
# Acton                                                    3846.0
# Acushnet                                                 3591.0
# Adams                                                     664.0
# Agawam                                                   8879.0
#
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Abington                                                     4486.0
# Acton                                                        4335.0
# Acushnet                                                     3591.0
# Adams                                                         664.0
# Agawam                                                       8879.0
#
#                   Trash Service Type Carts for Trash  Trash Cart size  \
# Municipality Name
# Abington                    Curbside             Yes             64.0
# Acton                       Drop-off             NaN              NaN
# Acushnet                    Curbside             Yes             65.0
# Adams                       Drop-off             NaN              NaN
# Agawam                      Curbside             Yes             65.0
#
#                   Recycling Service Type Recycling Collection Frequency  \
# Municipality Name
# Abington                        Curbside                         Weekly
# Acton                           Drop-off                            NaN
# Acushnet                            Both                      Bi-weekly
# Adams                           Drop-off                            NaN
# Agawam                          Curbside                      Bi-weekly
#
#                   SS Recycling  ...  \
# Municipality Name               ...
# Abington                   Yes  ...
# Acton                      NaN  ...
# Acushnet                   Yes  ...
# Adams                      NaN  ...
# Agawam                     Yes  ...
#
#                   Does trash disposal tonnage include bulky waste?  \
# Municipality Name
# Abington                                                       Yes
# Acton                                                          Yes
# Acushnet                                                        No
# Adams                                                           No
# Agawam                                                          No
#
#                    Bulky waste tonnage Fee for bulky waste?  \
# Municipality Name
# Abington                           NaN                  Yes
# Acton                              NaN                  Yes
# Acushnet                         41.00                  Yes
# Adams                             4.43                  Yes
# Agawam                          275.17                  Yes
#
#                   Annual Bulky \nWaste \nLimit Tip Fee as of 1/1/2020  \
# Municipality Name
# Abington                                   NaN                  86.50
# Acton                                      NaN                  57.16
# Acushnet                                   NaN                  64.60
# Adams                                      NaN                 110.00
# Agawam                                    30.0                  74.00
#
#                   Tons Single Stream Recyclables Newspaper Cardboard  \
# Municipality Name
# Abington                                 1413.42       NaN       NaN
# Acton                                        NaN       NaN       NaN
# Acushnet                                  879.50       3.7      20.0
# Adams                                        NaN       NaN       NaN
# Agawam                                   2238.00       NaN       NaN
#
#                   Mixed Paper Commingled
# Municipality Name
# Abington                  NaN        NaN
# Acton                  683.04     407.27
# Acushnet                16.94      27.40
# Adams                   94.13      45.48
# Agawam                    NaN        NaN
#
# [5 rows x 54 columns]

# %%
serv19.columns
# Out:
# Index(['Contact Name', 'Total Number of Households',
#        'Households Served by Municipal Trash Program',
#        'Households Served by Municipal Recycling Program',
#        'Trash Service Type', 'Carts for Trash', 'Trash Cart size',
#        'Recycling Service Type', 'Recycling Collection Frequency',
#        'SS Recycling', 'Carts for Recycling', 'Recycling Cart Size',
#        'Municipal Buildings Trash and Recycling Service',
#        'School Trash and Recycling Service',
#        'Business Trash and Recycling Service',
#        'Non-resident Trash and Recycling Service',
#        'Solid Waste program funded by property tax?',
#        'Solid Waste program funded by annual fee?',
#        'Solid Waste program funded by transfer station access fee?',
#        'Solid Waste program funded by per-visit fee?',
#        'Solid Waste program funded by PAYT/ SMART revenue?',
#        'What is the annual fee?', 'What is the transfer station access fee?',
#        'What is the per-visit fee?', 'PAYT/ SMART',
#        'Enforced Trash Limits at Curb', 'Maximum # bags/ barrels per week',
#        'Barrel size in gallons (eg 32 64 etc)', 'Trash Enforced by Muni',
#        'Trash Enforced by Hauler', 'Dedicated Trash Enforcement Personnel',
#        'Enforced Mandatory Recycling',
#        'Applies to Residential Generators Eligible to be Served by Municipal Program',
#        'Applies to Residential Generators not Eligible to be Served by the Municipal Program',
#        'Applies to Commercial Generators', 'Recycling Enforced by Muni',
#        'Recycling Enforced by Hauler',
#        'Dedicated Mandatory Recycling Enforcement Personnel',
#        '# Hours Enforcement Personnel on Street',
#        'Private Hauler regulations that require recycling',
#        'Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
#        'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program',
#        'Applies to Commercial Generators.1', 'Trash Disposal Tonnage',
#        'Does trash disposal tonnage include bulky waste?',
#        'Bulky waste tonnage', 'Fee for bulky waste?',
#        'Annual Bulky \nWaste \nLimit', 'Tip Fee as of 1/1/2020',
#        'Tons Single Stream Recyclables', 'Newspaper', 'Cardboard',
#        'Mixed Paper', 'Commingled'],
#       dtype='object')

# %%
serv19 = serv19.drop(columns=['Contact Name', 'Total Number of Households',
       'Households Served by Municipal Trash Program',
       'Households Served by Municipal Recycling Program'])

# %%
cols_to_use = ['Solid Waste program funded by property tax?',
       'Solid Waste program funded by annual fee?',
       'Solid Waste program funded by transfer station access fee?',
       'Solid Waste program funded by per-visit fee?',
       'Solid Waste program funded by PAYT/ SMART revenue?',
       'What is the annual fee?', 'What is the transfer station access fee?',
       'What is the per-visit fee?', 'PAYT/ SMART',
       'Municipal Buildings Trash and Recycling Service',
       'School Trash and Recycling Service',
       'Business Trash and Recycling Service',
       'Non-resident Trash and Recycling Service', 'Households Served by Municipal Trash Program', 'Trash Service Type', 'Carts for Trash', 'Trash Cart size', 'Does trash disposal tonnage include bulky waste?','Fee for bulky waste?',
       'Annual Bulky \nWaste \nLimit', 'Tip Fee as of 1/1/2020', 'Enforced Trash Limits at Curb', 'Maximum # bags/ barrels per week',
       'Barrel size in gallons (eg 32 64 etc)', 'Trash Enforced by Muni',
       'Trash Enforced by Hauler', 'Dedicated Trash Enforcement Personnel','Households Served by Municipal Recycling Program', 'Recycling Service Type', 'Recycling Collection Frequency',
       'SS Recycling', 'Carts for Recycling', 'Recycling Cart Size', 'Enforced Mandatory Recycling',
       'Applies to Residential Generators Eligible to be Served by Municipal Program',
       'Applies to Residential Generators not Eligible to be Served by the Municipal Program',
       'Applies to Commercial Generators', 'Recycling Enforced by Muni',
       'Recycling Enforced by Hauler',
       'Dedicated Mandatory Recycling Enforcement Personnel',
       '# Hours Enforcement Personnel on Street', 'Private Hauler regulations that require recycling',
       'Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
       'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program',
       'Applies to Commercial Generators.1'
              ]

# %%
# general information related to funding for service.

serv_fund = ['Solid Waste program funded by property tax?',
       'Solid Waste program funded by annual fee?',
       'Solid Waste program funded by transfer station access fee?',
       'Solid Waste program funded by per-visit fee?',
       'Solid Waste program funded by PAYT/ SMART revenue?',
       'What is the annual fee?', 'What is the transfer station access fee?',
       'What is the per-visit fee?', 'PAYT/ SMART',]

# %%
# general service information for non-residental buildings

gen_serv = ['Municipal Buildings Trash and Recycling Service',
       'School Trash and Recycling Service',
       'Business Trash and Recycling Service',
       'Non-resident Trash and Recycling Service', ]

# %%
# quantities and specifications related to trash services

trash_serv = ['Households Served by Municipal Trash Program', 'Trash Service Type', 'Carts for Trash', 'Trash Cart size', 'Does trash disposal tonnage include bulky waste?','Fee for bulky waste?',
       'Annual Bulky \nWaste \nLimit', 'Tip Fee as of 1/1/2020', 'Enforced Trash Limits at Curb', 'Maximum # bags/ barrels per week',
       'Barrel size in gallons (eg 32 64 etc)', 'Trash Enforced by Muni',
       'Trash Enforced by Hauler', 'Dedicated Trash Enforcement Personnel', ]

# %%
# quantitative data on trash tonnages collected

trash_tonnage_data = ['Households Served by Municipal Trash Program', 'Trash Disposal Tonnage', 'Bulky waste tonnage', ]

# %%
# quantities and specifications related to recycle services

recycle_serv= ['Households Served by Municipal Recycling Program', 'Recycling Service Type', 'Recycling Collection Frequency',
       'SS Recycling', 'Carts for Recycling', 'Recycling Cart Size', 'Enforced Mandatory Recycling',
       'Applies to Residential Generators Eligible to be Served by Municipal Program',
       'Applies to Residential Generators not Eligible to be Served by the Municipal Program',
       'Applies to Commercial Generators', 'Recycling Enforced by Muni',
       'Recycling Enforced by Hauler',
       'Dedicated Mandatory Recycling Enforcement Personnel',
       '# Hours Enforcement Personnel on Street', 'Private Hauler regulations that require recycling',
       'Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
       'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program',
       'Applies to Commercial Generators.1']

# %%
# Import summary data for municipal waste tonnages in 2019

tonnages19 = pd.read_csv('data/MA_MSW_Collection_Data/musum19.csv', index_col='Municipality Name')
tonnages19.head()
# Out:
#                    tot_households stream_type  tons_ss_recyclables  \
# Municipality Name
# Abington                   6558.0          ss              1413.42
# Acton                      9800.0          ms                 0.00
# Acushnet                   4304.0         ss+               879.50
# Adams                      3867.0          ms                 0.00
# Agawam                    12031.0          ss              2238.00
#
#                    tons_ms_recyclables  tons_recyclables_total  \
# Municipality Name
# Abington                          0.00                 1413.42
# Acton                          1090.31                 1090.31
# Acushnet                         68.04                  947.54
# Adams                           139.61                  139.61
# Agawam                            0.00                 2238.00
#
#                    hh_served_by_mu_recycle  tons_recyclables/hh  \
# Municipality Name
# Abington                            4486.0             0.315074
# Acton                               4335.0             0.251513
# Acushnet                            3591.0             0.263865
# Adams                                664.0             0.210256
# Agawam                              8879.0             0.252055
#
#                    hh_served_by_mu_trash  tons_trash_total  tons_trash/hh  \
# Municipality Name
# Abington                          4486.0           3826.66       0.853023
# Acton                             3846.0           2148.67       0.558677
# Acushnet                          3591.0           3446.38       0.959727
# Adams                              664.0            134.47       0.202515
# Agawam                            8879.0           6717.17       0.756523
#
#                    %recycle/hh  total_waste/hh
# Municipality Name
# Abington              0.269733        1.168096
# Acton                 0.310437        0.810190
# Acushnet              0.215648        1.223592
# Adams                 0.509377        0.412771
# Agawam                0.249912        1.008579

# %% [markdown]
# ## Setting up data for regression

# %%
df_for_regression = serv19.loc[:,cols_to_use].merge(tonnages19.loc[:,['%recycle/hh','total_waste/hh']], left_index=True, right_index=True)
df_for_regression.head(2)
# Out:
#                   Solid Waste program funded by property tax?  \
# Municipality Name
# Abington                                                  Yes
# Acton                                                     NaN
#
#                   Solid Waste program funded by annual fee?  \
# Municipality Name
# Abington                                                NaN
# Acton                                                   NaN
#
#                   Solid Waste program funded by transfer station access fee?  \
# Municipality Name
# Abington                                                         NaN
# Acton                                                            Yes
#
#                   Solid Waste program funded by per-visit fee?  \
# Municipality Name
# Abington                                                   NaN
# Acton                                                      Yes
#
#                   Solid Waste program funded by PAYT/ SMART revenue?  \
# Municipality Name
# Abington                                                         NaN
# Acton                                                            Yes
#
#                    What is the annual fee?  \
# Municipality Name
# Abington                               NaN
# Acton                                  NaN
#
#                    What is the transfer station access fee?  \
# Municipality Name
# Abington                                                NaN
# Acton                                                 100.0
#
#                    What is the per-visit fee? PAYT/ SMART  \
# Municipality Name
# Abington                                  NaN         NaN
# Acton                                    30.0         Yes
#
#                   Municipal Buildings Trash and Recycling Service  ...  \
# Municipality Name                                                  ...
# Abington                                                     Both  ...
# Acton                                                        Both  ...
#
#                   Recycling Enforced by Muni Recycling Enforced by Hauler  \
# Municipality Name
# Abington                                 Yes                          Yes
# Acton                                    Yes                          NaN
#
#                   Dedicated Mandatory Recycling Enforcement Personnel  \
# Municipality Name
# Abington                                                         Yes
# Acton                                                             No
#
#                    # Hours Enforcement Personnel on Street  \
# Municipality Name
# Abington                                              20.0
# Acton                                                  NaN
#
#                   Private Hauler regulations that require recycling  \
# Municipality Name
# Abington                                                        Yes
# Acton                                                           NaN
#
#                   Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program  \
# Municipality Name
# Abington                                                         Yes
# Acton                                                            NaN
#
#                    Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program  \
# Municipality Name
# Abington                                                         Yes
# Acton                                                            NaN
#
#                   Applies to Commercial Generators.1 %recycle/hh  \
# Municipality Name
# Abington                                         Yes    0.269733
# Acton                                            NaN    0.310437
#
#                    total_waste/hh
# Municipality Name
# Abington                 1.168096
# Acton                    0.810190
#
# [2 rows x 47 columns]

# %%
df_for_regression.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 277 entries, Abington to Yarmouth
# Data columns (total 47 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   Solid Waste program funded by property tax?                                                       192 non-null    object
#  1   Solid Waste program funded by annual fee?                                                         85 non-null     object
#  2   Solid Waste program funded by transfer station access fee?                                        73 non-null     object
#  3   Solid Waste program funded by per-visit fee?                                                      18 non-null     object
#  4   Solid Waste program funded by PAYT/ SMART revenue?                                                132 non-null    object
#  5   What is the annual fee?                                                                           85 non-null     float64
#  6   What is the transfer station access fee?                                                          73 non-null     float64
#  7   What is the per-visit fee?                                                                        18 non-null     float64
#  8   PAYT/ SMART                                                                                       137 non-null    object
#  9   Municipal Buildings Trash and Recycling Service                                                   277 non-null    object
#  10  School Trash and Recycling Service                                                                277 non-null    object
#  11  Business Trash and Recycling Service                                                              277 non-null    object
#  12  Non-resident Trash and Recycling Service                                                          277 non-null    object
#  13  Households Served by Municipal Trash Program                                                      277 non-null    float64
#  14  Trash Service Type                                                                                277 non-null    object
#  15  Carts for Trash                                                                                   66 non-null     object
#  16  Trash Cart size                                                                                   66 non-null     float64
#  17  Does trash disposal tonnage include bulky waste?                                                  277 non-null    object
#  18  Fee for bulky waste?                                                                              253 non-null    object
#  19  Annual Bulky
# Waste
# Limit                                                                        48 non-null     float64
#  20  Tip Fee as of 1/1/2020                                                                            229 non-null    float64
#  21  Enforced Trash Limits at Curb                                                                     50 non-null     object
#  22  Maximum # bags/ barrels per week                                                                  50 non-null     float64
#  23  Barrel size in gallons (eg 32 64 etc)                                                             50 non-null     float64
#  24  Trash Enforced by Muni                                                                            31 non-null     object
#  25  Trash Enforced by Hauler                                                                          35 non-null     object
#  26  Dedicated Trash Enforcement Personnel                                                             31 non-null     object
#  27  Households Served by Municipal Recycling Program                                                  277 non-null    float64
#  28  Recycling Service Type                                                                            277 non-null    object
#  29  Recycling Collection Frequency                                                                    142 non-null    object
#  30  SS Recycling                                                                                      148 non-null    object
#  31  Carts for Recycling                                                                               79 non-null     object
#  32  Recycling Cart Size                                                                               79 non-null     float64
#  33  Enforced Mandatory Recycling                                                                      170 non-null    object
#  34  Applies to Residential Generators Eligible to be Served by Municipal Program                      169 non-null    object
#  35  Applies to Residential Generators not Eligible to be Served by the Municipal Program              74 non-null     object
#  36  Applies to Commercial Generators                                                                  65 non-null     object
#  37  Recycling Enforced by Muni                                                                        102 non-null    object
#  38  Recycling Enforced by Hauler                                                                      58 non-null     object
#  39  Dedicated Mandatory Recycling Enforcement Personnel                                               102 non-null    object
#  40  # Hours Enforcement Personnel on Street                                                           33 non-null     float64
#  41  Private Hauler regulations that require recycling                                                 70 non-null     object
#  42  Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program      60 non-null     object
#  43  Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program  55 non-null     object
#  44  Applies to Commercial Generators.1                                                                51 non-null     object
#  45  %recycle/hh                                                                                       271 non-null    float64
#  46  total_waste/hh                                                                                    271 non-null    float64
# dtypes: float64(14), object(33)
# memory usage: 113.9+ KB

# %% [markdown]
# There are lot of columns missing quite a few values. 277 entries, let's look at anything that has less than 200 non-null values.

# %%
# df_for_regression.count()[df_for_regression.count() < 200].sort_values()
df_for_regression.count()[df_for_regression.count() < 277].sort_values()
# Out:
# Solid Waste program funded by per-visit fee?                                                         18
# What is the per-visit fee?                                                                           18
# Dedicated Trash Enforcement Personnel                                                                31
# Trash Enforced by Muni                                                                               31
# # Hours Enforcement Personnel on Street                                                              33
# Trash Enforced by Hauler                                                                             35
# Annual Bulky \nWaste \nLimit                                                                         48
# Maximum # bags/ barrels per week                                                                     50
# Enforced Trash Limits at Curb                                                                        50
# Barrel size in gallons (eg 32 64 etc)                                                                50
# Applies to Commercial Generators.1                                                                   51
# Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program     55
# Recycling Enforced by Hauler                                                                         58
# Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program         60
# Applies to Commercial Generators                                                                     65
# Trash Cart size                                                                                      66
# Carts for Trash                                                                                      66
# Private Hauler regulations that require recycling                                                    70
# What is the transfer station access fee?                                                             73
# Solid Waste program funded by transfer station access fee?                                           73
# Applies to Residential Generators not Eligible to be Served by the Municipal Program                 74
# Carts for Recycling                                                                                  79
# Recycling Cart Size                                                                                  79
# Solid Waste program funded by annual fee?                                                            85
# What is the annual fee?                                                                              85
# Recycling Enforced by Muni                                                                          102
# Dedicated Mandatory Recycling Enforcement Personnel                                                 102
# Solid Waste program funded by PAYT/ SMART revenue?                                                  132
# PAYT/ SMART                                                                                         137
# Recycling Collection Frequency                                                                      142
# SS Recycling                                                                                        148
# Applies to Residential Generators Eligible to be Served by Municipal Program                        169
# Enforced Mandatory Recycling                                                                        170
# Solid Waste program funded by property tax?                                                         192
# Tip Fee as of 1/1/2020                                                                              229
# Fee for bulky waste?                                                                                253
# %recycle/hh                                                                                         271
# total_waste/hh                                                                                      271
# dtype: int64

# %% [markdown]
# Okay, some of the NaNs are because they really mean "no" or "0", like "Solid Waste program funded by per-visit fee?"

# %%
for col in df_for_regression.columns[df_for_regression.count() < 100]:
    print(df_for_regression[col].value_counts())
# Out:
# Yes    85
# Name: Solid Waste program funded by annual fee?, dtype: int64
# Yes    73
# Name: Solid Waste program funded by transfer station access fee?, dtype: int64
# Yes    18
# Name: Solid Waste program funded by per-visit fee?, dtype: int64
# 40.00     5
# 100.00    5
# 50.00     5
# 85.00     4
# 90.00     4
# 250.00    3
# 125.00    3
# 120.00    3
# 200.00    3
# 168.00    2
# 135.00    2
# 150.00    2
# 300.00    2
# 75.00     2
# 25.00     2
# 65.00     2
# 45.00     2
# 30.00     2
# 60.00     2
# 280.00    2
# 272.00    1
# 182.00    1
# 55.00     1
# 241.00    1
# 242.00    1
# 146.00    1
# 211.27    1
# 10.00     1
# 165.00    1
# 345.00    1
# 177.60    1
# 162.00    1
# 70.00     1
# 240.00    1
# 170.00    1
# 145.00    1
# 110.00    1
# 216.00    1
# 285.00    1
# 296.00    1
# 20.00     1
# 225.00    1
# 310.00    1
# 204.00    1
# 360.00    1
# 237.00    1
# 160.00    1
# 202.68    1
# Name: What is the annual fee?, dtype: int64
# 10.00     8
# 25.00     7
# 50.00     6
# 20.00     4
# 60.00     4
# 150.00    4
# 65.00     4
# 15.00     4
# 75.00     4
# 40.00     3
# 100.00    3
# 80.00     2
# 30.00     2
# 85.00     2
# 90.00     2
# 35.00     1
# 5.00      1
# 125.00    1
# 165.00    1
# 95.00     1
# 82.09     1
# 70.00     1
# 45.00     1
# 200.00    1
# 245.00    1
# 0.00      1
# 32.00     1
# 120.00    1
# 235.00    1
# Name: What is the transfer station access fee?, dtype: int64
# 20.0    5
# 10.0    4
# 15.0    3
# 5.0     2
# 40.0    1
# 25.0    1
# 2.0     1
# 30.0    1
# Name: What is the per-visit fee?, dtype: int64
# Yes    66
# Name: Carts for Trash, dtype: int64
# 64.0    39
# 35.0    13
# 65.0     8
# 96.0     4
# 48.0     2
# Name: Trash Cart size, dtype: int64
# 52.0     31
# 104.0     5
# 12.0      3
# 156.0     2
# 2.0       2
# 15.0      1
# 780.0     1
# 208.0     1
# 40.0      1
# 30.0      1
# Name: Annual Bulky \nWaste \nLimit, dtype: int64
# Yes    50
# Name: Enforced Trash Limits at Curb, dtype: int64
# 1.0    24
# 2.0    10
# 3.0     9
# 4.0     3
# 6.0     2
# 5.0     1
# 7.0     1
# Name: Maximum # bags/ barrels per week, dtype: int64
# 64.0    23
# 32.0    11
# 65.0     5
# 30.0     3
# 35.0     3
# 45.0     3
# 36.0     1
# 96.0     1
# Name: Barrel size in gallons (eg 32 64 etc), dtype: int64
# Yes    31
# Name: Trash Enforced by Muni, dtype: int64
# Yes    35
# Name: Trash Enforced by Hauler, dtype: int64
# No     21
# Yes    10
# Name: Dedicated Trash Enforcement Personnel, dtype: int64
# Yes    79
# Name: Carts for Recycling, dtype: int64
# 96.0    33
# 64.0    25
# 95.0    12
# 65.0     7
# 35.0     1
# 0.0      1
# Name: Recycling Cart Size, dtype: int64
# Yes    74
# Name: Applies to Residential Generators not Eligible to be Served by the Municipal Program, dtype: int64
# Yes    65
# Name: Applies to Commercial Generators, dtype: int64
# Yes    58
# Name: Recycling Enforced by Hauler, dtype: int64
# 40.0     6
# 19.0     5
# 20.0     4
# 0.0      3
# 10.0     2
# 7.0      2
# 60.0     1
# 15.0     1
# 30.0     1
# 13.0     1
# 31.0     1
# 16.0     1
# 48.0     1
# 43.0     1
# 128.0    1
# 12.0     1
# 2.0      1
# Name: # Hours Enforcement Personnel on Street, dtype: int64
# Yes    70
# Name: Private Hauler regulations that require recycling, dtype: int64
# Yes    60
# Name: Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program, dtype: int64
# Yes    55
# Name: Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program, dtype: int64
# Yes    51
# Name: Applies to Commercial Generators.1, dtype: int64

# %%
df_for_regression['Recycling Cart Size'].value_counts()
# Out:
# 96.0    33
# 64.0    25
# 95.0    12
# 65.0     7
# 35.0     1
# 0.0      1
# Name: Recycling Cart Size, dtype: int64

# %%
# columns with only "yes", and NaN likely means "no"

OHE_list_1 = ['Solid Waste program funded by per-visit fee?', 'Trash Enforced by Muni', 'Trash Enforced by Hauler', 'Enforced Trash Limits at Curb', 'Applies to Commercial Generators.1', 
'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program', 'Recycling Enforced by Hauler', 'Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
'Applies to Commercial Generators', 'Carts for Trash', 'Private Hauler regulations that require recycling', 'Solid Waste program funded by transfer station access fee?', 'Applies to Residential Generators not Eligible to be Served by the Municipal Program',
'Carts for Recycling', 'Solid Waste program funded by annual fee?', 'Recycling Enforced by Muni', 'Solid Waste program funded by PAYT/ SMART revenue?', 'PAYT/ SMART', 'SS Recycling', 'Applies to Residential Generators Eligible to be Served by Municipal Program',
'Solid Waste program funded by property tax?']

# %%
# columns with "yes" and "no", but I will assume NaN still likely means "no"
# note that enforcement personnel has only 31 non-null values but # of hours enforces is 33.

OHE_list_2 = ['Dedicated Trash Enforcement Personnel', 'Dedicated Mandatory Recycling Enforcement Personnel', 'Enforced Mandatory Recycling', 'Fee for bulky waste?']

# %%
# columns where NaN likely means "0"

fill_w_zero = ['What is the per-visit fee?', '# Hours Enforcement Personnel on Street',  'Annual Bulky \nWaste \nLimit', 'Maximum # bags/ barrels per week', 'What is the transfer station access fee?', 'What is the annual fee?', 'Tip Fee as of 1/1/2020']

# %%
# columns to impute Nans with Mode
# MUST CROSS CHECK IF TRASH IS A SERVICE PROVIDED (recycle is for every mun because of my trimming)
# barrel size and cart size can probably be simplified to 32, 48, 64, and 96

# barrel size and trash cart size, only impute where recycling service type is curbside or both, otherwise 0

impute_w_mode = ['Barrel size in gallons (eg 32 64 etc)', 'Trash Cart size', 'Recycling Cart Size', 'Recycling Collection Frequency']

# %%
for col in OHE_list_1:
    df_for_regression[col] = df_for_regression[col].str.replace('Yes', '1')
    df_for_regression[col].fillna(0, inplace = True)
    df_for_regression[col] = pd.to_numeric(df_for_regression[col])

# %%
for col in OHE_list_2:
    df_for_regression[col] = df_for_regression[col].str.replace('Yes', '1')
    df_for_regression[col] = df_for_regression[col].str.replace('No', '0')
    df_for_regression[col].fillna(0, inplace = True)
    df_for_regression[col] = pd.to_numeric(df_for_regression[col])

# %%
df_for_regression[fill_w_zero].fillna(0, inplace=True)
# Out:
# C:\Users\nanai\anaconda3\lib\site-packages\pandas\core\frame.py:4147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %% [markdown]
# I'm struggling with the last group because if bin size is missing, it probably means there's no limit of what you can put out or it's drop off only. I could see bin size being important because if the bin is too small, they may recycle less. If no bin is needed, maybe you can recycle more?
#
# It's almost like... you could make a bin scale:
# ```
# 0       no curbside pick up
# 0.25    0-35 gal bins
# 0.50    35-65 gal bins
# 0.75    65-96 gal bins
# 1       no bins provided
# ```
# I also think that Barrel size and Trash cart size can be joined into one. I think Trash cart size is in reference to specifically supplied bins whle barrel size refers to max bin sizes accept. I could take the Barrel size and any missing values, first try to fill with trash cart size. Then if there is curbside pickup, missing values are 1 and if no curbside, values are 0.
#
#
# Lastly, recycling frequency is only missing valuse because of drop-off only. I think I can still just OHE it? hopefully weekly would be `0 1`, biweekly would be `1 0`, and drop-off only would be `0 0`.

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
test_ohe = pd.get_dummies(pd.DataFrame(df_for_regression['Recycling Collection Frequency']))

# %%
test_ohe
# Out:
#                    Recycling Collection Frequency_Bi-weekly  \
# Municipality Name
# Abington                                                  0
# Acton                                                     0
# Acushnet                                                  1
# Adams                                                     0
# Agawam                                                    1
# ...                                                     ...
# Woburn                                                    1
# Worcester                                                 0
# Worthington                                               0
# Wrentham                                                  1
# Yarmouth                                                  0
#
#                    Recycling Collection Frequency_Weekly
# Municipality Name
# Abington                                               1
# Acton                                                  0
# Acushnet                                               0
# Adams                                                  0
# Agawam                                                 0
# ...                                                  ...
# Woburn                                                 0
# Worcester                                              1
# Worthington                                            0
# Wrentham                                               0
# Yarmouth                                               0
#
# [277 rows x 2 columns]

# %%
# CLEAN DATA
# where you left off, you just need to add these two dummy columns into the table and figure out
# a good way to implement the bin size schema you discussed above.

# REGRESSION
# corr heat map
# then you can do the baseline fit. I'd try a LinReg and a gradient boosted tree
# maybe some gs with pipeline for encoding
# assess the importance of each feature through the regression coefs
# Q: do we want tot_waste/hh to be an X variable or another independent var? I think we want it as an X

# NEXT
# part 4 --> assessing the clusters using the same data and modelistic approach

# %% [markdown]
# ## Regression
