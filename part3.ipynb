# %% [markdown]
# # Recycling Effectiveness in MA
#
# ### *Part 3: Baseline Regressions for Recycling Rate in Total Population Based on Service Attributes of Each Municipality*

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from plotly.graph_objs import *
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing and Inspection of Data

# %%
# Import the 2019 municipal survey results into a df
# usecols is just trimming off additional columns that had to do with special/hazardous recyclables

serv19 = pd.read_csv('data/MA_MSW_Collection_Data/serv19cleaned.csv', index_col='Municipality Name')
serv19.head()
# Out:
#                        Contact Name  Total Number of Households  \
# Municipality Name
# Abington           Angela Dahlstrom                      6558.0
# Acton                    Corey York                      9800.0
# Acushnet                 Dan Menard                      4304.0
# Adams                  Linda Cernik                      3867.0
# Agawam                 Tracy DeMaio                     12031.0
#
#                    Households Served by Municipal Trash Program  \
# Municipality Name
# Abington                                                 4486.0
# Acton                                                    3846.0
# Acushnet                                                 3591.0
# Adams                                                     664.0
# Agawam                                                   8879.0
#
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Abington                                                     4486.0
# Acton                                                        4335.0
# Acushnet                                                     3591.0
# Adams                                                         664.0
# Agawam                                                       8879.0
#
#                   Trash Service Type Carts for Trash  Trash Cart size  \
# Municipality Name
# Abington                    Curbside             Yes             64.0
# Acton                       Drop-off             NaN              NaN
# Acushnet                    Curbside             Yes             65.0
# Adams                       Drop-off             NaN              NaN
# Agawam                      Curbside             Yes             65.0
#
#                   Recycling Service Type Recycling Collection Frequency  \
# Municipality Name
# Abington                        Curbside                         Weekly
# Acton                           Drop-off                            NaN
# Acushnet                            Both                      Bi-weekly
# Adams                           Drop-off                            NaN
# Agawam                          Curbside                      Bi-weekly
#
#                   SS Recycling  ...  \
# Municipality Name               ...
# Abington                   Yes  ...
# Acton                      NaN  ...
# Acushnet                   Yes  ...
# Adams                      NaN  ...
# Agawam                     Yes  ...
#
#                   Does trash disposal tonnage include bulky waste?  \
# Municipality Name
# Abington                                                       Yes
# Acton                                                          Yes
# Acushnet                                                        No
# Adams                                                           No
# Agawam                                                          No
#
#                    Bulky waste tonnage Fee for bulky waste?  \
# Municipality Name
# Abington                           NaN                  Yes
# Acton                              NaN                  Yes
# Acushnet                         41.00                  Yes
# Adams                             4.43                  Yes
# Agawam                          275.17                  Yes
#
#                   Annual Bulky \nWaste \nLimit Tip Fee as of 1/1/2020  \
# Municipality Name
# Abington                                   NaN                  86.50
# Acton                                      NaN                  57.16
# Acushnet                                   NaN                  64.60
# Adams                                      NaN                 110.00
# Agawam                                    30.0                  74.00
#
#                   Tons Single Stream Recyclables Newspaper Cardboard  \
# Municipality Name
# Abington                                 1413.42       NaN       NaN
# Acton                                        NaN       NaN       NaN
# Acushnet                                  879.50       3.7      20.0
# Adams                                        NaN       NaN       NaN
# Agawam                                   2238.00       NaN       NaN
#
#                   Mixed Paper Commingled
# Municipality Name
# Abington                  NaN        NaN
# Acton                  683.04     407.27
# Acushnet                16.94      27.40
# Adams                   94.13      45.48
# Agawam                    NaN        NaN
#
# [5 rows x 54 columns]

# %%
serv19.columns
# Out:
# Index(['Contact Name', 'Total Number of Households',
#        'Households Served by Municipal Trash Program',
#        'Households Served by Municipal Recycling Program',
#        'Trash Service Type', 'Carts for Trash', 'Trash Cart size',
#        'Recycling Service Type', 'Recycling Collection Frequency',
#        'SS Recycling', 'Carts for Recycling', 'Recycling Cart Size',
#        'Municipal Buildings Trash and Recycling Service',
#        'School Trash and Recycling Service',
#        'Business Trash and Recycling Service',
#        'Non-resident Trash and Recycling Service',
#        'Solid Waste program funded by property tax?',
#        'Solid Waste program funded by annual fee?',
#        'Solid Waste program funded by transfer station access fee?',
#        'Solid Waste program funded by per-visit fee?',
#        'Solid Waste program funded by PAYT/ SMART revenue?',
#        'What is the annual fee?', 'What is the transfer station access fee?',
#        'What is the per-visit fee?', 'PAYT/ SMART',
#        'Enforced Trash Limits at Curb', 'Maximum # bags/ barrels per week',
#        'Barrel size in gallons (eg 32 64 etc)', 'Trash Enforced by Muni',
#        'Trash Enforced by Hauler', 'Dedicated Trash Enforcement Personnel',
#        'Enforced Mandatory Recycling',
#        'Applies to Residential Generators Eligible to be Served by Municipal Program',
#        'Applies to Residential Generators not Eligible to be Served by the Municipal Program',
#        'Applies to Commercial Generators', 'Recycling Enforced by Muni',
#        'Recycling Enforced by Hauler',
#        'Dedicated Mandatory Recycling Enforcement Personnel',
#        '# Hours Enforcement Personnel on Street',
#        'Private Hauler regulations that require recycling',
#        'Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
#        'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program',
#        'Applies to Commercial Generators.1', 'Trash Disposal Tonnage',
#        'Does trash disposal tonnage include bulky waste?',
#        'Bulky waste tonnage', 'Fee for bulky waste?',
#        'Annual Bulky \nWaste \nLimit', 'Tip Fee as of 1/1/2020',
#        'Tons Single Stream Recyclables', 'Newspaper', 'Cardboard',
#        'Mixed Paper', 'Commingled'],
#       dtype='object')

# %%
cols_to_use = ['Solid Waste program funded by property tax?',
       'Solid Waste program funded by annual fee?',
       'Solid Waste program funded by transfer station access fee?',
       'Solid Waste program funded by per-visit fee?',
       'Solid Waste program funded by PAYT/ SMART revenue?',
       'What is the annual fee?', 'What is the transfer station access fee?',
       'What is the per-visit fee?', 'PAYT/ SMART',
       'Municipal Buildings Trash and Recycling Service',
       'School Trash and Recycling Service',
       'Business Trash and Recycling Service',
       'Non-resident Trash and Recycling Service', 'Households Served by Municipal Trash Program', 'Trash Service Type', 'Carts for Trash', 'Trash Cart size', 'Does trash disposal tonnage include bulky waste?','Fee for bulky waste?',
       'Annual Bulky \nWaste \nLimit', 'Tip Fee as of 1/1/2020', 'Enforced Trash Limits at Curb', 'Maximum # bags/ barrels per week',
       'Barrel size in gallons (eg 32 64 etc)', 'Trash Enforced by Muni',
       'Trash Enforced by Hauler', 'Dedicated Trash Enforcement Personnel','Households Served by Municipal Recycling Program', 'Recycling Service Type', 'Recycling Collection Frequency',
       'SS Recycling', 'Carts for Recycling', 'Recycling Cart Size', 'Enforced Mandatory Recycling',
       'Applies to Residential Generators Eligible to be Served by Municipal Program',
       'Applies to Residential Generators not Eligible to be Served by the Municipal Program',
       'Applies to Commercial Generators', 'Recycling Enforced by Muni',
       'Recycling Enforced by Hauler',
       'Dedicated Mandatory Recycling Enforcement Personnel',
       '# Hours Enforcement Personnel on Street', 'Private Hauler regulations that require recycling',
       'Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
       'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program',
       'Applies to Commercial Generators.1'
              ]

# %%
# general information related to funding for service.

serv_fund = ['Solid Waste program funded by property tax?',
       'Solid Waste program funded by annual fee?',
       'Solid Waste program funded by transfer station access fee?',
       'Solid Waste program funded by per-visit fee?',
       'Solid Waste program funded by PAYT/ SMART revenue?',
       'What is the annual fee?', 'What is the transfer station access fee?',
       'What is the per-visit fee?', 'PAYT/ SMART',]

# %%
# general service information for non-residental buildings

gen_serv = ['Municipal Buildings Trash and Recycling Service',
       'School Trash and Recycling Service',
       'Business Trash and Recycling Service',
       'Non-resident Trash and Recycling Service', ]

# %%
# quantities and specifications related to trash services

trash_serv = ['Households Served by Municipal Trash Program', 'Trash Service Type', 'Carts for Trash', 'Trash Cart size', 'Does trash disposal tonnage include bulky waste?','Fee for bulky waste?',
       'Annual Bulky \nWaste \nLimit', 'Tip Fee as of 1/1/2020', 'Enforced Trash Limits at Curb', 'Maximum # bags/ barrels per week',
       'Barrel size in gallons (eg 32 64 etc)', 'Trash Enforced by Muni',
       'Trash Enforced by Hauler', 'Dedicated Trash Enforcement Personnel', ]

# %%
# quantitative data on trash tonnages collected

trash_tonnage_data = ['Households Served by Municipal Trash Program', 'Trash Disposal Tonnage', 'Bulky waste tonnage', ]

# %%
# quantities and specifications related to recycle services

recycle_serv= ['Households Served by Municipal Recycling Program', 'Recycling Service Type', 'Recycling Collection Frequency',
       'SS Recycling', 'Carts for Recycling', 'Recycling Cart Size', 'Enforced Mandatory Recycling',
       'Applies to Residential Generators Eligible to be Served by Municipal Program',
       'Applies to Residential Generators not Eligible to be Served by the Municipal Program',
       'Applies to Commercial Generators', 'Recycling Enforced by Muni',
       'Recycling Enforced by Hauler',
       'Dedicated Mandatory Recycling Enforcement Personnel',
       '# Hours Enforcement Personnel on Street', 'Private Hauler regulations that require recycling',
       'Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
       'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program',
       'Applies to Commercial Generators.1']

# %%
# Import summary data for municipal waste tonnages in 2019

tonnages19 = pd.read_csv('data/MA_MSW_Collection_Data/musum19.csv', index_col='Municipality Name')
tonnages19.head()
# Out:
#                    tot_households stream_type  tons_ss_recyclables  \
# Municipality Name
# Abington                   6558.0          ss              1413.42
# Acton                      9800.0          ms                 0.00
# Acushnet                   4304.0         ss+               879.50
# Adams                      3867.0          ms                 0.00
# Agawam                    12031.0          ss              2238.00
#
#                    tons_ms_recyclables  tons_recyclables_total  \
# Municipality Name
# Abington                          0.00                 1413.42
# Acton                          1090.31                 1090.31
# Acushnet                         68.04                  947.54
# Adams                           139.61                  139.61
# Agawam                            0.00                 2238.00
#
#                    hh_served_by_mu_recycle  tons_recyclables/hh  \
# Municipality Name
# Abington                            4486.0             0.315074
# Acton                               4335.0             0.251513
# Acushnet                            3591.0             0.263865
# Adams                                664.0             0.210256
# Agawam                              8879.0             0.252055
#
#                    hh_served_by_mu_trash  tons_trash_total  tons_trash/hh  \
# Municipality Name
# Abington                          4486.0           3826.66       0.853023
# Acton                             3846.0           2148.67       0.558677
# Acushnet                          3591.0           3446.38       0.959727
# Adams                              664.0            134.47       0.202515
# Agawam                            8879.0           6717.17       0.756523
#
#                    %recycle/hh  total_waste/hh
# Municipality Name
# Abington              0.269733        1.168096
# Acton                 0.310437        0.810190
# Acushnet              0.215648        1.223592
# Adams                 0.509377        0.412771
# Agawam                0.249912        1.008579

# %% [markdown]
# ## Setting up data for regression

# %%
df_for_regression = serv19.loc[:,cols_to_use].merge(tonnages19.loc[:,['%recycle/hh','total_waste/hh']], left_index=True, right_index=True)
df_for_regression.head(2)
# Out:
#                   Solid Waste program funded by property tax?  \
# Municipality Name
# Abington                                                  Yes
# Acton                                                     NaN
#
#                   Solid Waste program funded by annual fee?  \
# Municipality Name
# Abington                                                NaN
# Acton                                                   NaN
#
#                   Solid Waste program funded by transfer station access fee?  \
# Municipality Name
# Abington                                                         NaN
# Acton                                                            Yes
#
#                   Solid Waste program funded by per-visit fee?  \
# Municipality Name
# Abington                                                   NaN
# Acton                                                      Yes
#
#                   Solid Waste program funded by PAYT/ SMART revenue?  \
# Municipality Name
# Abington                                                         NaN
# Acton                                                            Yes
#
#                    What is the annual fee?  \
# Municipality Name
# Abington                               NaN
# Acton                                  NaN
#
#                    What is the transfer station access fee?  \
# Municipality Name
# Abington                                                NaN
# Acton                                                 100.0
#
#                    What is the per-visit fee? PAYT/ SMART  \
# Municipality Name
# Abington                                  NaN         NaN
# Acton                                    30.0         Yes
#
#                   Municipal Buildings Trash and Recycling Service  ...  \
# Municipality Name                                                  ...
# Abington                                                     Both  ...
# Acton                                                        Both  ...
#
#                   Recycling Enforced by Muni Recycling Enforced by Hauler  \
# Municipality Name
# Abington                                 Yes                          Yes
# Acton                                    Yes                          NaN
#
#                   Dedicated Mandatory Recycling Enforcement Personnel  \
# Municipality Name
# Abington                                                         Yes
# Acton                                                             No
#
#                    # Hours Enforcement Personnel on Street  \
# Municipality Name
# Abington                                              20.0
# Acton                                                  NaN
#
#                   Private Hauler regulations that require recycling  \
# Municipality Name
# Abington                                                        Yes
# Acton                                                           NaN
#
#                   Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program  \
# Municipality Name
# Abington                                                         Yes
# Acton                                                            NaN
#
#                    Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program  \
# Municipality Name
# Abington                                                         Yes
# Acton                                                            NaN
#
#                   Applies to Commercial Generators.1 %recycle/hh  \
# Municipality Name
# Abington                                         Yes    0.269733
# Acton                                            NaN    0.310437
#
#                    total_waste/hh
# Municipality Name
# Abington                 1.168096
# Acton                    0.810190
#
# [2 rows x 47 columns]

# %%
df_for_regression.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 277 entries, Abington to Yarmouth
# Data columns (total 47 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   Solid Waste program funded by property tax?                                                       192 non-null    object
#  1   Solid Waste program funded by annual fee?                                                         85 non-null     object
#  2   Solid Waste program funded by transfer station access fee?                                        73 non-null     object
#  3   Solid Waste program funded by per-visit fee?                                                      18 non-null     object
#  4   Solid Waste program funded by PAYT/ SMART revenue?                                                132 non-null    object
#  5   What is the annual fee?                                                                           85 non-null     float64
#  6   What is the transfer station access fee?                                                          73 non-null     float64
#  7   What is the per-visit fee?                                                                        18 non-null     float64
#  8   PAYT/ SMART                                                                                       137 non-null    object
#  9   Municipal Buildings Trash and Recycling Service                                                   277 non-null    object
#  10  School Trash and Recycling Service                                                                277 non-null    object
#  11  Business Trash and Recycling Service                                                              277 non-null    object
#  12  Non-resident Trash and Recycling Service                                                          277 non-null    object
#  13  Households Served by Municipal Trash Program                                                      277 non-null    float64
#  14  Trash Service Type                                                                                277 non-null    object
#  15  Carts for Trash                                                                                   66 non-null     object
#  16  Trash Cart size                                                                                   66 non-null     float64
#  17  Does trash disposal tonnage include bulky waste?                                                  277 non-null    object
#  18  Fee for bulky waste?                                                                              253 non-null    object
#  19  Annual Bulky
# Waste
# Limit                                                                        48 non-null     float64
#  20  Tip Fee as of 1/1/2020                                                                            229 non-null    float64
#  21  Enforced Trash Limits at Curb                                                                     50 non-null     object
#  22  Maximum # bags/ barrels per week                                                                  50 non-null     float64
#  23  Barrel size in gallons (eg 32 64 etc)                                                             50 non-null     float64
#  24  Trash Enforced by Muni                                                                            31 non-null     object
#  25  Trash Enforced by Hauler                                                                          35 non-null     object
#  26  Dedicated Trash Enforcement Personnel                                                             31 non-null     object
#  27  Households Served by Municipal Recycling Program                                                  277 non-null    float64
#  28  Recycling Service Type                                                                            277 non-null    object
#  29  Recycling Collection Frequency                                                                    142 non-null    object
#  30  SS Recycling                                                                                      148 non-null    object
#  31  Carts for Recycling                                                                               79 non-null     object
#  32  Recycling Cart Size                                                                               79 non-null     float64
#  33  Enforced Mandatory Recycling                                                                      170 non-null    object
#  34  Applies to Residential Generators Eligible to be Served by Municipal Program                      169 non-null    object
#  35  Applies to Residential Generators not Eligible to be Served by the Municipal Program              74 non-null     object
#  36  Applies to Commercial Generators                                                                  65 non-null     object
#  37  Recycling Enforced by Muni                                                                        102 non-null    object
#  38  Recycling Enforced by Hauler                                                                      58 non-null     object
#  39  Dedicated Mandatory Recycling Enforcement Personnel                                               102 non-null    object
#  40  # Hours Enforcement Personnel on Street                                                           33 non-null     float64
#  41  Private Hauler regulations that require recycling                                                 70 non-null     object
#  42  Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program      60 non-null     object
#  43  Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program  55 non-null     object
#  44  Applies to Commercial Generators.1                                                                51 non-null     object
#  45  %recycle/hh                                                                                       271 non-null    float64
#  46  total_waste/hh                                                                                    271 non-null    float64
# dtypes: float64(14), object(33)
# memory usage: 113.9+ KB

# %% [markdown]
# ### Dealing with NaNs
#
# There are lot of columns missing quite a few values. 277 entries, let's look at anything that has less than 271 non-null values. I can see the features with 271 non-null values are datapoints that I knew were missing some data. I get to that last.

# %%
df_for_regression.count()[df_for_regression.count() < 271].sort_values()
# Out:
# Solid Waste program funded by per-visit fee?                                                         18
# What is the per-visit fee?                                                                           18
# Trash Enforced by Muni                                                                               31
# Dedicated Trash Enforcement Personnel                                                                31
# # Hours Enforcement Personnel on Street                                                              33
# Trash Enforced by Hauler                                                                             35
# Annual Bulky \nWaste \nLimit                                                                         48
# Barrel size in gallons (eg 32 64 etc)                                                                50
# Maximum # bags/ barrels per week                                                                     50
# Enforced Trash Limits at Curb                                                                        50
# Applies to Commercial Generators.1                                                                   51
# Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program     55
# Recycling Enforced by Hauler                                                                         58
# Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program         60
# Applies to Commercial Generators                                                                     65
# Carts for Trash                                                                                      66
# Trash Cart size                                                                                      66
# Private Hauler regulations that require recycling                                                    70
# What is the transfer station access fee?                                                             73
# Solid Waste program funded by transfer station access fee?                                           73
# Applies to Residential Generators not Eligible to be Served by the Municipal Program                 74
# Carts for Recycling                                                                                  79
# Recycling Cart Size                                                                                  79
# What is the annual fee?                                                                              85
# Solid Waste program funded by annual fee?                                                            85
# Recycling Enforced by Muni                                                                          102
# Dedicated Mandatory Recycling Enforcement Personnel                                                 102
# Solid Waste program funded by PAYT/ SMART revenue?                                                  132
# PAYT/ SMART                                                                                         137
# Recycling Collection Frequency                                                                      142
# SS Recycling                                                                                        148
# Applies to Residential Generators Eligible to be Served by Municipal Program                        169
# Enforced Mandatory Recycling                                                                        170
# Solid Waste program funded by property tax?                                                         192
# Tip Fee as of 1/1/2020                                                                              229
# Fee for bulky waste?                                                                                253
# dtype: int64

# %% [markdown]
# Okay, some of the NaNs are because they really mean "no" or "0", like "Solid Waste program funded by per-visit fee?". Others are numeric and I'll need to handle those appropriately.

# %%
# enter each feature name to see why they may have NaNs
df_for_regression['Recycling Cart Size'].value_counts()
# Out:
# 96.0    33
# 64.0    25
# 95.0    12
# 65.0     7
# 35.0     1
# 0.0      1
# Name: Recycling Cart Size, dtype: int64

# %%
# columns with only "yes", and NaN likely means "no"

OHE_list_1 = ['Solid Waste program funded by per-visit fee?', 'Trash Enforced by Muni', 'Trash Enforced by Hauler', 'Enforced Trash Limits at Curb', 'Applies to Commercial Generators.1', 
'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program', 'Recycling Enforced by Hauler', 'Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
'Applies to Commercial Generators', 'Carts for Trash', 'Private Hauler regulations that require recycling', 'Solid Waste program funded by transfer station access fee?', 'Applies to Residential Generators not Eligible to be Served by the Municipal Program',
'Carts for Recycling', 'Solid Waste program funded by annual fee?', 'Recycling Enforced by Muni', 'Solid Waste program funded by PAYT/ SMART revenue?', 'PAYT/ SMART', 'SS Recycling', 'Applies to Residential Generators Eligible to be Served by Municipal Program',
'Solid Waste program funded by property tax?']

# %%
# columns with "yes" and "no", but I will assume NaN still likely means "no"
# note that enforcement personnel has only 31 non-null values but # of hours enforces is 33.

OHE_list_2 = ['Dedicated Trash Enforcement Personnel', 'Dedicated Mandatory Recycling Enforcement Personnel', 'Enforced Mandatory Recycling', 'Fee for bulky waste?']

# %%
# columns where NaN likely means "0"

fill_w_zero = ['What is the per-visit fee?', '# Hours Enforcement Personnel on Street',  'Annual Bulky \nWaste \nLimit', 'Maximum # bags/ barrels per week', 'What is the transfer station access fee?', 'What is the annual fee?', 'Tip Fee as of 1/1/2020']

# %%
# columns that have multiple options 
# barrel size and cart size can probably be simplified to 32, 48, 64, and 96

# barrel size and trash cart size, only impute where recycling service type is curbside or both, otherwise 0

impute_w_mode = ['Barrel size in gallons (eg 32 64 etc)', 'Trash Cart size', 'Recycling Cart Size', 'Recycling Collection Frequency']

# %%
for col in OHE_list_1:
    df_for_regression[col] = df_for_regression[col].str.replace('Yes', '1')
    df_for_regression[col].fillna(0, inplace = True)
    df_for_regression[col] = pd.to_numeric(df_for_regression[col])

# %%
for col in OHE_list_2:
    df_for_regression[col] = df_for_regression[col].str.replace('Yes', '1')
    df_for_regression[col] = df_for_regression[col].str.replace('No', '0')
    df_for_regression[col].fillna(0, inplace = True)
    df_for_regression[col] = pd.to_numeric(df_for_regression[col])

# %%
df_for_regression[fill_w_zero] = df_for_regression[fill_w_zero].fillna(0)

# %% [markdown]
# I'm struggling with the last group because if bin size is missing, it probably means there's no limit of what you can put out or it's drop off only. I could see bin size being important because if the bin is too small, they may recycle less. If no bin is needed, maybe you can recycle more?
#
# It's almost like... you could make a bin scale:
# ```
# 0       no curbside pick up
# 0.25    0-35 gal bins
# 0.50    35-65 gal bins
# 0.75    65-96 gal bins
# 1       no bins provided
# ```
# I also think that Barrel size and Trash cart size can be joined into one. I think Trash cart size is in reference to specifically supplied bins whle barrel size refers to max bin sizes accept. I could take the Barrel size and any missing values, first try to fill with trash cart size. Then if there is curbside pickup, missing values are 1 and if no curbside, values are 0.
#
#
# Lastly, recycling frequency is only missing valuse because of drop-off only. I think I can still just OHE it? hopefully weekly would be `0 1`, biweekly would be `1 0`, and drop-off only would be `0 0`.

# %%
recycle_collection_encoding = pd.get_dummies(pd.DataFrame(df_for_regression['Recycling Collection Frequency']))

# %%
recycle_collection_encoding
# Out:
#                    Recycling Collection Frequency_Bi-weekly  \
# Municipality Name
# Abington                                                  0
# Acton                                                     0
# Acushnet                                                  1
# Adams                                                     0
# Agawam                                                    1
# ...                                                     ...
# Woburn                                                    1
# Worcester                                                 0
# Worthington                                               0
# Wrentham                                                  1
# Yarmouth                                                  0
#
#                    Recycling Collection Frequency_Weekly
# Municipality Name
# Abington                                               1
# Acton                                                  0
# Acushnet                                               0
# Adams                                                  0
# Agawam                                                 0
# ...                                                  ...
# Woburn                                                 0
# Worcester                                              1
# Worthington                                            0
# Wrentham                                               0
# Yarmouth                                               0
#
# [277 rows x 2 columns]

# %%
df_for_regression = df_for_regression.merge(recycle_collection_encoding, left_index=True,right_index=True)
df_for_regression.head()
# Out:
#                    Solid Waste program funded by property tax?  \
# Municipality Name
# Abington                                                     1
# Acton                                                        0
# Acushnet                                                     1
# Adams                                                        1
# Agawam                                                       1
#
#                    Solid Waste program funded by annual fee?  \
# Municipality Name
# Abington                                                   0
# Acton                                                      0
# Acushnet                                                   0
# Adams                                                      0
# Agawam                                                     0
#
#                    Solid Waste program funded by transfer station access fee?  \
# Municipality Name
# Abington                                                           0
# Acton                                                              1
# Acushnet                                                           0
# Adams                                                              1
# Agawam                                                             0
#
#                    Solid Waste program funded by per-visit fee?  \
# Municipality Name
# Abington                                                      0
# Acton                                                         1
# Acushnet                                                      0
# Adams                                                         0
# Agawam                                                        0
#
#                    Solid Waste program funded by PAYT/ SMART revenue?  \
# Municipality Name
# Abington                                                           0
# Acton                                                              1
# Acushnet                                                           0
# Adams                                                              1
# Agawam                                                             0
#
#                    What is the annual fee?  \
# Municipality Name
# Abington                               0.0
# Acton                                  0.0
# Acushnet                               0.0
# Adams                                  0.0
# Agawam                                 0.0
#
#                    What is the transfer station access fee?  \
# Municipality Name
# Abington                                                0.0
# Acton                                                 100.0
# Acushnet                                                0.0
# Adams                                                  50.0
# Agawam                                                  0.0
#
#                    What is the per-visit fee?  PAYT/ SMART  \
# Municipality Name
# Abington                                  0.0            0
# Acton                                    30.0            1
# Acushnet                                  0.0            0
# Adams                                     0.0            1
# Agawam                                    0.0            0
#
#                   Municipal Buildings Trash and Recycling Service  ...  \
# Municipality Name                                                  ...
# Abington                                                     Both  ...
# Acton                                                        Both  ...
# Acushnet                                                     Both  ...
# Adams                                                        Both  ...
# Agawam                                                       Both  ...
#
#                   Dedicated Mandatory Recycling Enforcement Personnel  \
# Municipality Name
# Abington                                                           1
# Acton                                                              0
# Acushnet                                                           0
# Adams                                                              0
# Agawam                                                             0
#
#                   # Hours Enforcement Personnel on Street  \
# Municipality Name
# Abington                                             20.0
# Acton                                                 0.0
# Acushnet                                              0.0
# Adams                                                 0.0
# Agawam                                                0.0
#
#                   Private Hauler regulations that require recycling  \
# Municipality Name
# Abington                                                          1
# Acton                                                             0
# Acushnet                                                          1
# Adams                                                             1
# Agawam                                                            0
#
#                    Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program  \
# Municipality Name
# Abington                                                           1
# Acton                                                              0
# Acushnet                                                           1
# Adams                                                              1
# Agawam                                                             0
#
#                   Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program  \
# Municipality Name
# Abington                                                           1
# Acton                                                              0
# Acushnet                                                           0
# Adams                                                              0
# Agawam                                                             0
#
#                    Applies to Commercial Generators.1  %recycle/hh  \
# Municipality Name
# Abington                                            1     0.269733
# Acton                                               0     0.310437
# Acushnet                                            0     0.215648
# Adams                                               1     0.509377
# Agawam                                              0     0.249912
#
#                   total_waste/hh  Recycling Collection Frequency_Bi-weekly  \
# Municipality Name
# Abington                1.168096                                         0
# Acton                   0.810190                                         0
# Acushnet                1.223592                                         1
# Adams                   0.412771                                         0
# Agawam                  1.008579                                         1
#
#                    Recycling Collection Frequency_Weekly
# Municipality Name
# Abington                                               1
# Acton                                                  0
# Acushnet                                               0
# Adams                                                  0
# Agawam                                                 0
#
# [5 rows x 49 columns]

# %%
df_for_regression.drop(columns='Recycling Collection Frequency', inplace=True)

# %%
def bin_rank(size, serve_type, limit_size):
    if limit_size != np.nan:
        x = (
            0 if serve_type == 'Drop-off' or serve_type == 'None' else
            0.25 if limit_size < 35 else
            0.50 if limit_size < 65 else
            0.75 if limit_size < 96 else
            1)
    else:
        x = (
            0 if serve_type == 'Drop-off' or serve_type == 'None' else
            0.25 if size < 35 else
            0.50 if size < 65 else
            0.75 if size < 96 else
            1)
    return x

# %%
df_for_regression['Trash Service Type'].unique()
# Out:
# array(['Curbside', 'Drop-off', 'Both', 'None'], dtype=object)

# %%
df_for_regression['Trash Bin Size Ranking'] = df_for_regression.apply(lambda row: bin_rank(row['Trash Cart size'], row['Trash Service Type'],row['Barrel size in gallons (eg 32 64 etc)']), axis=1)
df_for_regression.head(2)
# Out:
#                    Solid Waste program funded by property tax?  \
# Municipality Name
# Abington                                                     1
# Acton                                                        0
#
#                    Solid Waste program funded by annual fee?  \
# Municipality Name
# Abington                                                   0
# Acton                                                      0
#
#                    Solid Waste program funded by transfer station access fee?  \
# Municipality Name
# Abington                                                           0
# Acton                                                              1
#
#                    Solid Waste program funded by per-visit fee?  \
# Municipality Name
# Abington                                                      0
# Acton                                                         1
#
#                    Solid Waste program funded by PAYT/ SMART revenue?  \
# Municipality Name
# Abington                                                           0
# Acton                                                              1
#
#                    What is the annual fee?  \
# Municipality Name
# Abington                               0.0
# Acton                                  0.0
#
#                    What is the transfer station access fee?  \
# Municipality Name
# Abington                                                0.0
# Acton                                                 100.0
#
#                    What is the per-visit fee?  PAYT/ SMART  \
# Municipality Name
# Abington                                  0.0            0
# Acton                                    30.0            1
#
#                   Municipal Buildings Trash and Recycling Service  ...  \
# Municipality Name                                                  ...
# Abington                                                     Both  ...
# Acton                                                        Both  ...
#
#                   # Hours Enforcement Personnel on Street  \
# Municipality Name
# Abington                                             20.0
# Acton                                                 0.0
#
#                   Private Hauler regulations that require recycling  \
# Municipality Name
# Abington                                                          1
# Acton                                                             0
#
#                   Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program  \
# Municipality Name
# Abington                                                           1
# Acton                                                              0
#
#                    Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program  \
# Municipality Name
# Abington                                                           1
# Acton                                                              0
#
#                   Applies to Commercial Generators.1  %recycle/hh  \
# Municipality Name
# Abington                                           1     0.269733
# Acton                                              0     0.310437
#
#                    total_waste/hh Recycling Collection Frequency_Bi-weekly  \
# Municipality Name
# Abington                 1.168096                                        0
# Acton                    0.810190                                        0
#
#                    Recycling Collection Frequency_Weekly  \
# Municipality Name
# Abington                                               1
# Acton                                                  0
#
#                    Trash Bin Size Ranking
# Municipality Name
# Abington                              0.5
# Acton                                 0.0
#
# [2 rows x 49 columns]

# %%
df_for_regression.drop(columns=['Trash Cart size','Barrel size in gallons (eg 32 64 etc)'], inplace=True)

# %%
def bin_rank(size, serve_type):
    x = (
        0 if serve_type == 'Drop-off' or serve_type == 'None' else
        0.25 if size < 35 else
        0.50 if size < 65 else
        0.75 if size < 96 else
        1)
    return x

# %%
df_for_regression['Recycling Cart Size']
# Out:
# Municipality Name
# Abington       64.0
# Acton           NaN
# Acushnet       96.0
# Adams           NaN
# Agawam         95.0
#                ...
# Woburn          NaN
# Worcester       NaN
# Worthington     NaN
# Wrentham       96.0
# Yarmouth        NaN
# Name: Recycling Cart Size, Length: 277, dtype: float64

# %%
df_for_regression['Recycle Bin Size Ranking'] = df_for_regression.apply(lambda row: bin_rank(row['Recycling Cart Size'], row['Recycling Service Type']), axis=1)
df_for_regression.head(2)
# Out:
#                    Solid Waste program funded by property tax?  \
# Municipality Name
# Abington                                                     1
# Acton                                                        0
#
#                    Solid Waste program funded by annual fee?  \
# Municipality Name
# Abington                                                   0
# Acton                                                      0
#
#                    Solid Waste program funded by transfer station access fee?  \
# Municipality Name
# Abington                                                           0
# Acton                                                              1
#
#                    Solid Waste program funded by per-visit fee?  \
# Municipality Name
# Abington                                                      0
# Acton                                                         1
#
#                    Solid Waste program funded by PAYT/ SMART revenue?  \
# Municipality Name
# Abington                                                           0
# Acton                                                              1
#
#                    What is the annual fee?  \
# Municipality Name
# Abington                               0.0
# Acton                                  0.0
#
#                    What is the transfer station access fee?  \
# Municipality Name
# Abington                                                0.0
# Acton                                                 100.0
#
#                    What is the per-visit fee?  PAYT/ SMART  \
# Municipality Name
# Abington                                  0.0            0
# Acton                                    30.0            1
#
#                   Municipal Buildings Trash and Recycling Service  ...  \
# Municipality Name                                                  ...
# Abington                                                     Both  ...
# Acton                                                        Both  ...
#
#                   Private Hauler regulations that require recycling  \
# Municipality Name
# Abington                                                          1
# Acton                                                             0
#
#                   Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program  \
# Municipality Name
# Abington                                                           1
# Acton                                                              0
#
#                   Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program  \
# Municipality Name
# Abington                                                           1
# Acton                                                              0
#
#                    Applies to Commercial Generators.1 %recycle/hh  \
# Municipality Name
# Abington                                            1    0.269733
# Acton                                               0    0.310437
#
#                    total_waste/hh Recycling Collection Frequency_Bi-weekly  \
# Municipality Name
# Abington                 1.168096                                        0
# Acton                    0.810190                                        0
#
#                    Recycling Collection Frequency_Weekly  \
# Municipality Name
# Abington                                               1
# Acton                                                  0
#
#                    Trash Bin Size Ranking  Recycle Bin Size Ranking
# Municipality Name
# Abington                              0.5                       0.5
# Acton                                 0.0                       0.0
#
# [2 rows x 48 columns]

# %%
df_for_regression.drop(columns=['Recycling Cart Size'], inplace=True)

# %%
df_for_regression.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 277 entries, Abington to Yarmouth
# Data columns (total 47 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   Solid Waste program funded by property tax?                                                       277 non-null    int64
#  1   Solid Waste program funded by annual fee?                                                         277 non-null    int64
#  2   Solid Waste program funded by transfer station access fee?                                        277 non-null    int64
#  3   Solid Waste program funded by per-visit fee?                                                      277 non-null    int64
#  4   Solid Waste program funded by PAYT/ SMART revenue?                                                277 non-null    int64
#  5   What is the annual fee?                                                                           277 non-null    float64
#  6   What is the transfer station access fee?                                                          277 non-null    float64
#  7   What is the per-visit fee?                                                                        277 non-null    float64
#  8   PAYT/ SMART                                                                                       277 non-null    int64
#  9   Municipal Buildings Trash and Recycling Service                                                   277 non-null    object
#  10  School Trash and Recycling Service                                                                277 non-null    object
#  11  Business Trash and Recycling Service                                                              277 non-null    object
#  12  Non-resident Trash and Recycling Service                                                          277 non-null    object
#  13  Households Served by Municipal Trash Program                                                      277 non-null    float64
#  14  Trash Service Type                                                                                277 non-null    object
#  15  Carts for Trash                                                                                   277 non-null    int64
#  16  Does trash disposal tonnage include bulky waste?                                                  277 non-null    object
#  17  Fee for bulky waste?                                                                              277 non-null    int64
#  18  Annual Bulky
# Waste
# Limit                                                                        277 non-null    float64
#  19  Tip Fee as of 1/1/2020                                                                            277 non-null    float64
#  20  Enforced Trash Limits at Curb                                                                     277 non-null    int64
#  21  Maximum # bags/ barrels per week                                                                  277 non-null    float64
#  22  Trash Enforced by Muni                                                                            277 non-null    int64
#  23  Trash Enforced by Hauler                                                                          277 non-null    int64
#  24  Dedicated Trash Enforcement Personnel                                                             277 non-null    int64
#  25  Households Served by Municipal Recycling Program                                                  277 non-null    float64
#  26  Recycling Service Type                                                                            277 non-null    object
#  27  SS Recycling                                                                                      277 non-null    int64
#  28  Carts for Recycling                                                                               277 non-null    int64
#  29  Enforced Mandatory Recycling                                                                      277 non-null    int64
#  30  Applies to Residential Generators Eligible to be Served by Municipal Program                      277 non-null    int64
#  31  Applies to Residential Generators not Eligible to be Served by the Municipal Program              277 non-null    int64
#  32  Applies to Commercial Generators                                                                  277 non-null    int64
#  33  Recycling Enforced by Muni                                                                        277 non-null    int64
#  34  Recycling Enforced by Hauler                                                                      277 non-null    int64
#  35  Dedicated Mandatory Recycling Enforcement Personnel                                               277 non-null    int64
#  36  # Hours Enforcement Personnel on Street                                                           277 non-null    float64
#  37  Private Hauler regulations that require recycling                                                 277 non-null    int64
#  38  Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program      277 non-null    int64
#  39  Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program  277 non-null    int64
#  40  Applies to Commercial Generators.1                                                                277 non-null    int64
#  41  %recycle/hh                                                                                       271 non-null    float64
#  42  total_waste/hh                                                                                    271 non-null    float64
#  43  Recycling Collection Frequency_Bi-weekly                                                          277 non-null    uint8
#  44  Recycling Collection Frequency_Weekly                                                             277 non-null    uint8
#  45  Trash Bin Size Ranking                                                                            277 non-null    float64
#  46  Recycle Bin Size Ranking                                                                          277 non-null    float64
# dtypes: float64(13), int64(25), object(7), uint8(2)
# memory usage: 110.1+ KB

# %%
# for the last missing values, I'm just going to drop those columns because I was missing the trash data in the original dataset

df_for_regression.dropna(inplace=True)

# %%
# fixing some annoying formatting
df_for_regression.rename(columns=dict(zip(df_for_regression.columns, df_for_regression.columns.str.replace('\n',''))), inplace=True)

# %%
df_for_regression.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 271 entries, Abington to Yarmouth
# Data columns (total 47 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   Solid Waste program funded by property tax?                                                       271 non-null    int64
#  1   Solid Waste program funded by annual fee?                                                         271 non-null    int64
#  2   Solid Waste program funded by transfer station access fee?                                        271 non-null    int64
#  3   Solid Waste program funded by per-visit fee?                                                      271 non-null    int64
#  4   Solid Waste program funded by PAYT/ SMART revenue?                                                271 non-null    int64
#  5   What is the annual fee?                                                                           271 non-null    float64
#  6   What is the transfer station access fee?                                                          271 non-null    float64
#  7   What is the per-visit fee?                                                                        271 non-null    float64
#  8   PAYT/ SMART                                                                                       271 non-null    int64
#  9   Municipal Buildings Trash and Recycling Service                                                   271 non-null    object
#  10  School Trash and Recycling Service                                                                271 non-null    object
#  11  Business Trash and Recycling Service                                                              271 non-null    object
#  12  Non-resident Trash and Recycling Service                                                          271 non-null    object
#  13  Households Served by Municipal Trash Program                                                      271 non-null    float64
#  14  Trash Service Type                                                                                271 non-null    object
#  15  Carts for Trash                                                                                   271 non-null    int64
#  16  Does trash disposal tonnage include bulky waste?                                                  271 non-null    object
#  17  Fee for bulky waste?                                                                              271 non-null    int64
#  18  Annual Bulky Waste Limit                                                                          271 non-null    float64
#  19  Tip Fee as of 1/1/2020                                                                            271 non-null    float64
#  20  Enforced Trash Limits at Curb                                                                     271 non-null    int64
#  21  Maximum # bags/ barrels per week                                                                  271 non-null    float64
#  22  Trash Enforced by Muni                                                                            271 non-null    int64
#  23  Trash Enforced by Hauler                                                                          271 non-null    int64
#  24  Dedicated Trash Enforcement Personnel                                                             271 non-null    int64
#  25  Households Served by Municipal Recycling Program                                                  271 non-null    float64
#  26  Recycling Service Type                                                                            271 non-null    object
#  27  SS Recycling                                                                                      271 non-null    int64
#  28  Carts for Recycling                                                                               271 non-null    int64
#  29  Enforced Mandatory Recycling                                                                      271 non-null    int64
#  30  Applies to Residential Generators Eligible to be Served by Municipal Program                      271 non-null    int64
#  31  Applies to Residential Generators not Eligible to be Served by the Municipal Program              271 non-null    int64
#  32  Applies to Commercial Generators                                                                  271 non-null    int64
#  33  Recycling Enforced by Muni                                                                        271 non-null    int64
#  34  Recycling Enforced by Hauler                                                                      271 non-null    int64
#  35  Dedicated Mandatory Recycling Enforcement Personnel                                               271 non-null    int64
#  36  # Hours Enforcement Personnel on Street                                                           271 non-null    float64
#  37  Private Hauler regulations that require recycling                                                 271 non-null    int64
#  38  Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program      271 non-null    int64
#  39  Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program  271 non-null    int64
#  40  Applies to Commercial Generators.1                                                                271 non-null    int64
#  41  %recycle/hh                                                                                       271 non-null    float64
#  42  total_waste/hh                                                                                    271 non-null    float64
#  43  Recycling Collection Frequency_Bi-weekly                                                          271 non-null    uint8
#  44  Recycling Collection Frequency_Weekly                                                             271 non-null    uint8
#  45  Trash Bin Size Ranking                                                                            271 non-null    float64
#  46  Recycle Bin Size Ranking                                                                          271 non-null    float64
# dtypes: float64(13), int64(25), object(7), uint8(2)
# memory usage: 97.9+ KB

# %% [markdown]
# #### Encoding to make all features numeric

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df_for_regression['Does trash disposal tonnage include bulky waste?'] = le.fit_transform(df_for_regression['Does trash disposal tonnage include bulky waste?'])

# %%
from category_encoders import OneHotEncoder

# %%
ohe = OneHotEncoder(use_cat_names=True)
df_for_regression = ohe.fit_transform(df_for_regression)

# %%
ohe.get_feature_names
# Out:
# <bound method OneHotEncoder.get_feature_names of OneHotEncoder(cols=['Municipal Buildings Trash and Recycling Service',
#                     'School Trash and Recycling Service',
#                     'Business Trash and Recycling Service',
#                     'Non-resident Trash and Recycling Service',
#                     'Trash Service Type', 'Recycling Service Type'],
#               use_cat_names=True)>

# %%
df_for_regression = df_for_regression.drop(columns=['Municipal Buildings Trash and Recycling Service_Neither', 'School Trash and Recycling Service_Neither', 'Business Trash and Recycling Service_Neither',
                               'Non-resident Trash and Recycling Service_Neither', 'Trash Service Type_Drop-off', 'Recycling Service Type_Drop-off'])

# %%
df_for_regression.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 271 entries, Abington to Yarmouth
# Data columns (total 55 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   Solid Waste program funded by property tax?                                                       271 non-null    int64
#  1   Solid Waste program funded by annual fee?                                                         271 non-null    int64
#  2   Solid Waste program funded by transfer station access fee?                                        271 non-null    int64
#  3   Solid Waste program funded by per-visit fee?                                                      271 non-null    int64
#  4   Solid Waste program funded by PAYT/ SMART revenue?                                                271 non-null    int64
#  5   What is the annual fee?                                                                           271 non-null    float64
#  6   What is the transfer station access fee?                                                          271 non-null    float64
#  7   What is the per-visit fee?                                                                        271 non-null    float64
#  8   PAYT/ SMART                                                                                       271 non-null    int64
#  9   Municipal Buildings Trash and Recycling Service_Both                                              271 non-null    int64
#  10  Municipal Buildings Trash and Recycling Service_Recycling                                         271 non-null    int64
#  11  Municipal Buildings Trash and Recycling Service_Trash                                             271 non-null    int64
#  12  School Trash and Recycling Service_Both                                                           271 non-null    int64
#  13  School Trash and Recycling Service_Recycling                                                      271 non-null    int64
#  14  Business Trash and Recycling Service_Recycling                                                    271 non-null    int64
#  15  Business Trash and Recycling Service_Both                                                         271 non-null    int64
#  16  Non-resident Trash and Recycling Service_Both                                                     271 non-null    int64
#  17  Non-resident Trash and Recycling Service_Recycling                                                271 non-null    int64
#  18  Non-resident Trash and Recycling Service_Trash                                                    271 non-null    int64
#  19  Households Served by Municipal Trash Program                                                      271 non-null    float64
#  20  Trash Service Type_Curbside                                                                       271 non-null    int64
#  21  Trash Service Type_Both                                                                           271 non-null    int64
#  22  Carts for Trash                                                                                   271 non-null    int64
#  23  Does trash disposal tonnage include bulky waste?                                                  271 non-null    int32
#  24  Fee for bulky waste?                                                                              271 non-null    int64
#  25  Annual Bulky Waste Limit                                                                          271 non-null    float64
#  26  Tip Fee as of 1/1/2020                                                                            271 non-null    float64
#  27  Enforced Trash Limits at Curb                                                                     271 non-null    int64
#  28  Maximum # bags/ barrels per week                                                                  271 non-null    float64
#  29  Trash Enforced by Muni                                                                            271 non-null    int64
#  30  Trash Enforced by Hauler                                                                          271 non-null    int64
#  31  Dedicated Trash Enforcement Personnel                                                             271 non-null    int64
#  32  Households Served by Municipal Recycling Program                                                  271 non-null    float64
#  33  Recycling Service Type_Curbside                                                                   271 non-null    int64
#  34  Recycling Service Type_Both                                                                       271 non-null    int64
#  35  SS Recycling                                                                                      271 non-null    int64
#  36  Carts for Recycling                                                                               271 non-null    int64
#  37  Enforced Mandatory Recycling                                                                      271 non-null    int64
#  38  Applies to Residential Generators Eligible to be Served by Municipal Program                      271 non-null    int64
#  39  Applies to Residential Generators not Eligible to be Served by the Municipal Program              271 non-null    int64
#  40  Applies to Commercial Generators                                                                  271 non-null    int64
#  41  Recycling Enforced by Muni                                                                        271 non-null    int64
#  42  Recycling Enforced by Hauler                                                                      271 non-null    int64
#  43  Dedicated Mandatory Recycling Enforcement Personnel                                               271 non-null    int64
#  44  # Hours Enforcement Personnel on Street                                                           271 non-null    float64
#  45  Private Hauler regulations that require recycling                                                 271 non-null    int64
#  46  Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program      271 non-null    int64
#  47  Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program  271 non-null    int64
#  48  Applies to Commercial Generators.1                                                                271 non-null    int64
#  49  %recycle/hh                                                                                       271 non-null    float64
#  50  total_waste/hh                                                                                    271 non-null    float64
#  51  Recycling Collection Frequency_Bi-weekly                                                          271 non-null    uint8
#  52  Recycling Collection Frequency_Weekly                                                             271 non-null    uint8
#  53  Trash Bin Size Ranking                                                                            271 non-null    float64
#  54  Recycle Bin Size Ranking                                                                          271 non-null    float64
# dtypes: float64(13), int32(1), int64(39), uint8(2)
# memory usage: 113.8+ KB

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Removing highly correlated data

# %% [markdown]
# First off, I don't need `total_waste/hh` because this is a cluster feature (used in notebooke Part 2), rather than a regression prediction feature. So I will remove this.

# %%
df_for_regression.drop(columns='total_waste/hh', inplace = True)

# %% [markdown]
# I want to look at the correlations for the data to be used for regression. I know some of the information will be _highly_ correlated (like over 0.75) and I will probably want to remove these. But there are 55 features so jumping straight into a heat map may not be super helpful. Instead, I'll make a matrix of the correlations for different subcategories found in the original survey. These subcategories often had a "primary question" and then bunch of follow up questions if the survery-answerer marked yes to the primary question. This is leading to a lot of highly correlated features. After assessing each subcategory, I'll look at the full matrix of remaining features. I will apply a style to these matrices to identify any correlations above 0.75.

# %%
# colors "true" values to make the table more readable
def color_val_red(val):
    color = 'red' if abs(val) > 0.75 and val < 1 else 'black'
    return 'color: {}'.format(color)

# %%
# Program Funding Mechanism  
df_for_regression[['Solid Waste program funded by property tax?',
       'Solid Waste program funded by annual fee?',
       'Solid Waste program funded by transfer station access fee?',
       'Solid Waste program funded by per-visit fee?',
       'Solid Waste program funded by PAYT/ SMART revenue?',
       'What is the annual fee?', 'What is the transfer station access fee?',
       'What is the per-visit fee?']].corr().style.applymap(color_val_red)
# Out:
# <style  type="text/css" >
#     #T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col0 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col1 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col2 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col3 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col4 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col5 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col6 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col7 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row1_col0 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row1_col1 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row1_col2 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row1_col3 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row1_col4 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row1_col5 {
#             color:  red;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row1_col6 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row1_col7 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row2_col0 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row2_col1 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row2_col2 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row2_col3 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row2_col4 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row2_col5 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row2_col6 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row2_col7 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row3_col0 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row3_col1 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row3_col2 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row3_col3 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row3_col4 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row3_col5 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row3_col6 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row3_col7 {
#             color:  red;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row4_col0 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row4_col1 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row4_col2 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row4_col3 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row4_col4 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row4_col5 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row4_col6 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row4_col7 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row5_col0 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row5_col1 {
#             color:  red;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row5_col2 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row5_col3 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row5_col4 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row5_col5 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row5_col6 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row5_col7 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row6_col0 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row6_col1 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row6_col2 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row6_col3 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row6_col4 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row6_col5 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row6_col6 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row6_col7 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row7_col0 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row7_col1 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row7_col2 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row7_col3 {
#             color:  red;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row7_col4 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row7_col5 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row7_col6 {
#             color:  black;
#         }    #T_c4824527_70b8_11eb_847d_5cf3709e0882row7_col7 {
#             color:  black;
#         }</style><table id="T_c4824527_70b8_11eb_847d_5cf3709e0882" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Solid Waste program funded by property tax?</th>        <th class="col_heading level0 col1" >Solid Waste program funded by annual fee?</th>        <th class="col_heading level0 col2" >Solid Waste program funded by transfer station access fee?</th>        <th class="col_heading level0 col3" >Solid Waste program funded by per-visit fee?</th>        <th class="col_heading level0 col4" >Solid Waste program funded by PAYT/ SMART revenue?</th>        <th class="col_heading level0 col5" >What is the annual fee?</th>        <th class="col_heading level0 col6" >What is the transfer station access fee?</th>        <th class="col_heading level0 col7" >What is the per-visit fee?</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c4824527_70b8_11eb_847d_5cf3709e0882level0_row0" class="row_heading level0 row0" >Solid Waste program funded by property tax?</th>
#                         <td id="T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col1" class="data row0 col1" >-0.368231</td>
#                         <td id="T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col2" class="data row0 col2" >-0.173991</td>
#                         <td id="T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col3" class="data row0 col3" >-0.144251</td>
#                         <td id="T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col4" class="data row0 col4" >-0.153305</td>
#                         <td id="T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col5" class="data row0 col5" >-0.437962</td>
#                         <td id="T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col6" class="data row0 col6" >-0.249015</td>
#                         <td id="T_c4824527_70b8_11eb_847d_5cf3709e0882row0_col7" class="data row0 col7" >-0.180522</td>
#             </tr>
#             <tr>
#                         <th id="T_c4824527_70b8_11eb_847d_5cf3709e0882level0_row1" class="row_heading level0 row1"

# %% [markdown]
# remove `Solid Waste program funded by annual fee?` as this is redundant with `What is the annual fee?`.
#
# remove `Solid Waste program funded by per-visit fee?` as this is redundant with `What is the per-visit fee?`.

# %%
df_for_regression.drop(columns=['Solid Waste program funded by annual fee?', 'Solid Waste program funded by per-visit fee?', 'Solid Waste program funded by PAYT/ SMART revenue?'], inplace=True)

# %%
# for some reason, these two municipalities said they're funded by PAYT/SMART but they did not respond to the `PAYT/ SMART` question so I'll manually enter it for them
df_for_regression.at[['Shirley', 'Middleborough'],['PAYT/ SMART']] = 1

# %%
# Trash Limits

df_for_regression[['Enforced Trash Limits at Curb',
       'Maximum # bags/ barrels per week', 'Trash Enforced by Muni',
       'Trash Enforced by Hauler', 'Dedicated Trash Enforcement Personnel', 'Trash Bin Size Ranking']].corr().style.applymap(color_val_red)
# Out:
# <style  type="text/css" >
#     #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row0_col0 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row0_col1 {
#             color:  red;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row0_col2 {
#             color:  red;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row0_col3 {
#             color:  red;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row0_col4 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row0_col5 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row1_col0 {
#             color:  red;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row1_col1 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row1_col2 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row1_col3 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row1_col4 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row1_col5 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row2_col0 {
#             color:  red;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row2_col1 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row2_col2 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row2_col3 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row2_col4 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row2_col5 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row3_col0 {
#             color:  red;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row3_col1 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row3_col2 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row3_col3 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row3_col4 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row3_col5 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row4_col0 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row4_col1 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row4_col2 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row4_col3 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row4_col4 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row4_col5 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row5_col0 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row5_col1 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row5_col2 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row5_col3 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row5_col4 {
#             color:  black;
#         }    #T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row5_col5 {
#             color:  black;
#         }</style><table id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Enforced Trash Limits at Curb</th>        <th class="col_heading level0 col1" >Maximum # bags/ barrels per week</th>        <th class="col_heading level0 col2" >Trash Enforced by Muni</th>        <th class="col_heading level0 col3" >Trash Enforced by Hauler</th>        <th class="col_heading level0 col4" >Dedicated Trash Enforcement Personnel</th>        <th class="col_heading level0 col5" >Trash Bin Size Ranking</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882level0_row0" class="row_heading level0 row0" >Enforced Trash Limits at Curb</th>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row0_col1" class="data row0 col1" >0.793255</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row0_col2" class="data row0 col2" >0.755590</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row0_col3" class="data row0 col3" >0.809635</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row0_col4" class="data row0 col4" >0.411520</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row0_col5" class="data row0 col5" >0.041874</td>
#             </tr>
#             <tr>
#                         <th id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882level0_row1" class="row_heading level0 row1" >Maximum # bags/ barrels per week</th>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row1_col0" class="data row1 col0" >0.793255</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row1_col2" class="data row1 col2" >0.451582</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row1_col3" class="data row1 col3" >0.664328</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row1_col4" class="data row1 col4" >0.188020</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row1_col5" class="data row1 col5" >-0.021528</td>
#             </tr>
#             <tr>
#                         <th id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882level0_row2" class="row_heading level0 row2" >Trash Enforced by Muni</th>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row2_col0" class="data row2 col0" >0.755590</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row2_col1" class="data row2 col1" >0.451582</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row2_col3" class="data row2 col3" >0.622123</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row2_col4" class="data row2 col4" >0.544634</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row2_col5" class="data row2 col5" >0.040247</td>
#             </tr>
#             <tr>
#                         <th id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882level0_row3" class="row_heading level0 row3" >Trash Enforced by Hauler</th>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row3_col0" class="data row3 col0" >0.809635</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row3_col1" class="data row3 col1" >0.664328</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row3_col2" class="data row3 col2" >0.622123</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row3_col4" class="data row3 col4" >0.274815</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row3_col5" class="data row3 col5" >0.027197</td>
#             </tr>
#             <tr>
#                         <th id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882level0_row4" class="row_heading level0 row4" >Dedicated Trash Enforcement Personnel</th>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row4_col0" class="data row4 col0" >0.411520</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row4_col1" class="data row4 col1" >0.188020</td>
#                         <td id="T_c48d68a0_70b8_11eb_bc3f_5cf3709e0882row4_col2" class="data ro

# %% [markdown]
# `Enforced Trash Limits at Curb` needs to go. It's a primary question and the other questions are follow ups. So anyone who doesn't enforce,  all the other cateories will be 0.

# %%
df_for_regression.drop(columns=['Enforced Trash Limits at Curb'], inplace=True)

# %%
# Mandatory Recycling

df_for_regression[['Enforced Mandatory Recycling',
       'Applies to Residential Generators Eligible to be Served by Municipal Program',
       'Applies to Residential Generators not Eligible to be Served by the Municipal Program',
       'Applies to Commercial Generators', 'Recycling Enforced by Muni',
       'Recycling Enforced by Hauler',
       'Dedicated Mandatory Recycling Enforcement Personnel',
       '# Hours Enforcement Personnel on Street']].corr().style.applymap(color_val_red)
# Out:
# <style  type="text/css" >
#     #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col0 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col1 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col2 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col3 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col4 {
#             color:  red;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col5 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col6 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col7 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row1_col0 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row1_col1 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row1_col2 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row1_col3 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row1_col4 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row1_col5 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row1_col6 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row1_col7 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row2_col0 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row2_col1 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row2_col2 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row2_col3 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row2_col4 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row2_col5 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row2_col6 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row2_col7 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row3_col0 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row3_col1 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row3_col2 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row3_col3 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row3_col4 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row3_col5 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row3_col6 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row3_col7 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row4_col0 {
#             color:  red;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row4_col1 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row4_col2 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row4_col3 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row4_col4 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row4_col5 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row4_col6 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row4_col7 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row5_col0 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row5_col1 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row5_col2 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row5_col3 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row5_col4 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row5_col5 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row5_col6 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row5_col7 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row6_col0 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row6_col1 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row6_col2 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row6_col3 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row6_col4 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row6_col5 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row6_col6 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row6_col7 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row7_col0 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row7_col1 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row7_col2 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row7_col3 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row7_col4 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row7_col5 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row7_col6 {
#             color:  black;
#         }    #T_c494bbab_70b8_11eb_82c5_5cf3709e0882row7_col7 {
#             color:  black;
#         }</style><table id="T_c494bbab_70b8_11eb_82c5_5cf3709e0882" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Enforced Mandatory Recycling</th>        <th class="col_heading level0 col1" >Applies to Residential Generators Eligible to be Served by Municipal Program</th>        <th class="col_heading level0 col2" >Applies to Residential Generators not Eligible to be Served by the Municipal Program</th>        <th class="col_heading level0 col3" >Applies to Commercial Generators</th>        <th class="col_heading level0 col4" >Recycling Enforced by Muni</th>        <th class="col_heading level0 col5" >Recycling Enforced by Hauler</th>        <th class="col_heading level0 col6" >Dedicated Mandatory Recycling Enforcement Personnel</th>        <th class="col_heading level0 col7" ># Hours Enforcement Personnel on Street</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c494bbab_70b8_11eb_82c5_5cf3709e0882level0_row0" class="row_heading level0 row0" >Enforced Mandatory Recycling</th>
#                         <td id="T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col1" class="data row0 col1" >0.698249</td>
#                         <td id="T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col2" class="data row0 col2" >0.267236</td>
#                         <td id="T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col3" class="data row0 col3" >0.488373</td>
#                         <td id="T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col4" class="data row0 col4" >0.878021</td>
#                         <td id="T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col5" class="data row0 col5" >0.589756</td>
#                         <td id="T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col6" class="data row0 col6" >0.420840</td>
#                         <td id="T_c494bbab_70b8_11eb_82c5_5cf3709e0882row0_col7" class="data row0 col7" >0.300477</td>
#             </tr>
#             <tr>
#                         <th id="T_c494bbab_70b8_11eb_82c5_5cf3709e0882level0_row1" class="row

# %% [markdown]
# Remove `Enforced Mandatory Recycling` as this is the primary question and everything else is follow-up.

# %%
df_for_regression.drop(columns=['Enforced Mandatory Recycling'], inplace=True)

# %%
df_for_regression.columns
# Out:
# Index(['Solid Waste program funded by property tax?',
#        'Solid Waste program funded by transfer station access fee?',
#        'What is the annual fee?', 'What is the transfer station access fee?',
#        'What is the per-visit fee?', 'PAYT/ SMART',
#        'Municipal Buildings Trash and Recycling Service_Both',
#        'Municipal Buildings Trash and Recycling Service_Recycling',
#        'Municipal Buildings Trash and Recycling Service_Trash',
#        'School Trash and Recycling Service_Both',
#        'School Trash and Recycling Service_Recycling',
#        'Business Trash and Recycling Service_Recycling',
#        'Business Trash and Recycling Service_Both',
#        'Non-resident Trash and Recycling Service_Both',
#        'Non-resident Trash and Recycling Service_Recycling',
#        'Non-resident Trash and Recycling Service_Trash',
#        'Households Served by Municipal Trash Program',
#        'Trash Service Type_Curbside', 'Trash Service Type_Both',
#        'Carts for Trash', 'Does trash disposal tonnage include bulky waste?',
#        'Fee for bulky waste?', 'Annual Bulky Waste Limit',
#        'Tip Fee as of 1/1/2020', 'Maximum # bags/ barrels per week',
#        'Trash Enforced by Muni', 'Trash Enforced by Hauler',
#        'Dedicated Trash Enforcement Personnel',
#        'Households Served by Municipal Recycling Program',
#        'Recycling Service Type_Curbside', 'Recycling Service Type_Both',
#        'SS Recycling', 'Carts for Recycling',
#        'Applies to Residential Generators Eligible to be Served by Municipal Program',
#        'Applies to Residential Generators not Eligible to be Served by the Municipal Program',
#        'Applies to Commercial Generators', 'Recycling Enforced by Muni',
#        'Recycling Enforced by Hauler',
#        'Dedicated Mandatory Recycling Enforcement Personnel',
#        '# Hours Enforcement Personnel on Street',
#        'Private Hauler regulations that require recycling',
#        'Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
#        'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program',
#        'Applies to Commercial Generators.1', '%recycle/hh',
#        'Recycling Collection Frequency_Bi-weekly',
#        'Recycling Collection Frequency_Weekly', 'Trash Bin Size Ranking',
#        'Recycle Bin Size Ranking'],
#       dtype='object')

# %%
# Private Hauler Regulations  

df_for_regression[['Private Hauler regulations that require recycling',
       'Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
       'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program',
       'Applies to Commercial Generators.1']].corr().style.applymap(color_val_red)
# Out:
# <style  type="text/css" >
#     #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row0_col0 {
#             color:  black;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row0_col1 {
#             color:  red;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row0_col2 {
#             color:  red;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row0_col3 {
#             color:  red;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row1_col0 {
#             color:  red;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row1_col1 {
#             color:  black;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row1_col2 {
#             color:  red;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row1_col3 {
#             color:  red;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row2_col0 {
#             color:  red;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row2_col1 {
#             color:  red;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row2_col2 {
#             color:  black;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row2_col3 {
#             color:  red;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row3_col0 {
#             color:  red;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row3_col1 {
#             color:  red;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row3_col2 {
#             color:  red;
#         }    #T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row3_col3 {
#             color:  black;
#         }</style><table id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Private Hauler regulations that require recycling</th>        <th class="col_heading level0 col1" >Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program</th>        <th class="col_heading level0 col2" >Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program</th>        <th class="col_heading level0 col3" >Applies to Commercial Generators.1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882level0_row0" class="row_heading level0 row0" >Private Hauler regulations that require recycling</th>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row0_col1" class="data row0 col1" >0.902629</td>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row0_col2" class="data row0 col2" >0.863387</td>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row0_col3" class="data row0 col3" >0.823806</td>
#             </tr>
#             <tr>
#                         <th id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882level0_row1" class="row_heading level0 row1" >Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program</th>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row1_col0" class="data row1 col0" >0.902629</td>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row1_col2" class="data row1 col2" >0.778674</td>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row1_col3" class="data row1 col3" >0.752542</td>
#             </tr>
#             <tr>
#                         <th id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882level0_row2" class="row_heading level0 row2" >Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program</th>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row2_col0" class="data row2 col0" >0.863387</td>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row2_col1" class="data row2 col1" >0.778674</td>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row2_col3" class="data row2 col3" >0.813319</td>
#             </tr>
#             <tr>
#                         <th id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882level0_row3" class="row_heading level0 row3" >Applies to Commercial Generators.1</th>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row3_col0" class="data row3 col0" >0.823806</td>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row3_col1" class="data row3 col1" >0.752542</td>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row3_col2" class="data row3 col2" >0.813319</td>
#                         <td id="T_c49c35c0_70b8_11eb_8f51_5cf3709e0882row3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# This one is a bit trickier because they're all correlated. It seems like in this case I'm going to want to remove all the follow-up questions: `'Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
#        'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program',
#        'Applies to Commercial Generators.1'`

# %%
df_for_regression.drop(columns=['Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
       'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program',
       'Applies to Commercial Generators.1'], inplace=True)

# %%
# Now the whole table

dfcorr= df_for_regression.corr()

# %%
# dfcorr = dfcorr[abs(dfcorr['%recycle/hh']) >= 0.1]

# %%
mask = ((dfcorr>0.75) & (dfcorr<1)).any(axis=0)

# %%
dfcorr[mask].T.style.applymap(color_val_red)
# Out:
# <style  type="text/css" >
#     #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row0_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row0_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row0_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row0_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row1_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row1_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row1_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row1_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row2_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row2_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row2_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row2_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row3_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row3_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row3_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row3_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row4_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row4_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row4_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row4_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row5_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row5_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row5_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row5_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row6_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row6_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row6_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row6_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row7_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row7_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row7_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row7_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row8_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row8_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row8_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row8_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row9_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row9_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row9_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row9_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row10_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row10_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row10_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row10_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row11_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row11_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row11_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row11_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row12_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row12_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row12_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row12_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row13_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row13_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row13_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row13_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row14_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row14_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row14_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row14_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row15_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row15_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row15_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row15_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row16_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row16_col1 {
#             color:  red;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row16_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row16_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row17_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row17_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row17_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row17_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row18_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row18_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row18_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row18_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row19_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row19_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row19_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row19_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row20_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row20_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row20_col2 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row20_col3 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row21_col0 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row21_col1 {
#             color:  black;
#         }    #T_c4b16b5a_70b8_11eb_ab62_5cf3709e0882row21_col2 {
#             color:  black;
#         }    #T_c4b16

# %% [markdown]
# `Households Served by Municipal Trash Program` and `Households Served by Municipal Recycling Program` are correlated. I think I feel ok removing both these columns because this is similar to, or will scale linearly with population. Population isn't in this table but it is in the "cluster" data. However, I would need something like this for the baseline regression... okay, I'll keep one, let's go with `Households Served by Municipal Recycling Program` since this whole analysis is about recycling. Maybe I'll run two regressions, with and without this feature, just to see how it does.
#
# `Trash Bin Size Ranking` and `Recycle Bin Size Ranking` are correlated. This is tricky because I'm interested in both of these features. However, a lot of the time, if a municipality as a big trash can, they have a big recycling can and vice versa. I supposed what I could do is keep the `Recycle Bin Size Ranking` as is, since this is a recycling study, but make a new feature--like a manually engineered polynomial in a way--of the ratio of `recycle bin rank:trash bin rank` and I can see how that faires in the correlation matrix.

# %%
df_for_regression['recycle bin rank:trash bin rank'] = df_for_regression['Recycle Bin Size Ranking'].div(df_for_regression['Trash Bin Size Ranking'])

# %%
df_for_regression[['Trash Bin Size Ranking', 'Recycle Bin Size Ranking', 'recycle bin rank:trash bin rank']][df_for_regression['recycle bin rank:trash bin rank'].isna()].sort_values(by='Trash Bin Size Ranking')
# Out:
#                    Trash Bin Size Ranking  Recycle Bin Size Ranking  \
# Municipality Name
# Acton                                 0.0                       0.0
# Sandwich                              0.0                       0.0
# Russell                               0.0                       0.0
# Royalston                             0.0                       0.0
# Rowe                                  0.0                       0.0
# ...                                   ...                       ...
# Douglas                               0.0                       0.0
# Dennis                                0.0                       0.0
# Deerfield                             0.0                       0.0
# Medfield                              0.0                       0.0
# Yarmouth                              0.0                       0.0
#
#                    recycle bin rank:trash bin rank
# Municipality Name
# Acton                                          NaN
# Sandwich                                       NaN
# Russell                                        NaN
# Royalston                                      NaN
# Rowe                                           NaN
# ...                                            ...
# Douglas                                        NaN
# Dennis                                         NaN
# Deerfield                                      NaN
# Medfield                                       NaN
# Yarmouth                                       NaN
#
# [129 rows x 3 columns]

# %%
# looks like we got some NaNs where the rank was 0 for both categories.
df_for_regression['recycle bin rank:trash bin rank'] = df_for_regression['recycle bin rank:trash bin rank'].fillna(0)

# %%
df_for_regression[['Trash Bin Size Ranking', 'Recycle Bin Size Ranking', 'recycle bin rank:trash bin rank']][df_for_regression['recycle bin rank:trash bin rank'].isna()]
# Out:
# Empty DataFrame
# Columns: [Trash Bin Size Ranking, Recycle Bin Size Ranking, recycle bin rank:trash bin rank]
# Index: []

# %%
# checking the new column

df_for_regression[['Trash Bin Size Ranking', 'Recycle Bin Size Ranking', 'recycle bin rank:trash bin rank']].corr().style.applymap(color_val_red)
# Out:
# <style  type="text/css" >
#     #T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row0_col0 {
#             color:  black;
#         }    #T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row0_col1 {
#             color:  red;
#         }    #T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row0_col2 {
#             color:  black;
#         }    #T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row1_col0 {
#             color:  red;
#         }    #T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row1_col1 {
#             color:  black;
#         }    #T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row1_col2 {
#             color:  red;
#         }    #T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row2_col0 {
#             color:  black;
#         }    #T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row2_col1 {
#             color:  red;
#         }    #T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row2_col2 {
#             color:  black;
#         }</style><table id="T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Trash Bin Size Ranking</th>        <th class="col_heading level0 col1" >Recycle Bin Size Ranking</th>        <th class="col_heading level0 col2" >recycle bin rank:trash bin rank</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882level0_row0" class="row_heading level0 row0" >Trash Bin Size Ranking</th>
#                         <td id="T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row0_col1" class="data row0 col1" >0.823893</td>
#                         <td id="T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row0_col2" class="data row0 col2" >0.351215</td>
#             </tr>
#             <tr>
#                         <th id="T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882level0_row1" class="row_heading level0 row1" >Recycle Bin Size Ranking</th>
#                         <td id="T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row1_col0" class="data row1 col0" >0.823893</td>
#                         <td id="T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row1_col2" class="data row1 col2" >0.761509</td>
#             </tr>
#             <tr>
#                         <th id="T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882level0_row2" class="row_heading level0 row2" >recycle bin rank:trash bin rank</th>
#                         <td id="T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row2_col0" class="data row2 col0" >0.351215</td>
#                         <td id="T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row2_col1" class="data row2 col1" >0.761509</td>
#                         <td id="T_c4c0d4cc_70b8_11eb_9719_5cf3709e0882row2_col2" class="data row2 col2" >1.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# No, the new column is still _too_ strongly correlate (>0.75) with recycle bin ranking so I must remove `Trash Bin Size Ranking` and my new feature to remove any high correlations. I'll also the `Households Served by Municipal Trash Program` feature mentioned above.

# %%
df_for_regression.drop(columns=['Trash Bin Size Ranking', 'recycle bin rank:trash bin rank', 'Households Served by Municipal Trash Program'], inplace=True)

# %%
# Remaking the correlation matrix

dfcorr= df_for_regression.corr()

# %%
mask = ((dfcorr>0.75) & (dfcorr<1)).any(axis=0)

# %%
dfcorr[mask].T.style.applymap(color_val_red)
# Out:
# <style  type="text/css" >
# </style><table id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882" ><thead></thead><tbody>
#                 <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row0" class="row_heading level0 row0" >Solid Waste program funded by property tax?</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row1" class="row_heading level0 row1" >Solid Waste program funded by transfer station access fee?</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row2" class="row_heading level0 row2" >What is the annual fee?</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row3" class="row_heading level0 row3" >What is the transfer station access fee?</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row4" class="row_heading level0 row4" >What is the per-visit fee?</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row5" class="row_heading level0 row5" >PAYT/ SMART</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row6" class="row_heading level0 row6" >Municipal Buildings Trash and Recycling Service_Both</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row7" class="row_heading level0 row7" >Municipal Buildings Trash and Recycling Service_Recycling</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row8" class="row_heading level0 row8" >Municipal Buildings Trash and Recycling Service_Trash</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row9" class="row_heading level0 row9" >School Trash and Recycling Service_Both</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row10" class="row_heading level0 row10" >School Trash and Recycling Service_Recycling</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row11" class="row_heading level0 row11" >Business Trash and Recycling Service_Recycling</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row12" class="row_heading level0 row12" >Business Trash and Recycling Service_Both</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row13" class="row_heading level0 row13" >Non-resident Trash and Recycling Service_Both</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row14" class="row_heading level0 row14" >Non-resident Trash and Recycling Service_Recycling</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row15" class="row_heading level0 row15" >Non-resident Trash and Recycling Service_Trash</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row16" class="row_heading level0 row16" >Trash Service Type_Curbside</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row17" class="row_heading level0 row17" >Trash Service Type_Both</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row18" class="row_heading level0 row18" >Carts for Trash</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row19" class="row_heading level0 row19" >Does trash disposal tonnage include bulky waste?</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row20" class="row_heading level0 row20" >Fee for bulky waste?</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row21" class="row_heading level0 row21" >Annual Bulky Waste Limit</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row22" class="row_heading level0 row22" >Tip Fee as of 1/1/2020</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row23" class="row_heading level0 row23" >Maximum # bags/ barrels per week</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row24" class="row_heading level0 row24" >Trash Enforced by Muni</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row25" class="row_heading level0 row25" >Trash Enforced by Hauler</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row26" class="row_heading level0 row26" >Dedicated Trash Enforcement Personnel</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row27" class="row_heading level0 row27" >Households Served by Municipal Recycling Program</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row28" class="row_heading level0 row28" >Recycling Service Type_Curbside</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row29" class="row_heading level0 row29" >Recycling Service Type_Both</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row30" class="row_heading level0 row30" >SS Recycling</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row31" class="row_heading level0 row31" >Carts for Recycling</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row32" class="row_heading level0 row32" >Applies to Residential Generators Eligible to be Served by Municipal Program</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row33" class="row_heading level0 row33" >Applies to Residential Generators not Eligible to be Served by the Municipal Program</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row34" class="row_heading level0 row34" >Applies to Commercial Generators</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row35" class="row_heading level0 row35" >Recycling Enforced by Muni</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row36" class="row_heading level0 row36" >Recycling Enforced by Hauler</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row37" class="row_heading level0 row37" >Dedicated Mandatory Recycling Enforcement Personnel</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row38" class="row_heading level0 row38" ># Hours Enforcement Personnel on Street</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce904d_70b8_11eb_b628_5cf3709e0882level0_row39" class="row_heading level0 row39" >Private Hauler regulations that require recycling</th>
#             </tr>
#             <tr>
#                         <th id="T_c4ce90

# %% [markdown]
# Cool, no more correlations above 0.75.

# %%
# # For saving files
# df_for_regression.to_csv('data/data_for_regression.csv', index=True)

# %% [markdown]
# ### Making the Baseline Regression *
#
# I will test out several algorithms and determine which result in models with the best scores. Of the top scoring-models, I will determine the coefficients or feature importances. These will translate to the most important aspects of recycling / waste management services in maximizing recycling across the entire population. The resulting scores may not be high; however, this will give further credance to my theory that there are sub-groups within the population that can be observed independently to come up with a better predictive model, and thus better service suggests for specific municipalities.
#
# \* due to some data abnormalities found in the regression section, I have started a new notebook [part3b.ipynb](part3b.ipynb).

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor, BaggingRegressor, VotingRegressor
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import RFE

# %%
X = df_for_regression.drop(columns=['%recycle/hh'])
y = df_for_regression['%recycle/hh']

# %%
X.columns
# Out:
# Index(['Solid Waste program funded by property tax?',
#        'Solid Waste program funded by transfer station access fee?',
#        'What is the annual fee?', 'What is the transfer station access fee?',
#        'What is the per-visit fee?', 'PAYT/ SMART',
#        'Municipal Buildings Trash and Recycling Service_Both',
#        'Municipal Buildings Trash and Recycling Service_Recycling',
#        'Municipal Buildings Trash and Recycling Service_Trash',
#        'School Trash and Recycling Service_Both',
#        'School Trash and Recycling Service_Recycling',
#        'Business Trash and Recycling Service_Recycling',
#        'Business Trash and Recycling Service_Both',
#        'Non-resident Trash and Recycling Service_Both',
#        'Non-resident Trash and Recycling Service_Recycling',
#        'Non-resident Trash and Recycling Service_Trash',
#        'Trash Service Type_Curbside', 'Trash Service Type_Both',
#        'Carts for Trash', 'Does trash disposal tonnage include bulky waste?',
#        'Fee for bulky waste?', 'Annual Bulky Waste Limit',
#        'Tip Fee as of 1/1/2020', 'Maximum # bags/ barrels per week',
#        'Trash Enforced by Muni', 'Trash Enforced by Hauler',
#        'Dedicated Trash Enforcement Personnel',
#        'Households Served by Municipal Recycling Program',
#        'Recycling Service Type_Curbside', 'Recycling Service Type_Both',
#        'SS Recycling', 'Carts for Recycling',
#        'Applies to Residential Generators Eligible to be Served by Municipal Program',
#        'Applies to Residential Generators not Eligible to be Served by the Municipal Program',
#        'Applies to Commercial Generators', 'Recycling Enforced by Muni',
#        'Recycling Enforced by Hauler',
#        'Dedicated Mandatory Recycling Enforcement Personnel',
#        '# Hours Enforcement Personnel on Street',
#        'Private Hauler regulations that require recycling',
#        'Recycling Collection Frequency_Bi-weekly',
#        'Recycling Collection Frequency_Weekly', 'Recycle Bin Size Ranking'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
fit_results = {}

def fit_model(model, name):
    model.fit(X_train, y_train)
    score = model.score(X_test, y_test)
    rmse = mean_squared_error(y_test, model.predict(X_test), squared=False)
    fit_results[name] = (score, rmse)
    return score

# %%
model0 = DummyRegressor()
fit_model(model0, 'dummy')

# %%
model1 = LinearRegression(n_jobs=-1)
fit_model(model1, 'plain_linreg')
# Out:
# 0.21859654846224486

# %%
model2 = RandomForestRegressor(n_jobs=-1, random_state=123)
fit_model(model2, 'RFR')
# Out:
# 0.13740517005245223

# %%
model3 = HistGradientBoostingRegressor(max_iter=10_000, random_state=123)
fit_model(model3, 'GradBoost')
# Out:
# -0.25126471106226456

# %%
model4 = BaggingRegressor(n_jobs=-1, n_estimators=100, random_state=123)
fit_model(model4, 'bagging')
# Out:
# 0.15359534479323111

# %%
model5 = make_pipeline(StandardScaler(), HistGradientBoostingRegressor(max_iter=10_000, random_state=123))
fit_model(model5, 'GB_w_scaler')
# Out:
# -0.25126471106226456

# %%
model6 = make_pipeline(StandardScaler(),Ridge())
fit_model(model6, 'plain_ridge')
# Out:
# 0.22099629888522287

# %%
model7 = make_pipeline(StandardScaler(),Lasso())
fit_model(model7, 'lasso')
# Out:
# -0.005464464679645564

# %%
params6 = {
    'ridge__alpha':[1,10,100]
}
gs6 = GridSearchCV(model6, params6, n_jobs=-1)
fit_model(gs6, 'gs_on_ridge')
# Out:
# 0.20921888682507017

# %%
params2={
    'n_estimators':[100,1000],
    'max_depth': [25,50]
}

gs2 = GridSearchCV(RandomForestRegressor(random_state=123), params2, n_jobs=-1)
fit_model(gs2, 'gs_on_RFR')
# Out:
# 0.11768490658402153

# %%
pd.DataFrame(gs2.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.279999      0.024883         0.014000    2.279558e-03
# 1       2.444399      0.121693         0.085799    7.195073e-03
# 2       0.236799      0.007781         0.011000    5.519789e-07
# 3       2.018200      0.356314         0.057399    1.076386e-02
#
#   param_max_depth param_n_estimators                                   params  \
# 0              25                100   {'max_depth': 25, 'n_estimators': 100}
# 1              25               1000  {'max_depth': 25, 'n_estimators': 1000}
# 2              50                100   {'max_depth': 50, 'n_estimators': 100}
# 3              50               1000  {'max_depth': 50, 'n_estimators': 1000}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.130418           0.046887          -0.175587          -0.654952
# 1           0.145396           0.071692          -0.116526          -0.574878
# 2           0.118661           0.093043          -0.034194          -0.509845
# 3           0.136908           0.073096          -0.115700          -0.456528
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.143313        -0.101984        0.299177                4
# 1           0.083434        -0.078176        0.263342                3
# 2           0.135378        -0.039391        0.242659                1
# 3           0.132171        -0.046011        0.224844                2

# %% [markdown]
# The irregular outcomes between splits leads me to believe there are "multiple profiles" in one dataset, further supporting my instinct to compare the baseline model against the clustered models.

# %%
model8 = make_pipeline(StandardScaler(), RFE(Ridge()), LinearRegression())
params8 = {
    'rfe__n_features_to_select':[10,20,30]
}
gs8 = GridSearchCV(model8, params8, n_jobs=-1)
fit_model(gs8, 'gs_rfe_ridge_lr')
# Out:
# 0.22862135241911452

# %%
pd.DataFrame(gs8.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.043201      0.007025         0.003001        0.000002
# 1       0.033000      0.004147         0.003198        0.000399
# 2       0.022597      0.004759         0.002799        0.000400
#
#   param_rfe__n_features_to_select                             params  \
# 0                              10  {'rfe__n_features_to_select': 10}
# 1                              20  {'rfe__n_features_to_select': 20}
# 2                              30  {'rfe__n_features_to_select': 30}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0          -0.027404          -1.307755          -0.439416          -0.084713
# 1          -0.065728          -0.874100          -0.593595          -0.293900
# 2          -0.200684          -1.357271          -0.515951          -0.386792
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.107802        -0.350297        0.511726                1
# 1          -0.005166        -0.366498        0.327269                2
# 2          -0.131086        -0.518357        0.440905                3

# %%
model8 = make_pipeline(StandardScaler(), RFE(Ridge(), n_features_to_select=11), LinearRegression())
fit_model(model8, 'rfe_ridge_lr')
# Out:
# 0.2368909310876468

# %%
model9 = make_pipeline(StandardScaler(), RFE(LinearRegression(), n_features_to_select=6), LinearRegression())
fit_model(model9, 'rfe_lr_lr')
# Out:
# 0.21911175946737882

# %%
model10 = make_pipeline(StandardScaler(), LinearRegression())
fit_model(model10, 'lr_scaler')
# Out:
# 0.21859654846299525

# %%
pd.DataFrame(fit_results, index=['score','rmse']).T.sort_values(by='score', ascending=False)
# Out:
#                     score      rmse
# rfe_ridge_lr     0.236891  0.063603
# gs_rfe_ridge_lr  0.228621  0.063946
# plain_ridge      0.220996  0.064262
# rfe_lr_lr        0.219112  0.064339
# lr_scaler        0.218597  0.064361
# plain_linreg     0.218597  0.064361
# gs_on_ridge      0.209219  0.064746
# bagging          0.153595  0.066984
# RFR              0.137405  0.067622
# gs_on_RFR        0.117685  0.068390
# dummy           -0.005464  0.073007
# lasso           -0.005464  0.073007
# GradBoost       -0.251265  0.081444
# GB_w_scaler     -0.251265  0.081444

# %%
vr11 = VotingRegressor([('lr_w_rfe', model8), ('bagging', model4)])
fit_model(vr11, 'vr_bagging_lr_w_rfe_ridge')
# Out:
# 0.24131292985001096

# %%
results = pd.DataFrame(fit_results, index=['Score','RMSE']).T
results.sort_values('Score', ascending = False)
# Out:
#                               Score      RMSE
# vr_bagging_lr_w_rfe_ridge  0.241313  0.063418
# rfe_ridge_lr               0.236891  0.063603
# gs_rfe_ridge_lr            0.228621  0.063946
# plain_ridge                0.220996  0.064262
# rfe_lr_lr                  0.219112  0.064339
# lr_scaler                  0.218597  0.064361
# plain_linreg               0.218597  0.064361
# gs_on_ridge                0.209219  0.064746
# bagging                    0.153595  0.066984
# RFR                        0.137405  0.067622
# gs_on_RFR                  0.117685  0.068390
# dummy                     -0.005464  0.073007
# lasso                     -0.005464  0.073007
# GradBoost                 -0.251265  0.081444
# GB_w_scaler               -0.251265  0.081444

# %%
model8.named_steps
# Out:
# {'standardscaler': StandardScaler(),
#  'rfe': RFE(estimator=Ridge(), n_features_to_select=11),
#  'linearregression': LinearRegression()}

# %%
rfe_lr_lr_coefs = pd.Series(data= model9.named_steps['linearregression'].coef_, index = X.columns[model9.named_steps['rfe'].support_], name= 'rfe_lr_lr')

# %%
rfe_ridge_lr_coefs = pd.Series(data= model8.named_steps['linearregression'].coef_, index = X.columns[model8.named_steps['rfe'].support_], name='rfe_ridge_lr')

# %%
bagging_coefs = np.mean([
    tree.feature_importances_ for tree in model4.estimators_
], axis=0)
# model4.estimators_[0].feature_importances_

# %%
model_coefs = pd.DataFrame(data={'plain_linreg':model1.coef_, 'plain_ridge':model6.named_steps['ridge'].coef_, "bagging":bagging_coefs},index=X.columns)

# %%
model_coefs = model_coefs.merge(rfe_lr_lr_coefs,how = 'left',left_index=True,right_index=True)

# %%
model_coefs = model_coefs.merge(rfe_ridge_lr_coefs,how = 'left',left_index=True,right_index=True)

# %%
model_coefs = model_coefs.fillna(0)

# %%
model_coefs['vr_bag_w_rfe_ridge_lr'] = (model_coefs['bagging'] + model_coefs['rfe_ridge_lr']) / 2

# %%
model_coefs.sort_values(by='vr_bag_w_rfe_ridge_lr')
# Out:
#                                                     plain_linreg  plain_ridge  \
# Recycling Collection Frequency_Bi-weekly           -4.352970e-02    -0.013459
# Non-resident Trash and Recycling Service_Trash     -1.436053e-01    -0.009920
# # Hours Enforcement Personnel on Street            -1.566063e-03    -0.018940
# Non-resident Trash and Recycling Service_Recycling -5.296178e-02    -0.008017
# Municipal Buildings Trash and Recycling Service...  2.449933e-12     0.000000
# Dedicated Trash Enforcement Personnel               7.588894e-03     0.001495
# Fee for bulky waste?                               -2.783589e-02    -0.011908
# Trash Enforced by Hauler                           -2.427997e-02    -0.008423
# Recycling Service Type_Curbside                    -2.325173e-02    -0.004533
# Trash Enforced by Muni                              2.157855e-02     0.007229
# Municipal Buildings Trash and Recycling Service... -4.718247e-02    -0.008267
# School Trash and Recycling Service_Recycling       -6.201004e-03    -0.001714
# Recycling Service Type_Both                        -2.455346e-02    -0.005009
# Applies to Commercial Generators                    4.510393e-03     0.002163
# Solid Waste program funded by property tax?        -9.339399e-03    -0.004234
# Trash Service Type_Both                             4.692604e-02     0.008824
# Applies to Residential Generators Eligible to b...  4.457633e-03     0.001906
# Recycling Collection Frequency_Weekly              -4.275486e-03     0.003283
# Recycling Enforced by Muni                          5.317372e-03     0.002615
# Business Trash and Recycling Service_Both           1.058039e-02     0.004436
# Applies to Residential Generators not Eligible ...  9.686493e-03     0.004150
# Annual Bulky Waste Limit                            4.253475e-05     0.002497
# Carts for Trash                                    -1.074206e-02    -0.004300
# Solid Waste program funded by transfer station ... -5.802960e-03    -0.002860
# What is the per-visit fee?                          1.084121e-03     0.005072
# Non-resident Trash and Recycling Service_Both       4.674458e-03     0.001607
# School Trash and Recycling Service_Both            -1.558350e-02    -0.007776
# Recycling Enforced by Hauler                        1.162204e-02     0.004863
# Maximum # bags/ barrels per week                   -1.140652e-03    -0.001285
# Does trash disposal tonnage include bulky waste?    6.957029e-03     0.003411
# Municipal Buildings Trash and Recycling Service... -5.340104e-02    -0.013186
# Recycle Bin Size Ranking                           -9.585759e-04    -0.001686
# SS Recycling                                        9.145855e-03     0.004278
# Private Hauler regulations that require recycling   9.880107e-03     0.004374
# Business Trash and Recycling Service_Recycling      3.631684e-02     0.010843
# Trash Service Type_Curbside                         6.994384e-02     0.023335
# Dedicated Mandatory Recycling Enforcement Perso...  2.421164e-02     0.007430
# Carts for Recycling                                 3.736245e-02     0.016619
# What is the annual fee?                            -8.208167e-05    -0.006841
# What is the transfer station access fee?           -6.597921e-05    -0.002482
# Tip Fee as of 1/1/2020                             -9.026628e-06    -0.000018
# Households Served by Municipal Recycling Program   -8.006053e-07    -0.015283
# PAYT/ SMART                                         6.118825e-02     0.030658
#
#                                                      bagging  rfe_lr_lr  \
# Recycling Collection Frequency_Bi-weekly            0.004723  -0.013893
# Non-resident Trash and Recycling Service_Trash      0.000081   0.000000
# # Hours Enforcement Personnel on Street             0.009754  -0.013662
# Non-resident Trash and Recycling Service_Recycling  0.004352   0.000000
# Municipal Buildings Trash and Recycling Service...  0.000000   0.000000
# Dedicated Trash Enforcement Personnel               0.000390   0.000000
# Fee for bulky waste?                                0.012969   0.000000
# Trash Enforced by Hauler                            0.002407   0.000000
# Recycling Service Type_Curbside                     0.003942   0.000000
# Trash Enforced by Muni                              0.004277   0.000000
# Municipal Buildings Trash and Recycling Service...  0.004306   0.000000
# School Trash and Recycling Service_Recycling        0.004504   0.000000
# Recycling Service Type_Both                         0.004904   0.000000
# Applies to Commercial Generators                    0.007068   0.000000
# Solid Waste program funded by property tax?         0.007101   0.000000
# Trash Service Type_Both                             0.007187   0.000000
# Applies to Residential Generators Eligible to b...  0.009601   0.000000
# Recycling Collection Frequency_Weekly               0.010172   0.000000
# Recycling Enforced by Muni                          0.011390   0.000000
# Business Trash and Recycling Service_Both           0.011424   0.000000
# Applies to Residential Generators not Eligible ...  0.011789   0.000000
# Annual Bulky Waste Limit                            0.012136   0.000000
# Carts for Trash                                     0.013032   0.000000
# Solid Waste program funded by transfer station ...  0.013268   0.000000
# What is the per-visit fee?                          0.013417   0.000000
# Non-resident Trash and Recycling Service_Both       0.013614   0.000000
# School Trash and Recycling Service_Both             0.013982   0.000000
# Recycling Enforced by Hauler                        0.014987   0.000000
# Maximum # bags/ barrels per week                    0.016153   0.000000
# Does trash disposal tonnage include bulky waste?    0.016426   0.000000
# Municipal Buildings Trash and Recycling Service...  0.016472   0.000000
# Recycle Bin Size Ranking                            0.017183   0.000000
# SS Recycling                                        0.017604   0.000000
# Private Hauler regulations that require recycling   0.017915   0.000000
# Business Trash and Recycling Service_Recycling      0.008223   0.000000
# Trash Service Type_Curbside                         0.007644   0.000000
# Dedicated Mandatory Recycling Enforcement Perso...  0.007141   0.012376
# Carts for Recycling                                 0.004348   0.021028
# What is the annual fee?                             0.053801   0.000000
# What is the transfer station access fee?            0.062710   0.000000
# Tip Fee as of 1/1/2020                              0.165902   0.000000
# Households Served by Municipal Recycling Program    0.190399  -0.010637
# PAYT/ SMART                                         0.171299   0.035514
#
#                                                     rfe_ridge_lr  \
# Recycling Collection Frequency_Bi-weekly               -0.016732
# Non-resident Trash and Recycling Service_Trash         -0.009580
# # Hours Enforcement Personnel on Street                -0.017136
# Non-resident Trash and Recycling Service_Recycling     -0.009221
# Municipal Buildings Trash and Recycling Service...      0.000000
# Dedicated Trash Enforcement Personnel                   0.000000
# Fee for bulky waste?                                   -0.010811
# Trash Enforced by Hauler                                0.000000
# Recycling Service Type_Curbside                         0.000000
# Trash Enforced by Muni                                  0.000000
# Municipal Buildings Trash and Recycling Service...      0.000000
# School Trash and Recycling Service_Recycling            0.000000
# Recycling Service Type_Both                             0.000000
# Applies to Commercial Generators                        0.000000
# Solid Waste program funded by property tax?             0.000000
# Trash Service Type_Both                                 0.000000
# Applies to Residential Generators Eligible to b...      0.000000
# Recycling Collection Frequency_Weekly                   0.000000
# Recycling Enforced by Muni                              0.000000
# Business Trash and Recycling Service_Both               0.000000
# Applies to Residential Generators not Eligible ...      0.000000
# Annual Bulky Waste Limit                                0.000000
# Carts for Trash                                         0.000000
# Solid Waste program funded by transfer station ...      0.000000
# What is the per-visit fee?                              0.000000
# Non-resident Trash and Recycling Service_Both           0.000000
# School Trash and Recycling Service_Both                 0.000000
# Recycling Enforced by Hauler                            0.000000
# Maximum # bags/ barrels per week                        0.000000
# Does trash disposal tonnage include bulky waste?        0.000000
# Municipal Buildings Trash and Recycling Service...      0.000000
# Recycle Bin Size Ranking                                0.000000
# SS Recycling                                            0.000000
# Private Hauler regulations that require recycling       0.000000
# Business Trash and Recycling Service_Recycling          0.010245
# Trash Service Type_Curbside                             0.012595
# Dedicated Mandatory Recycling Enforcement Perso...      0.013497
# Carts for Recycling                                     0.017208
# What is the annual fee?                                 0.000000
# What is the transfer station access fee?                0.000000
# Tip Fee as of 1/1/2020                                  0.000000
# Households Served by Municipal Recycling Program       -0.013228
# PAYT/ SMART                                             0.036293
#
#                                                     vr_bag_w_rfe_ridge_lr
# Recycling Collection Frequency_Bi-weekly                        -0.006004
# Non-resident Trash and Recycling Service_Trash                  -0.004749
# # Hours Enforcement Personnel on Street                         -0.003691
# Non-resident Trash and Recycling Service_Recycling              -0.002434
# Municipal Buildings Trash and Recycling Service...               0.000000
# Dedicated Trash Enforcement Personnel                            0.000195
# Fee for bulky waste?                                             0.001079
# Trash Enforced by Hauler                                         0.001203
# Recycling Service Type_Curbside                                  0.001971
# Trash Enforced by Muni                                           0.002139
# Municipal Buildings Trash and Recycling Service...               0.002153
# School Trash and Recycling Service_Recycling                     0.002252
# Recycling Service Type_Both                                      0.002452
# Applies to Commercial Generators                                 0.003534
# Solid Waste program funded by property tax?                      0.003551
# Trash Service Type_Both                                          0.003593
# Applies to Residential Generators Eligible to b...               0.004800
# Recycling Collection Frequency_Weekly                            0.005086
# Recycling Enforced by Muni                                       0.005695
# Business Trash and Recycling Service_Both                        0.005712
# Applies to Residential Generators not Eligible ...               0.005895
# Annual Bulky Waste Limit                                         0.006068
# Carts for Trash                                                  0.006516
# Solid Waste program funded by transfer station ...               0.006634
# What is the per-visit fee?                                       0.006709
# Non-resident Trash and Recycling Service_Both                    0.006807
# School Trash and Recycling Service_Both                          0.006991
# Recycling Enforced by Hauler                                     0.007494
# Maximum # bags/ barrels per week                                 0.008077
# Does trash disposal tonnage include bulky waste?                 0.008213
# Municipal Buildings Trash and Recycling Service...               0.008236
# Recycle Bin Size Ranking                                         0.008591
# SS Recycling                                                     0.008802
# Private Hauler regulations that require recycling                0.008957
# Business Trash and Recycling Service_Recycling                   0.009234
# Trash Service Type_Curbside                                      0.010120
# Dedicated Mandatory Recycling Enforcement Perso...               0.010319
# Carts for Recycling                                              0.010778
# What is the annual fee?                                          0.026900
# What is the transfer station access fee?                         0.031355
# Tip Fee as of 1/1/2020                                           0.082951
# Households Served by Municipal Recycling Program                 0.088586
# PAYT/ SMART                                                      0.103796

# %% [markdown]
# The best non-ensemble models were Linear Regressions using Ridge or Linear Regression RFE before fitting. Let's see what theses models said are the most important features...
#
# **Negative Correlations** -- *presences of these features or higher amounts of these features **reduce** recycling effectiveness. /b/ indicates these features were in both the RFE results with linear regression and ridge. If no /b/ is present, the feature only appeard in the ridge results.*
#
# * /b/`# Hours Enforcement Personnel on Street` -- surprising...
# * /b/`Recycling Collection Frequency_Bi-weekly` -- doesn't do as well as recycling weekly, I suppose
# * /b/`Households Served by Municipal Recycling Program` -- this is probably showing some indication of population size
# * `Fee for bulky waste?`  -- I'm not sure what to make of this. Could it be that some of the bulky waste is recyclable? like kiddy-pools?
# * `Non-resident Trash and Recycling Service` (Trash + Recycling) -- Not sure why servicing non-residental buildings would lead to lower recycling over all..
#
# **Positive Correlations** -- *presences of these features or higher amounts of these features **increase** recycling effectiveness. /b/ indicates these features were in both the RFE results with linear regression and ridge. If no /b/ is present, the feature only appeard in the ridge results.*
# * `Business Trash and Recycling Service_Recycling` -- I think this makes sense because if you are encouraged to recycle at work or out and about, you're probably more likely to recycle at home. Or maybe municipalities that are more recycling-conscious would want to implement comprehensive recycling outside just residential homes... hard to say. That's why I'm surprised "non-residential services" somehow led to lower recycling...
# * `Trash Service Type_Curbside` -- More convenient for the participants, but I'm surprised *recycling* curbside didn't matter more...
# * /b/`Dedicated Mandatory Recycling Enforcement Personnel` -- LOL ... so why is hours of enforcement a negative impact?
# * /b/`Carts for Recycling` -- Makes sense. No excuse to not recycle if you already have a bin
# * /b/`PAYT/ SMART` -- Makes sense, if you pay for the amount you throw out, you probably want to minimize your volume of trash by recycling. Plus, that money goes to further waste handling funding!
#
# The Voting Regression model that used both the linear regression with ridge RFE and Bagging did have the highest score by a small amount. It shares a lot of the same important features (makes sense since half of this model is the linear regression with ridge RFE) but there are some difference:
# * bulky waste fee impact was flipped (but also insignificant)
# * Households Served by Municipal Recycling Program impact was flipped (and is highly significant)
# * Seemed a lot more concerned with funding. In addition to `PAYT/ SMART`, the bagging regressor brought in: `What is the annual fee?`, `What is the transfer station access fee`, `Tip Fee as of 1/1/2020`
# * Seemed to focus more on positive correlations actually
#
# If I want to put more of an emphasis on funding, I may want to select to voting regressor. However, I'll probably also compare future results to the linear regression using ridge RFE. My major take aways in seeing the erratic scores and sometimes logically-opposing feature importances, I think running a predictive model on the population as a whole does not make sense. Assessing smaller sub-populations will probably yield better scores and insights. That's the theory anyways...

# %%
results = results.sort_values('Score', ascending=False)

# %%
# # For saving files

# model_coefs.to_csv('data/baseline_models_coefs.csv', index=True)
# results.to_csv('data/baseline_models_scores.csv', index=True)
