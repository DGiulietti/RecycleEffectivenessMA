# %% [markdown]
# ## Comparing predictive models of the population and the clusters
#
# Next step is to see if:
#
# 1. we can get better predictions within the clusters than within the population as a whole
# 2. the trends within the clusters are significantly different (e.g. feature1 is has a positive correlation with recycling rate in cluster0 but a negative correlation in cluster2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Recap

# %%
bl_model_coefs = pd.read_csv('data/baseline_models_coefs.csv', index_col=0)
bl_model_scores = pd.read_csv('data/baseline_models_scores.csv', index_col=0)

# %% [markdown]
# #### Review Baseline model scores
#
# As confirmed by cross validation in part 3b, the best fit models for the baseline data were all tree-based so I will only consider tree-based models for my individual clusters. Of the baseline models, the best fit was with an **bagging algorithm optimized by gridsearch parameters** (`bagging_op`). The score was 0.139. The follow up score was for an optimized random forest regressor (`rfr_op`, 0.110), and I couldn't get the boosting algorithm to work well with my dataset (I think this algorithm requires more data than most). I expect that bagging or random forest will still work best in the clusters, but I think the fits will be much better (at least in the larger clusters). It will also be interesting to see how the feature importances change.

# %%
bl_model_scores
# Out:
#              score_train  score_test      rmse       mae
# GS_bagging      0.558013    0.151202  0.073488  0.055929
# GS_RF_MSE       0.565859    0.148285  0.073614  0.056166
# GS_RF_MAE       0.570668    0.145455  0.073736  0.055663
# bagging_op      0.576620    0.139168  0.074007  0.055768
# GS_RF_MSE2      0.387818    0.132343  0.074299  0.056118
# rfr_op          0.575200    0.128513  0.074463  0.056970
# RFR             0.880999    0.090887  0.076054  0.058374
# GS_boosting     0.495300    0.085775  0.076267  0.059735
# dummy           0.000000   -0.010230  0.080172  0.060118
# bagging         0.809259   -0.028548  0.080895  0.062488
# boosting_op     0.898064   -0.076738  0.082769  0.059563
# GradBoost       0.998480   -0.385776  0.093898  0.068800

# %% [markdown]
# #### Review baseline model coefficients (feature importance)
#
# The models mostly agreed on what the important fetures are. However, there are not many important features. Looking at features that scored over 0.05 on the bagging_op models, seems like population is indirectly important in `Households Served by Municipal Recycling Program` and the rest of the important features are related to funding: `Tip Fee as of 1/1/2020`, `PAYT/ SMART`, `What is the transfer station access fee?`, `What is the annual fee?`.
#
# However, these features are not that strongly important. So I'm curious to see how they change in the individual clusters.

# %%
bl_model_coefs
# Out:
#                                                       RFR  RFR_op  bagging  \
# Tip Fee as of 1/1/2020                              0.194   0.201    0.207
# Households Served by Municipal Recycling Program    0.162   0.148    0.159
# PAYT/ SMART                                         0.188   0.198    0.213
# What is the transfer station access fee?            0.051   0.051    0.038
# What is the annual fee?                             0.051   0.040    0.055
# Recycling Collection Frequency_Weekly               0.014   0.016    0.005
# Does trash disposal tonnage include bulky waste?    0.016   0.020    0.017
# # Hours Enforcement Personnel on Street             0.013   0.011    0.013
# Municipal Buildings Trash and Recycling Service...  0.022   0.015    0.028
# Applies to Residential Generators not Eligible ...  0.015   0.016    0.009
# Non-resident Trash and Recycling Service_Both       0.021   0.017    0.020
# Maximum # bags/ barrels per week                    0.023   0.017    0.022
# School Trash and Recycling Service_Both             0.010   0.011    0.005
# Recycle Bin Size Ranking                            0.015   0.016    0.021
# Business Trash and Recycling Service_Both           0.010   0.015    0.007
# Solid Waste program funded by property tax?         0.008   0.014    0.008
# Fee for bulky waste?                                0.012   0.013    0.010
# Solid Waste program funded by transfer station ...  0.014   0.010    0.002
# Recycling Enforced by Muni                          0.013   0.015    0.008
# Applies to Residential Generators Eligible to b...  0.013   0.012    0.012
# SS Recycling                                        0.010   0.011    0.007
# Annual Bulky Waste Limit                            0.012   0.016    0.010
# Recycling Enforced by Hauler                        0.021   0.013    0.052
# Business Trash and Recycling Service_Recycling      0.010   0.013    0.005
# Private Hauler regulations that require recycling   0.010   0.007    0.013
# Recycling Collection Frequency_Bi-weekly            0.010   0.009    0.007
# Recycling Service Type_Both                         0.005   0.008    0.004
# What is the per-visit fee?                          0.004   0.006    0.001
# Dedicated Mandatory Recycling Enforcement Perso...  0.010   0.010    0.003
# Carts for Recycling                                 0.004   0.008    0.004
# Applies to Commercial Generators                    0.005   0.007    0.001
# Trash Service Type_Both                             0.008   0.008    0.007
# Trash Service Type_Curbside                         0.005   0.005    0.010
# Recycling Service Type_Curbside                     0.004   0.006    0.002
# Carts for Trash                                     0.005   0.004    0.003
# Trash Enforced by Hauler                            0.001   0.004    0.002
# Trash Enforced by Muni                              0.003   0.002    0.004
# School Trash and Recycling Service_Recycling        0.003   0.003    0.002
# Municipal Buildings Trash and Recycling Service...  0.002   0.002    0.002
# Dedicated Trash Enforcement Personnel               0.001   0.001    0.000
# Non-resident Trash and Recycling Service_Trash      0.000   0.000    0.000
# Non-resident Trash and Recycling Service_Recycling  0.001   0.000    0.000
# Municipal Buildings Trash and Recycling Service...  0.000   0.000    0.000
#
#                                                     bagging_op  gradboost  \
# Tip Fee as of 1/1/2020                                   0.248      0.194
# Households Served by Municipal Recycling Program         0.201      0.162
# PAYT/ SMART                                              0.196      0.188
# What is the transfer station access fee?                 0.069      0.051
# What is the annual fee?                                  0.060      0.051
# Recycling Collection Frequency_Weekly                    0.027      0.014
# Does trash disposal tonnage include bulky waste?         0.027      0.016
# # Hours Enforcement Personnel on Street                  0.027      0.013
# Municipal Buildings Trash and Recycling Service...       0.026      0.022
# Applies to Residential Generators not Eligible ...       0.025      0.015
# Non-resident Trash and Recycling Service_Both            0.025      0.021
# Maximum # bags/ barrels per week                         0.024      0.023
# School Trash and Recycling Service_Both                  0.022      0.010
# Recycle Bin Size Ranking                                 0.022      0.015
# Business Trash and Recycling Service_Both                0.022      0.010
# Solid Waste program funded by property tax?              0.021      0.008
# Fee for bulky waste?                                     0.021      0.012
# Solid Waste program funded by transfer station ...       0.020      0.014
# Recycling Enforced by Muni                               0.020      0.013
# Applies to Residential Generators Eligible to b...       0.020      0.013
# SS Recycling                                             0.019      0.010
# Annual Bulky Waste Limit                                 0.019      0.012
# Recycling Enforced by Hauler                             0.017      0.021
# Business Trash and Recycling Service_Recycling           0.017      0.010
# Private Hauler regulations that require recycling        0.015      0.010
# Recycling Collection Frequency_Bi-weekly                 0.014      0.010
# Recycling Service Type_Both                              0.013      0.005
# What is the per-visit fee?                               0.013      0.004
# Dedicated Mandatory Recycling Enforcement Perso...       0.013      0.010
# Carts for Recycling                                      0.012      0.004
# Applies to Commercial Generators                         0.012      0.005
# Trash Service Type_Both                                  0.011      0.008
# Trash Service Type_Curbside                              0.010      0.005
# Recycling Service Type_Curbside                          0.009      0.004
# Carts for Trash                                          0.009      0.005
# Trash Enforced by Hauler                                 0.006      0.001
# Trash Enforced by Muni                                   0.006      0.003
# School Trash and Recycling Service_Recycling             0.005      0.003
# Municipal Buildings Trash and Recycling Service...       0.003      0.002
# Dedicated Trash Enforcement Personnel                    0.002      0.001
# Non-resident Trash and Recycling Service_Trash           0.000      0.000
# Non-resident Trash and Recycling Service_Recycling       0.000      0.001
# Municipal Buildings Trash and Recycling Service...       0.000      0.000
#
#                                                     gradboost_op
# Tip Fee as of 1/1/2020                                     0.172
# Households Served by Municipal Recycling Program           0.192
# PAYT/ SMART                                                0.212
# What is the transfer station access fee?                   0.105
# What is the annual fee?                                    0.021
# Recycling Collection Frequency_Weekly                      0.025
# Does trash disposal tonnage include bulky waste?           0.019
# # Hours Enforcement Personnel on Street                    0.016
# Municipal Buildings Trash and Recycling Service...         0.037
# Applies to Residential Generators not Eligible ...         0.010
# Non-resident Trash and Recycling Service_Both              0.014
# Maximum # bags/ barrels per week                           0.030
# School Trash and Recycling Service_Both                    0.007
# Recycle Bin Size Ranking                                   0.005
# Business Trash and Recycling Service_Both                  0.005
# Solid Waste program funded by property tax?                0.003
# Fee for bulky waste?                                       0.011
# Solid Waste program funded by transfer station ...         0.000
# Recycling Enforced by Muni                                 0.002
# Applies to Residential Generators Eligible to b...         0.004
# SS Recycling                                               0.005
# Annual Bulky Waste Limit                                   0.012
# Recycling Enforced by Hauler                               0.022
# Business Trash and Recycling Service_Recycling             0.012
# Private Hauler regulations that require recycling          0.002
# Recycling Collection Frequency_Bi-weekly                   0.005
# Recycling Service Type_Both                                0.004
# What is the per-visit fee?                                 0.012
# Dedicated Mandatory Recycling Enforcement Perso...         0.002
# Carts for Recycling                                        0.011
# Applies to Commercial Generators                           0.006
# Trash Service Type_Both                                    0.002
# Trash Service Type_Curbside                                0.000
# Recycling Service Type_Curbside                            0.000
# Carts for Trash                                            0.000
# Trash Enforced by Hauler                                   0.012
# Trash Enforced by Muni                                     0.002
# School Trash and Recycling Service_Recycling               0.000
# Municipal Buildings Trash and Recycling Service...         0.000
# Dedicated Trash Enforcement Personnel                      0.000
# Non-resident Trash and Recycling Service_Trash             0.000
# Non-resident Trash and Recycling Service_Recycling         0.000
# Municipal Buildings Trash and Recycling Service...         0.000

# %% [markdown]
# ## Setting up data for individual cluster analysis

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score, KFold
from sklearn.pipeline import make_pipeline
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor, BaggingRegressor, VotingRegressor
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.feature_selection import RFE

# %%
# import clustering data

cluster = pd.read_csv('data/cluster_Data.csv', index_col='municipality')
cluster_labels = cluster.loc[:,'km_label':]

# %%
# df of service details per municipality with 'hc-schema' labels

df_of_serve_details = pd.read_csv('data/data_for_regression.csv', index_col = 'Municipality Name')
df_of_serve_details = df_of_serve_details.merge(cluster_labels['hc_label'], left_index = True, right_index=True)
df_of_serve_details.head()
# Out:
#           Solid Waste program funded by property tax?  \
# Abington                                            1
# Acton                                               0
# Acushnet                                            1
# Adams                                               1
# Agawam                                              1
#
#           Solid Waste program funded by transfer station access fee?  \
# Abington                                                  0
# Acton                                                     1
# Acushnet                                                  0
# Adams                                                     1
# Agawam                                                    0
#
#           What is the annual fee?  What is the transfer station access fee?  \
# Abington                      0.0                                       0.0
# Acton                         0.0                                     100.0
# Acushnet                      0.0                                       0.0
# Adams                         0.0                                      50.0
# Agawam                        0.0                                       0.0
#
#           What is the per-visit fee?  PAYT/ SMART  \
# Abington                         0.0            0
# Acton                           30.0            1
# Acushnet                         0.0            0
# Adams                            0.0            1
# Agawam                           0.0            0
#
#           Municipal Buildings Trash and Recycling Service_Both  \
# Abington                                                  1
# Acton                                                     1
# Acushnet                                                  1
# Adams                                                     1
# Agawam                                                    1
#
#           Municipal Buildings Trash and Recycling Service_Recycling  \
# Abington                                                  0
# Acton                                                     0
# Acushnet                                                  0
# Adams                                                     0
# Agawam                                                    0
#
#           Municipal Buildings Trash and Recycling Service_Trash  \
# Abington                                                  0
# Acton                                                     0
# Acushnet                                                  0
# Adams                                                     0
# Agawam                                                    0
#
#           School Trash and Recycling Service_Both  ...  \
# Abington                                        1  ...
# Acton                                           0  ...
# Acushnet                                        1  ...
# Adams                                           0  ...
# Agawam                                          1  ...
#
#           Recycling Enforced by Muni  Recycling Enforced by Hauler  \
# Abington                           1                             1
# Acton                              1                             0
# Acushnet                           1                             1
# Adams                              1                             1
# Agawam                             0                             0
#
#           Dedicated Mandatory Recycling Enforcement Personnel  \
# Abington                                                  1
# Acton                                                     0
# Acushnet                                                  0
# Adams                                                     0
# Agawam                                                    0
#
#           # Hours Enforcement Personnel on Street  \
# Abington                                     20.0
# Acton                                         0.0
# Acushnet                                      0.0
# Adams                                         0.0
# Agawam                                        0.0
#
#           Private Hauler regulations that require recycling  %recycle/hh  \
# Abington                                                  1     0.269733
# Acton                                                     0     0.310437
# Acushnet                                                  1     0.215648
# Adams                                                     1     0.509377
# Agawam                                                    0     0.249912
#
#           Recycling Collection Frequency_Bi-weekly  \
# Abington                                         0
# Acton                                            0
# Acushnet                                         1
# Adams                                            0
# Agawam                                           1
#
#           Recycling Collection Frequency_Weekly  Recycle Bin Size Ranking  \
# Abington                                      1                      0.50
# Acton                                         0                      0.00
# Acushnet                                      0                      1.00
# Adams                                         0                      0.00
# Agawam                                        0                      0.75
#
#           hc_label
# Abington         0
# Acton            2
# Acushnet         0
# Adams            0
# Agawam           0
#
# [5 rows x 45 columns]

# %% [markdown]
# ### Separating cluster data
#
# It's important to note the quantities of municipalities in each cluster label. Label 0 has the most by far, so shouldn't have too much trouble in terms of training the data and still having enough data to test. Labels 2 and 1 will become a little more challenging as they have under 100 municipalites (label 1 in particular will be tough with only 35 labels). Label 3 is Boston, all by itself, so there is no regression to be had. Boston is very much on a scale far different than any other municipality in terms of population, economic stability, etc, so this makes sense.
#
# So I will only be studying the fit of three labels, and I'll be expecting some challenging fits within two of them.

# %%
df_of_serve_details['hc_label'].value_counts()
# Out:
# 0    179
# 2     52
# 1     35
# 3      1
# Name: hc_label, dtype: int64

# %%
l0_serve = df_of_serve_details.groupby('hc_label').get_group(0)
l1_serve = df_of_serve_details.groupby('hc_label').get_group(1)
l2_serve = df_of_serve_details.groupby('hc_label').get_group(2)
l3_serve = df_of_serve_details.groupby('hc_label').get_group(3)

# %% [markdown]
# ### Running the regressions
#
# Below is a function for doing some basic-models (with no optimization) on each of the labels. The function fits and scores a dummy model, a random forest regressor, a bagging regressor, and a gradient boosting regressor. `fit_results` will record all the data for comparison after the fits.

# %%
fit_results = {}

def tree_models(serv_df, name):
    X = serv_df.drop(columns=['%recycle/hh', 'hc_label'])
    y = serv_df['%recycle/hh']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 8)
    
    dummy = DummyRegressor()
    rfr = RandomForestRegressor(random_state=8)
    bagging = BaggingRegressor(random_state=8)
    boost = GradientBoostingRegressor(random_state=8)
    
    model = dummy
    model.fit(X_train,y_train)
    score_train = model.score(X_train, y_train)
    score_test = model.score(X_test, y_test)
    rmse = mean_squared_error(y_test, model.predict(X_test), squared=False)
    mae = mean_absolute_error(y_test, model.predict(X_test))
    fit_results[name+'__dummy'] = (score_train, score_test, rmse, mae)
    print('dummy complete...')
    
    model = rfr
    model.fit(X_train,y_train)
    score_train = model.score(X_train, y_train)
    score_test = model.score(X_test, y_test)
    rmse = mean_squared_error(y_test, model.predict(X_test), squared=False)
    mae = mean_absolute_error(y_test, model.predict(X_test))
    fit_results[name+'__rfr'] = (score_train, score_test, rmse, mae)
    print('rfr complete...')
    
    model = bagging
    model.fit(X_train,y_train)
    score_train = model.score(X_train, y_train)
    score_test = model.score(X_test, y_test)
    rmse = mean_squared_error(y_test, model.predict(X_test), squared=False)
    mae = mean_absolute_error(y_test, model.predict(X_test))
    fit_results[name+'__bagging'] = (score_train, score_test, rmse, mae)
    print('bagging complete...')
    
    model = boost
    model.fit(X_train,y_train)
    score_train = model.score(X_train, y_train)
    score_test = model.score(X_test, y_test)
    rmse = mean_squared_error(y_test, model.predict(X_test), squared=False)
    mae = mean_absolute_error(y_test, model.predict(X_test))
    fit_results[name+'__boost'] = (score_train, score_test, rmse, mae)
    print('boost complete...')
    
    return

# %%
tree_models(l0_serve,'L0')
# Out:
# dummy complete...
# rfr complete...
# bagging complete...
# boost complete...

# %%
tree_models(l1_serve, 'L1')
# Out:
# dummy complete...
# rfr complete...
# bagging complete...
# boost complete...

# %%
tree_models(l2_serve, 'L2')
# Out:
# dummy complete...
# rfr complete...
# bagging complete...
# boost complete...

# %%
pd.DataFrame(fit_results, index=['score_train', 'score_test', 'rmse', 'mae']).T.sort_values(by='score_test', ascending = False)
# Out:
#              score_train  score_test      rmse       mae
# L2__rfr         0.812889    0.533310  0.052097  0.043196
# L2__bagging     0.800556    0.490688  0.054424  0.044869
# L2__boost       0.998540    0.445003  0.056812  0.046576
# L0__bagging     0.783686    0.202839  0.069744  0.054325
# L0__rfr         0.844602    0.112866  0.073575  0.056070
# L0__boost       0.910077    0.039026  0.076576  0.057548
# L0__dummy       0.000000   -0.003264  0.078243  0.063760
# L1__dummy       0.000000   -0.114973  0.060690  0.052558
# L2__dummy       0.000000   -0.122624  0.080800  0.065204
# L1__rfr         0.855375   -0.302122  0.065586  0.053689
# L1__bagging     0.772080   -0.732672  0.075656  0.058755
# L1__boost       0.999983   -1.409569  0.089219  0.069259

# %% [markdown]
# #### Initial take-aways
#
# So right away, we can see a few trends:
# 1. Label 2 suprisingly has the best fits, followed by label 0. As expect, label 1 has the worst fits (even worse then the dummy models), probably because it's sample size is *so* low.
# 1. the fits in label 2 are *way* higher than those in the baseline model of the entire population. L0 is higher but not to the same degree.
# 1. the boosting algorithm really seems to lead to overfiting in the training set (with scores consistently above 0.90); I think this is the result of it not using bootstrapping. I realling think that gradient boosting is not the right algorithm for my dataset.

# %% [markdown]
# ### Tweaking the Regressions
#
# Like I did with the baseline model, I will spend some time tweaking these un-altered models to get the best fit for each cluster. Because I'm looking at 3 different groups, I'm going to drop the Gradient Boosting model as it as repeatedly looked like a bad fit. I will use GridSearch to play with different hyperparameters in random forest regressors and bagging regressors.

# %%
params_rf = {
    'n_estimators': [10,100,1000],
    'max_samples': [1, 0.66, 0.33],
    'max_features': [1.0, 0.75, 0.5],
    'max_depth': [5, 10, 20, 50]
}

# %%
params_bagging = {
    'n_estimators': [100,1000],
    'max_samples': [1.0, 0.66, 0.33],
    'max_features': [1.0, 0.75, 0.5]
}

# %%
kf = KFold(n_splits=3, shuffle = True, random_state= 8)

# %%
def gs_models(serv_df, name):
    X = serv_df.drop(columns=['%recycle/hh', 'hc_label'])
    y = serv_df['%recycle/hh']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 8)

    rfr = RandomForestRegressor(random_state=8)
    bagging = BaggingRegressor(random_state=8)

    gs1 = GridSearchCV(rfr, params_rf, cv=kf, n_jobs=-1)
    gs1.fit(X_train,y_train)
    score_train = gs1.score(X_train, y_train)
    score_test = gs1.score(X_test, y_test)
    rmse = mean_squared_error(y_test, gs1.predict(X_test), squared=False)
    mae = mean_absolute_error(y_test, gs1.predict(X_test))
    fit_results[name+'__gs_rfr'] = (score_train, score_test, rmse, mae)
    print('gridsearch rfr complete...')
    
    gs2 = GridSearchCV(bagging, params_bagging, cv=kf, n_jobs=-1)
    gs2.fit(X_train,y_train)
    score_train = gs2.score(X_train, y_train)
    score_test = gs2.score(X_test, y_test)
    rmse = mean_squared_error(y_test, gs2.predict(X_test), squared=False)
    mae = mean_absolute_error(y_test, gs2.predict(X_test))
    fit_results[name+'__gs_bagging'] = (score_train, score_test, rmse, mae)
    print('gridsearch bagging complete...')

    return (gs1, gs2)

# %% [markdown]
# ### Label 0

# %%
gs1, gs2 = gs_models(l0_serve,'L0')
# Out:
# gridsearch rfr complete...
# gridsearch bagging complete...

# %%
gs_cv_results = pd.DataFrame(gs1.cv_results_).sort_values(by='mean_test_score', ascending = False)
gs_cv_results.iloc[:,4:].head(5)
# gs_cv_results[gs_cv_results['mean_test_score'] > 0].iloc[:,4:]
# Out:
#     param_max_depth param_max_features param_max_samples param_n_estimators  \
# 25                5                0.5              0.33                100
# 106              50                0.5              0.33                100
# 79               20                0.5              0.33                100
# 10                5               0.75                 1                100
# 91               50               0.75                 1                100
#
#                                                 params  split0_test_score  \
# 25   {'max_depth': 5, 'max_features': 0.5, 'max_sam...          -0.043441
# 106  {'max_depth': 50, 'max_features': 0.5, 'max_sa...          -0.046482
# 79   {'max_depth': 20, 'max_features': 0.5, 'max_sa...          -0.046482
# 10   {'max_depth': 5, 'max_features': 0.75, 'max_sa...          -0.000202
# 91   {'max_depth': 50, 'max_features': 0.75, 'max_s...          -0.000202
#
#      split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 25            0.010121           0.038823         0.001835        0.034092
# 106           0.011015           0.023030        -0.004146        0.030336
# 79            0.011015           0.023030        -0.004146        0.030336
# 10           -0.000345          -0.014249        -0.004932        0.006589
# 91           -0.000345          -0.014249        -0.004932        0.006589
#
#      rank_test_score
# 25                 1
# 106                2
# 79                 2
# 10                 4
# 91                 4

# %% [markdown]
# The scores are mostly all negative but I'm wondering if I try these hyperparameters not in a GridSearch (where it is even further dividing the sample set) if I will get better results. Looks like the top ranking configurations all had n_estimators of 100, a max_sample of 0.33, and a max_feature of 0.5. Seems like the max_depth of 5 did manage to produce a positive score, so I'll use it; however, it didn't make a huge difference so I may remove it.

# %%
gs_cv_results = pd.DataFrame(gs2.cv_results_).sort_values(by='mean_test_score', ascending = False)
gs_cv_results.iloc[:,4:].head(5)
# gs_cv_results[gs_cv_results['mean_test_score'] > 0].iloc[:,4:]
# Out:
#    param_max_features param_max_samples param_n_estimators  \
# 17                0.5              0.33               1000
# 15                0.5              0.66               1000
# 11               0.75              0.33               1000
# 5                   1              0.33               1000
# 13                0.5                 1               1000
#
#                                                params  split0_test_score  \
# 17  {'max_features': 0.5, 'max_samples': 0.33, 'n_...          -0.022679
# 15  {'max_features': 0.5, 'max_samples': 0.66, 'n_...          -0.022802
# 11  {'max_features': 0.75, 'max_samples': 0.33, 'n...          -0.039092
# 5   {'max_features': 1.0, 'max_samples': 0.33, 'n_...          -0.069215
# 13  {'max_features': 0.5, 'max_samples': 1.0, 'n_e...          -0.030595
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 17          -0.023362          -0.013028        -0.019690        0.004719
# 15          -0.056910           0.020248        -0.019821        0.031570
# 11          -0.047360           0.014994        -0.023819        0.027652
# 5           -0.042947           0.037676        -0.024828        0.045480
# 13          -0.102056           0.024029        -0.036207        0.051627
#
#     rank_test_score
# 17                1
# 15                2
# 11                3
# 5                 4
# 13                5

# %% [markdown]
# All the scores were negative this time. Looks like the same max_feature and max_sample generally worked well, although max_samples of 0.33 and 0.66 performed pretty close. Seems consistent that the higher n_estimators did best.

# %%
serv_df = l0_serve
name = 'L0'

X = serv_df.drop(columns=['%recycle/hh', 'hc_label'])
y = serv_df['%recycle/hh']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 8)

rfr = RandomForestRegressor(max_samples= 0.33, max_features=0.5, n_estimators=100, random_state=8)
bagging = BaggingRegressor(max_samples= 0.66, max_features=0.5, n_estimators=1000, random_state=8)


rfr.fit(X_train,y_train)
score_train = rfr.score(X_train, y_train)
score_test = rfr.score(X_test, y_test)
rmse = mean_squared_error(y_test, rfr.predict(X_test), squared=False)
mae = mean_absolute_error(y_test, rfr.predict(X_test))
fit_results[name+'__rfr_op'] = (score_train, score_test, rmse, mae)
print('rfr complete...')


bagging.fit(X_train,y_train)
score_train = bagging.score(X_train, y_train)
score_test = bagging.score(X_test, y_test)
rmse = mean_squared_error(y_test, bagging.predict(X_test), squared=False)
mae = mean_absolute_error(y_test, bagging.predict(X_test))
fit_results[name+'__bagging_op'] = (score_train, score_test, rmse, mae)
print('bagging complete...')
# Out:
# rfr complete...
# bagging complete...

# %%
L0_results = pd.DataFrame(fit_results, index=['score_train', 'score_test', 'rmse', 'mae']).T.sort_index().iloc[:8]
L0_results.sort_values(by='score_test', ascending = False)
# Out:
#                 score_train  score_test      rmse       mae
# L0__bagging        0.783686    0.202839  0.069744  0.054325
# L0__bagging_op     0.707691    0.178111  0.070818  0.055872
# L0__rfr_op         0.485509    0.145754  0.072198  0.057303
# L0__gs_bagging     0.464493    0.142147  0.072351  0.057859
# L0__gs_rfr         0.436620    0.142121  0.072352  0.056845
# L0__rfr            0.844602    0.112866  0.073575  0.056070
# L0__boost          0.910077    0.039026  0.076576  0.057548
# L0__dummy          0.000000   -0.003264  0.078243  0.063760

# %% [markdown]
# #### Coefficients for feature importance
#
# because of the way I ran the original function with the plain models, I just have to fit another plain bagging model one more time to get the coefs from the best fit model.

# %%
serv_df = l0_serve
name = 'L0'

X = serv_df.drop(columns=['%recycle/hh', 'hc_label'])
y = serv_df['%recycle/hh']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 8)

bagging = BaggingRegressor(random_state=8)
bagging.fit(X_train,y_train)
# just making sure it's the same data as in my table
print('training score: ', bagging.score(X_train, y_train))
print('test score: ', bagging.score(X_test, y_test))
print( 'rmse: ', mean_squared_error(y_test, bagging.predict(X_test), squared=False))
print('mae: ', mean_absolute_error(y_test, bagging.predict(X_test)))
# Out:
# training score:  0.7836863982005179
# test score:  0.20283850159161265
# rmse:  0.06974444410357723
# mae:  0.054324699861871766

# %%
bagging_trees_coefs = {}
for tree in range(len(bagging.estimators_)):
    bagging_trees_coefs[tree] = dict(zip(bagging.estimators_features_[tree], bagging.estimators_[tree].feature_importances_))

bagging_trees_coefs = pd.DataFrame(bagging_trees_coefs).sort_index()
L0__bagging_coefs = pd.DataFrame(bagging_trees_coefs.mean(axis=1))
L0__bagging_coefs['Feature Name'] = X.columns
L0__bagging_coefs.set_index('Feature Name', inplace = True)
L0__bagging_coefs.rename(columns={0:'coefs'}, inplace = True)
L0__bagging_coefs.sort_values(by='coefs', ascending=False).head(10)
# Out:
#                                                        coefs
# Feature Name
# Households Served by Municipal Recycling Program    0.202576
# Tip Fee as of 1/1/2020                              0.160272
# What is the transfer station access fee?            0.116475
# PAYT/ SMART                                         0.089092
# What is the annual fee?                             0.058338
# Municipal Buildings Trash and Recycling Service...  0.040240
# Business Trash and Recycling Service_Recycling      0.029783
# Does trash disposal tonnage include bulky waste?    0.029514
# Solid Waste program funded by property tax?         0.028205
# Recycling Enforced by Hauler                        0.022959

# %%
plt.scatter(y_test, bagging.predict(X_test));

# %% [markdown]
# #### Thoughts on Label 0
#
# So, default Bagging actually performed the best with an test score R2 value of 0.203 and an MAE of 0.054. Seems like any alterations to the bagging algorithm just resulted in worse fits both in training and testing, which I find interesting. For random forest, I was able to bring up the test score from 0.113 to 0.146 but this still doesn't beat the plain bagging algorithm.
#
# Overall, this score still beats the overall population's fit but my hypothesis is that this rather large cluster of 150+ municipalities may actually be better represented in two groups. Perhaps going back to a clustering algorithm where n=5 may be interesting to look at in contrast.
#
# This hypothesis is further supported by the top feature importances of this bagging model which mostly mirror the total-population: indirectly population with `Households Served by Municipal Recycling Program` and funding information in `Tip Fee as of 1/1/2020`, `What is the transfer station access fee?`, `PAYT/ SMART`, and `What is the annual fee?`.

# %% [markdown]
# ### Label 1

# %%
L1_gs1, L1_gs2 = gs_models(l1_serve,'L1')
# Out:
# gridsearch rfr complete...
# gridsearch bagging complete...

# %%
gs_cv_results = pd.DataFrame(L1_gs1.cv_results_).sort_values(by='mean_test_score', ascending = False)
gs_cv_results.iloc[:,4:].head(5)
# gs_cv_results[gs_cv_results['mean_test_score'] > 0].iloc[:,4:]
# Out:
#    param_max_depth param_max_features param_max_samples param_n_estimators  \
# 33              10                  1              0.33                 10
# 87              50                  1              0.33                 10
# 6                5                  1              0.33                 10
# 60              20                  1              0.33                 10
# 64              20               0.75                 1                100
#
#                                                params  split0_test_score  \
# 33  {'max_depth': 10, 'max_features': 1.0, 'max_sa...          -0.203339
# 87  {'max_depth': 50, 'max_features': 1.0, 'max_sa...          -0.203339
# 6   {'max_depth': 5, 'max_features': 1.0, 'max_sam...          -0.203339
# 60  {'max_depth': 20, 'max_features': 1.0, 'max_sa...          -0.203339
# 64  {'max_depth': 20, 'max_features': 0.75, 'max_s...          -0.293379
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 33          -0.357115           0.138740        -0.140571        0.207240
# 87          -0.357115           0.138740        -0.140571        0.207240
# 6           -0.357115           0.138740        -0.140571        0.207240
# 60          -0.357115           0.138740        -0.140571        0.207240
# 64          -0.168197          -0.052727        -0.171434        0.098272
#
#     rank_test_score
# 33                1
# 87                1
# 6                 1
# 60                1
# 64                5

# %% [markdown]
# All the scores are negative for a max_sample of 0.33 consistently did best along with n_estimators of 10. Limiting max features didn't help, and max_depth didn't seem do do anything, so I'll remove those two attributes.

# %%
gs_cv_results = pd.DataFrame(L1_gs2.cv_results_).sort_values(by='mean_test_score', ascending = False)
gs_cv_results.iloc[:,4:].head(5)
# gs_cv_results[gs_cv_results['mean_test_score'] > 0].iloc[:,4:]
# Out:
#    param_max_features param_max_samples param_n_estimators  \
# 16                0.5              0.33                100
# 10               0.75              0.33                100
# 4                   1              0.33                100
# 5                   1              0.33               1000
# 17                0.5              0.33               1000
#
#                                                params  split0_test_score  \
# 16  {'max_features': 0.5, 'max_samples': 0.33, 'n_...          -0.497863
# 10  {'max_features': 0.75, 'max_samples': 0.33, 'n...          -0.552072
# 4   {'max_features': 1.0, 'max_samples': 0.33, 'n_...          -0.594714
# 5   {'max_features': 1.0, 'max_samples': 0.33, 'n_...          -0.609814
# 17  {'max_features': 0.5, 'max_samples': 0.33, 'n_...          -0.654873
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 16          -0.296763          -0.009163        -0.267930        0.200550
# 10          -0.224096          -0.080158        -0.285442        0.197481
# 4           -0.152634          -0.118092        -0.288480        0.216999
# 5           -0.211780          -0.079444        -0.300346        0.225397
# 17          -0.249617          -0.014716        -0.306402        0.264409
#
#     rank_test_score
# 16                1
# 10                2
# 4                 3
# 5                 4
# 17                5

# %% [markdown]
# All negative scores again. Max sample of 0.33 and n_estimators of 100 did best consistently. Max_feature did seem to do something measurable to the score so I'll keep that as well. This will make the bagging model the same as the GS model.

# %%
serv_df = l1_serve
name = 'L1'

X = serv_df.drop(columns=['%recycle/hh', 'hc_label'])
y = serv_df['%recycle/hh']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 8)

rfr = RandomForestRegressor(max_samples= 0.33, n_estimators=10, random_state=8)
bagging = BaggingRegressor(max_samples= 0.33, max_features=0.5, n_estimators=100, random_state=8)


rfr.fit(X_train,y_train)
score_train = rfr.score(X_train, y_train)
score_test = rfr.score(X_test, y_test)
rmse = mean_squared_error(y_test, rfr.predict(X_test), squared=False)
mae = mean_absolute_error(y_test, rfr.predict(X_test))
fit_results[name+'__rfr_op'] = (score_train, score_test, rmse, mae)
print('rfr complete...')


bagging.fit(X_train,y_train)
score_train = bagging.score(X_train, y_train)
score_test = bagging.score(X_test, y_test)
rmse = mean_squared_error(y_test, bagging.predict(X_test), squared=False)
mae = mean_absolute_error(y_test, bagging.predict(X_test))
fit_results[name+'__bagging_op'] = (score_train, score_test, rmse, mae)
print('bagging complete...')
# Out:
# rfr complete...
# bagging complete...

# %%
L1_results = pd.DataFrame(fit_results, index=['score_train', 'score_test', 'rmse', 'mae']).T.sort_index().iloc[8:16]
L1_results.sort_values(by='score_test', ascending = False)
# Out:
#                 score_train  score_test      rmse       mae
# L1__rfr_op         0.371751   -0.003033  0.057563  0.045403
# L1__gs_rfr         0.377552   -0.012099  0.057823  0.045841
# L1__bagging_op     0.418971   -0.030399  0.058343  0.049767
# L1__gs_bagging     0.418971   -0.030399  0.058343  0.049767
# L1__dummy          0.000000   -0.114973  0.060690  0.052558
# L1__rfr            0.855375   -0.302122  0.065586  0.053689
# L1__bagging        0.772080   -0.732672  0.075656  0.058755
# L1__boost          0.999983   -1.409569  0.089219  0.069259

# %% [markdown]
# #### Coefficients for feature importance
#
# I'll just be looking at the coefficients from the optimized random forest but I won't put too much stock in the results because these fits were so poor.

# %%
rfr_op_coefs = np.mean([
    tree.feature_importances_ for tree in rfr.estimators_
], axis=0)
rfr_op_coefs
# Out:
# array([0.00000000e+00, 0.00000000e+00, 7.01346441e-03, 2.01105695e-02,
#        8.74078346e-05, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.04297392e-06,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.45764777e-02, 3.36845721e-03, 4.70346227e-04, 4.68080323e-02,
#        4.50837455e-03, 1.00037544e-01, 1.02855941e-01, 2.07782907e-02,
#        0.00000000e+00, 2.47634919e-04, 0.00000000e+00, 7.95645470e-02,
#        1.83497229e-02, 3.19471390e-02, 0.00000000e+00, 2.42581905e-03,
#        1.25650038e-03, 6.17789552e-02, 1.82685739e-01, 2.17747937e-03,
#        0.00000000e+00, 0.00000000e+00, 2.23411789e-02, 1.52275967e-04,
#        1.53561774e-01, 2.16753040e-02, 7.12189807e-02])

# %%
L1__rfr_op_coefs = pd.DataFrame(rfr_op_coefs, index=X.columns)
# L1__rfr_op_coefs.rename(index={L1__rfr_op_coefs.index:'Feature Name'}, inplace = True)
L1__rfr_op_coefs.rename(columns={0:'coefs'}, inplace = True)
L1__rfr_op_coefs.sort_values(by='coefs', ascending=False).head(10)
# Out:
#                                                        coefs
# Applies to Commercial Generators                    0.182686
# Recycling Collection Frequency_Bi-weekly            0.153562
# Tip Fee as of 1/1/2020                              0.102856
# Annual Bulky Waste Limit                            0.100038
# Households Served by Municipal Recycling Program    0.079565
# Recycle Bin Size Ranking                            0.071219
# Applies to Residential Generators not Eligible ...  0.061779
# Does trash disposal tonnage include bulky waste?    0.046808
# Trash Service Type_Curbside                         0.044576
# Recycling Service Type_Both                         0.031947

# %% [markdown]
# #### Thoughts on Label 1
#
# None of the models produce a positive score. I'm not surprised by this because of the size of label 1 (35 municipalities). These are not a lot of data points so perhaps a fit is indeterminable or I'd need to seek other methods for small sample sizes that apply to tree-based models.
#
# I really don't want to even interpret the coefficients because the model fits are so poor. I don't think these coefficients mean much.

# %% [markdown]
# ### Label 2

# %%
L2_gs1, L2_gs2 = gs_models(l2_serve,'L2')
# Out:
# gridsearch rfr complete...
# gridsearch bagging complete...

# %%
gs_cv_results = pd.DataFrame(L2_gs1.cv_results_).sort_values(by='mean_test_score', ascending = False)
gs_cv_results.iloc[:,4:].head(5)
# gs_cv_results[gs_cv_results['mean_test_score'] > 0].iloc[:,4:]
# Out:
#    param_max_depth param_max_features param_max_samples param_n_estimators  \
# 37              10               0.75                 1                100
# 10               5               0.75                 1                100
# 55              20                  1                 1                100
# 46              10                0.5                 1                100
# 19               5                0.5                 1                100
#
#                                                params  split0_test_score  \
# 37  {'max_depth': 10, 'max_features': 0.75, 'max_s...          -0.014595
# 10  {'max_depth': 5, 'max_features': 0.75, 'max_sa...          -0.014595
# 55  {'max_depth': 20, 'max_features': 1.0, 'max_sa...          -0.014595
# 46  {'max_depth': 10, 'max_features': 0.5, 'max_sa...          -0.014595
# 19  {'max_depth': 5, 'max_features': 0.5, 'max_sam...          -0.014595
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 37          -0.202944          -0.240827        -0.152788        0.098934
# 10          -0.202944          -0.240827        -0.152788        0.098934
# 55          -0.202944          -0.240827        -0.152788        0.098934
# 46          -0.202944          -0.240827        -0.152788        0.098934
# 19          -0.202944          -0.240827        -0.152788        0.098934
#
#     rank_test_score
# 37                1
# 10                1
# 55                1
# 46                1
# 19                1

# %% [markdown]
# All the scores are negative and the top 5 are all identical. Which says to me that the onlyparameters that matters is the n_estimators of 100 and the max_samples should not be adjusted from the default.

# %%
gs_cv_results = pd.DataFrame(L2_gs2.cv_results_).sort_values(by='mean_test_score', ascending = False)
gs_cv_results.iloc[:,4:].head(5)
# gs_cv_results[gs_cv_results['mean_test_score'] > 0].iloc[:,4:]
# Out:
#    param_max_features param_max_samples param_n_estimators  \
# 17                0.5              0.33               1000
# 15                0.5              0.66               1000
# 11               0.75              0.33               1000
# 5                   1              0.33               1000
# 13                0.5                 1               1000
#
#                                                params  split0_test_score  \
# 17  {'max_features': 0.5, 'max_samples': 0.33, 'n_...          -0.022679
# 15  {'max_features': 0.5, 'max_samples': 0.66, 'n_...          -0.022802
# 11  {'max_features': 0.75, 'max_samples': 0.33, 'n...          -0.039092
# 5   {'max_features': 1.0, 'max_samples': 0.33, 'n_...          -0.069215
# 13  {'max_features': 0.5, 'max_samples': 1.0, 'n_e...          -0.030595
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 17          -0.023362          -0.013028        -0.019690        0.004719
# 15          -0.056910           0.020248        -0.019821        0.031570
# 11          -0.047360           0.014994        -0.023819        0.027652
# 5           -0.042947           0.037676        -0.024828        0.045480
# 13          -0.102056           0.024029        -0.036207        0.051627
#
#     rank_test_score
# 17                1
# 15                2
# 11                3
# 5                 4
# 13                5

# %% [markdown]
# The scores are all negative and the first two are very close. So it appears that a max_features of 0.5 is good along with n_estimators of 1000. Max_samples of 0.33 was technically best but I'm going to run 0.66 to see how it varies from the gs_bagging score.

# %%
serv_df = l2_serve
name = 'L2'

X = serv_df.drop(columns=['%recycle/hh', 'hc_label'])
y = serv_df['%recycle/hh']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 8)

rfr = RandomForestRegressor(n_estimators=100, random_state=8)
bagging = BaggingRegressor(max_samples= 0.66, max_features=0.5, n_estimators=1000, random_state=8)


rfr.fit(X_train,y_train)
score_train = rfr.score(X_train, y_train)
score_test = rfr.score(X_test, y_test)
rmse = mean_squared_error(y_test, rfr.predict(X_test), squared=False)
mae = mean_absolute_error(y_test, rfr.predict(X_test))
fit_results[name+'__rfr_op'] = (score_train, score_test, rmse, mae)
print('rfr complete...')


bagging.fit(X_train,y_train)
score_train = bagging.score(X_train, y_train)
score_test = bagging.score(X_test, y_test)
rmse = mean_squared_error(y_test, bagging.predict(X_test), squared=False)
mae = mean_absolute_error(y_test, bagging.predict(X_test))
fit_results[name+'__bagging_op'] = (score_train, score_test, rmse, mae)
print('bagging complete...')
# Out:
# rfr complete...
# bagging complete...

# %%
L2_results = pd.DataFrame(fit_results, index=['score_train', 'score_test', 'rmse', 'mae']).T.sort_index().iloc[16:]
L2_results.sort_values(by='score_test', ascending = False)
# Out:
#                 score_train  score_test      rmse       mae
# L2__rfr            0.812889    0.533310  0.052097  0.043196
# L2__rfr_op         0.812889    0.533310  0.052097  0.043196
# L2__bagging        0.800556    0.490688  0.054424  0.044869
# L2__boost          0.998540    0.445003  0.056812  0.046576
# L2__bagging_op     0.691152    0.270230  0.065146  0.051459
# L2__gs_bagging     0.438990    0.134465  0.070948  0.056917
# L2__gs_rfr        -0.001922   -0.094027  0.079764  0.064835
# L2__dummy          0.000000   -0.122624  0.080800  0.065204

# %%
rfr_op_coefs = np.mean([
    tree.feature_importances_ for tree in rfr.estimators_
], axis=0)
rfr_op_coefs
# Out:
# array([9.08943379e-03, 1.59472733e-03, 1.70409278e-01, 2.47664605e-02,
#        1.62476783e-02, 1.71147845e-01, 1.78668753e-03, 4.49210161e-03,
#        0.00000000e+00, 1.30722521e-02, 6.00570747e-03, 7.47402853e-03,
#        2.65995499e-02, 1.82622936e-02, 4.61070810e-05, 0.00000000e+00,
#        9.23721817e-03, 1.30606411e-02, 7.96852464e-03, 6.98531863e-03,
#        8.31208927e-03, 3.49712161e-03, 7.37308462e-02, 8.00701387e-02,
#        3.52222036e-03, 1.12175603e-02, 0.00000000e+00, 1.09244172e-01,
#        8.36288046e-03, 1.51875613e-02, 5.58862410e-02, 8.99465167e-03,
#        8.34357712e-03, 3.51523337e-03, 2.22434650e-03, 1.02904772e-02,
#        9.78305243e-03, 1.06017475e-02, 3.04373428e-02, 3.94722405e-03,
#        1.53399207e-02, 8.32479332e-03, 1.09209486e-02])

# %%
L2__rfr_op_coefs = pd.DataFrame(rfr_op_coefs, index=X.columns)
# L2__rfr_op_coefs.rename(index={L2__rfr_op_coefs.index:'Feature Name'}, inplace = True)
L2__rfr_op_coefs.rename(columns={0:'coefs'}, inplace = True)
L2__rfr_op_coefs.sort_values(by='coefs', ascending=False).head(10)
# Out:
#                                                      coefs
# PAYT/ SMART                                       0.171148
# What is the annual fee?                           0.170409
# Households Served by Municipal Recycling Program  0.109244
# Maximum # bags/ barrels per week                  0.080070
# Tip Fee as of 1/1/2020                            0.073731
# SS Recycling                                      0.055886
# # Hours Enforcement Personnel on Street           0.030437
# Business Trash and Recycling Service_Both         0.026600
# What is the transfer station access fee?          0.024766
# Non-resident Trash and Recycling Service_Both     0.018262

# %% [markdown]
# #### Thoughts on Label 2
#
# This label definitely has the best fit of the bunch with a test score of 0.533 and MAE of 0.043. I'm actually curious to see what the residuals look like from this model.

# %%
plt.scatter(y_test, rfr.predict(X_test));

# %% [markdown]
# Okay, so it looks like it had a hard time accurately predicting lower scoring municipalities, and for some reason there's a huge jump betweeb the second to highest point and the highest point. That is rather curious... but it seems like the model at least predicted the trend, which is what we're interested in for determing important features.
#
# Based on the coefficients, We still see a trend of funding and population being important but we have some more diversity in features: `Maximum # bags/ barrels per week` and `SS Recycling`.
#
# These coefficients may suggest that putting a limit on how much trash you can throw out per week and that having single stream recycle services is the most effective way to increase recycling. Also, in-terms of funding models, a Pay-As-You throw (PAY/SMART) model in addition to annual fees seem to yield better rates of recycling. `Tip Fee as of 1/1/2020` implies #TODO
#
# As for total households served, I'm guessing that smaller municipalities do not have the funds to support added features like enforcement. However, enforcement doesn't seem to be a very important feature, so I'm not sure what to make of recycle rate being tied to population.
