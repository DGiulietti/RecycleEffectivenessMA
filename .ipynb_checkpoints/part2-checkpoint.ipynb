# %% [markdown]
# # Recycling Effectiveness in MA
#
# ### *Part 2: Clustering of Municipalities Based on Census Data*

# %%
# imports

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.cluster.hierarchy as sch

from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans

# %%
# creating df for each group

groups = [
    'education_char',
    'economic_char',
    'housing_char',
    'demo_char'
]

for characteristic in groups:
    exec(f'{characteristic} = pd.read_csv("data/census_data/{characteristic}.csv")')

# %%
education_char.set_index('municipality', inplace = True)
education_char.head()
# Out:
#               population_25_and_older  edu_high_school_and_higher_%  \
# municipality
# Weymouth                        41855                          93.8
# Winthrop                        14263                          95.5
# Belchertown                      2017                          93.2
# Needham                         20559                          97.8
# Quincy                          73038                          88.2
#
#               edu_bachelors_and_higher_%
# municipality
# Weymouth                            39.2
# Winthrop                            38.3
# Belchertown                         40.5
# Needham                             76.0
# Quincy                              45.1

# %%
economic_char.set_index('municipality', inplace = True)
housing_char.set_index('municipality', inplace = True)
demo_char.set_index('municipality', inplace = True)

# %%
comb_char = pd.concat([education_char,economic_char,housing_char,demo_char], axis=1)
comb_char.head()
# Out:
#               population_25_and_older  edu_high_school_and_higher_%  \
# municipality
# Weymouth                        41855                          93.8
# Winthrop                        14263                          95.5
# Belchertown                      2017                          93.2
# Needham                         20559                          97.8
# Quincy                          73038                          88.2
#
#               edu_bachelors_and_higher_%  unemployment_rate  \
# municipality
# Weymouth                            39.2                5.8
# Winthrop                            38.3                3.6
# Belchertown                         40.5                4.4
# Needham                             76.0                4.0
# Quincy                              45.1                5.1
#
#               median_household_income  mean_household_income  \
# municipality
# Weymouth                        84942                 100858
# Winthrop                        74069                 102769
# Belchertown                     78578                  96836
# Needham                        165547                 223894
# Quincy                          77562                  94360
#
#               families_below_poverty_level_%  people_below_poverty_level_%  \
# municipality
# Weymouth                                 4.3                           6.0
# Winthrop                                 5.4                           8.8
# Belchertown                              3.7                           9.3
# Needham                                  1.4                           2.7
# Quincy                                   8.0                          11.3
#
#               Total housing units  occupancy_%  ...  renter-occupied_%  \
# municipality                                    ...
# Weymouth                    24570         96.6  ...               33.0
# Winthrop                     8367         93.6  ...               44.1
# Belchertown                  1224         92.9  ...               31.6
# Needham                     11309         95.5  ...               16.1
# Quincy                      43736         94.2  ...               53.8
#
#               males-to-100females  median_age  demo_white_%  demo_black_aa_%  \
# municipality
# Weymouth                     90.4        42.4          85.7              6.3
# Winthrop                     88.3        44.9          95.0              3.7
# Belchertown                  99.0        42.0          92.9              1.5
# Needham                      92.2        43.5          87.4              3.4
# Quincy                       94.5        39.7          62.7              5.8
#
#               demo_american_indian_%  demo_asian_%  demo_native_islander%  \
# municipality
# Weymouth                         0.3           7.5                    0.2
# Winthrop                         0.2           1.3                    0.0
# Belchertown                      0.0           9.2                    0.0
# Needham                          0.3          10.6                    0.0
# Quincy                           0.4          31.4                    0.3
#
#               demo_other_Race_%  demo_hispanic_latino_%
# municipality
# Weymouth                    1.8                     3.8
# Winthrop                    1.9                     9.5
# Belchertown                 0.0                     5.2
# Needham                     0.7                     3.2
# Quincy                      1.4                     3.1
#
# [5 rows x 30 columns]

# %%
kmeans = KMeans(n_clusters=6)
kmeans.fit(comb_char)
# Out:
# KMeans(n_clusters=6)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 2.05590000e+04,  9.78000000e+01,  7.60000000e+01,
#          4.00000000e+00,  1.65547000e+05,  2.23894000e+05,
#          1.40000000e+00,  2.70000000e+00,  1.13090000e+04,
#          9.55000000e+01,  7.64000000e+01,  5.40000000e+00,
#          3.80000000e+00,  1.60000000e+00,  2.20000000e+00,
#          1.60000000e+00,  8.90000000e+00,  0.00000000e+00,
#          0.00000000e+00,  8.39000000e+01,  1.61000000e+01,
#          9.22000000e+01,  4.35000000e+01,  8.74000000e+01,
#          3.40000000e+00,  3.00000000e-01,  1.06000000e+01,
#          0.00000000e+00,  7.00000000e-01,  3.20000000e+00],
#        [ 3.40000000e+01,  1.00000000e+02,  7.65000000e+01,
#          0.00000000e+00, -6.66666666e+08, -9.99999999e+08,
#          0.00000000e+00,  0.00000000e+00,  4.70000000e+01,
#          3.62000000e+01,  1.00000000e+02,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+02,  0.00000000e+00,
#          1.00000000e+02,  8.11000000e+01,  1.00000000e+02,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 1.12000000e+02,  1.00000000e+02,  6.88000000e+01,
#          0.00000000e+00, -6.66666666e+08,  3.85690000e+04,
#          4.72000000e+01,  4.40000000e+01,  4.51000000e+02,
#          1.55000000e+01,  9.36000000e+01,  0.00000000e+00,
#          0.00000000e+00,  6.40000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  8.57000000e+01,  1.43000000e+01,
#          1.54200000e+02,  6.23000000e+01,  1.00000000e+02,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 3.46200000e+03,  8.80000000e+01,  2.88000000e+01,
#          4.60000000e+00,  7.06920000e+04,  7.76610000e+04,
#          9.10000000e+00,  1.17000000e+01,  2.12300000e+03,
#          9.44000000e+01,  6.72000000e+01,  8.00000000e-01,
#          1.00000000e+00,  5.50000000e+00,  3.50000000e+00,
#          1.00000000e+01,  1.21000000e+01,  0.00000000e+00,
#          0.00000000e+00,  6.19000000e+01,  3.81000000e+01,
#          8.99000000e+01,  4.62000000e+01,  9.74000000e+01,
#          1.90000000e+00,  1.00000000e-01,  2.00000000e+00,
#          0.00000000e+00,  5.00000000e-01,  1.00000000e-01],
#        [ 4.73775000e+05,  8.72000000e+01,  4.97000000e+01,
#          6.60000000e+00,  7.11150000e+04,  1.07608000e+05,
#          1.41000000e+01,  1.89000000e+01,  2.94418000e+05,
#          9.15000000e+01,  1.19000000e+01,  6.30000000e+00,
#          1.34000000e+01,  2.42000000e+01,  1.10000000e+01,
#          7.70000000e+00,  2.53000000e+01,  1.00000000e-01,
#          0.00000000e+00,  3.50000000e+01,  6.50000000e+01,
#          9.23000000e+01,  3.22000000e+01,  5.74000000e+01,
#          2.89000000e+01,  9.00000000e-01,  1.07000000e+01,
#          2.00000000e-01,  7.40000000e+00,  1.98000000e+01],
#        [ 2.77200000e+03,  9.70000000e+01,  5.72000000e+01,
#          2.50000000e+00,  9.77780000e+04,  1.38334000e+05,
#          1.90000000e+00,  2.40000000e+00,  1.72400000e+03,
#          9.29000000e+01,  6.95000000e+01,  1.20000000e+00,
#          1.12000000e+01,  3.90000000e+00,  6.80000000e+00,
#          3.80000000e+00,  3.60000000e+00,  0.00000000e+00,
#          0.00000000e+00,  7.05000000e+01,  2.95000000e+01,
#          8.66000000e+01,  5.23000000e+01,  9.68000000e+01,
#          1.00000000e-01,  5.00000000e-01,  2.50000000e+00,
#          0.00000000e+00,  1.00000000e+00,  1.50000000e+00]])

# %%
pd.Series(kmeans.labels_).value_counts()
# Out:
# 3    146
# 5     79
# 0     15
# 2      2
# 1      2
# 4      1
# dtype: int64

# %%
comb_char['label'] = kmeans.labels_

# %%
comb_stats = comb_char.describe().T

# %%
stats0 = comb_char[comb_char['label'] == 0].describe().T

# %%
stats3 = comb_char[comb_char['label'] == 3].describe().T
stats4 = comb_char[comb_char['label'] == 4].describe().T

# %%
sub = 100*(comb_stats - stats3) / comb_stats

# %%
sub.drop(columns=['count', 'std', 'min', 'max'], inplace=True)
sub.head()
# Out:
#                                     mean        25%        50%        75%
# population_25_and_older         6.890073   5.234029   4.237787  12.452022
# edu_high_school_and_higher_%    2.192263   2.588106   2.375924   2.361396
# edu_bachelors_and_higher_%     22.519978  19.531250  25.471698  23.194946
# unemployment_rate             -10.521033 -20.000000 -14.634146  -5.263158
# median_household_income       100.601291  11.238981  16.031052  23.232110

# %%
sub.style.background_gradient(cmap='Blues')
# Out:
# C:\Users\nanai\anaconda3\lib\site-packages\pandas\io\formats\style.py:1093: RuntimeWarning: invalid value encountered in double_scalars
#   norm = colors.Normalize(smin - (rng * low), smax + (rng * high))
# <style  type="text/css" >
#     #T_c2bb431f_6586_11eb_920e_5cf3709e0882row0_col0 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row0_col2 {
#             background-color:  #2a7ab9;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row0_col3 {
#             background-color:  #105ba4;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row1_col0 {
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row1_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row1_col2 {
#             background-color:  #3080bd;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row1_col3 {
#             background-color:  #1c6bb0;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row2_col0 {
#             background-color:  #6aaed6;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row2_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row2_col3 {
#             background-color:  #084b93;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row3_col0 {
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row3_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row3_col2 {
#             background-color:  #79b5d9;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row3_col3 {
#             background-color:  #2777b8;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row4_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row4_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row4_col2 {
#             background-color:  #08519c;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row4_col3 {
#             background-color:  #084b93;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row5_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row5_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row5_col2 {
#             background-color:  #105ba4;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row5_col3 {
#             background-color:  #084b93;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row6_col0 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row6_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row6_col2 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row6_col3 {
#             background-color:  #66abd4;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row7_col0 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row7_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row7_col2 {
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row7_col3 {
#             background-color:  #3888c1;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row8_col0 {
#             background-color:  #99c7e0;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row8_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row8_col2 {
#             background-color:  #3e8ec4;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row8_col3 {
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row9_col0 {
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row9_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row9_col2 {
#             background-color:  #3181bd;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row9_col3 {
#             background-color:  #1e6db2;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row10_col0 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row10_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row10_col2 {
#             background-color:  #1967ad;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row10_col3 {
#             background-color:  #1865ac;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row11_col0 {
#             background-color:  #84bcdb;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row11_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row11_col2 {
#             background-color:  #0c56a0;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row11_col3 {
#             background-color:  #1c6ab0;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row12_col0 {
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row12_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row12_col2 {
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row12_col3 {
#             background-color:  #2c7cba;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row13_col0 {
#             background-color:  #ccdff1;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row13_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row13_col2 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row13_col3 {
#             background-color:  #3888c1;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row14_col0 {
#             background-color:  #cddff1;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row14_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row14_col2 {
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }    #T_c2bb431f_6586_11eb_920e_5cf3709e0882row14_col3 {
#             background-color:  #4292c6;

# %% [markdown]
# Checking the smaller groups manually for key features.

# %%
comb_char[comb_char['label'] == 1]
# Out:
#                      population_25_and_older  edu_high_school_and_higher_%  \
# municipality
# Seconsett Island                          40                         100.0
# Popponesset Island                        34                         100.0
#
#                      edu_bachelors_and_higher_%  unemployment_rate  \
# municipality
# Seconsett Island                           22.5                0.0
# Popponesset Island                         76.5                0.0
#
#                      median_household_income  mean_household_income  \
# municipality
# Seconsett Island                  -666666666             -999999999
# Popponesset Island                -666666666             -999999999
#
#                      families_below_poverty_level_%  \
# municipality
# Seconsett Island                                0.0
# Popponesset Island                              0.0
#
#                      people_below_poverty_level_%  Total housing units  \
# municipality
# Seconsett Island                              0.0                   77
# Popponesset Island                            0.0                   47
#
#                      occupancy_%  ...  males-to-100females  median_age  \
# municipality                      ...
# Seconsett Island            24.7  ...                 90.5        37.9
# Popponesset Island          36.2  ...                100.0        81.1
#
#                      demo_white_%  demo_black_aa_%  demo_american_indian_%  \
# municipality
# Seconsett Island            100.0              0.0                     0.0
# Popponesset Island          100.0              0.0                     0.0
#
#                      demo_asian_%  demo_native_islander%  demo_other_Race_%  \
# municipality
# Seconsett Island              0.0                    0.0                0.0
# Popponesset Island            0.0                    0.0                0.0
#
#                      demo_hispanic_latino_%  label
# municipality
# Seconsett Island                        0.0      1
# Popponesset Island                      0.0      1
#
# [2 rows x 31 columns]

# %% [markdown]
# these are small summer retreat type towns. I doubt I even have data on them. will probably remove

# %%
comb_char[comb_char['label'] == 2]
# Out:
#               population_25_and_older  edu_high_school_and_higher_%  \
# municipality
# Popponesset                       112                         100.0
# Deerfield                         311                          98.4
#
#               edu_bachelors_and_higher_%  unemployment_rate  \
# municipality
# Popponesset                         68.8                0.0
# Deerfield                           74.6                8.1
#
#               median_household_income  mean_household_income  \
# municipality
# Popponesset                -666666666                  38569
# Deerfield                  -666666666                  90963
#
#               families_below_poverty_level_%  people_below_poverty_level_%  \
# municipality
# Popponesset                             47.2                          44.0
# Deerfield                                0.0                          38.9
#
#               Total housing units  occupancy_%  ...  males-to-100females  \
# municipality                                    ...
# Popponesset                   451         15.5  ...                154.2
# Deerfield                     155        100.0  ...                121.0
#
#               median_age  demo_white_%  demo_black_aa_%  \
# municipality
# Popponesset         62.3         100.0              0.0
# Deerfield           40.0          76.3             28.8
#
#               demo_american_indian_%  demo_asian_%  demo_native_islander%  \
# municipality
# Popponesset                      0.0           0.0                    0.0
# Deerfield                        0.0           9.0                    0.0
#
#               demo_other_Race_%  demo_hispanic_latino_%  label
# municipality
# Popponesset                 0.0                     0.0      2
# Deerfield                   1.3                     9.5      2
#
# [2 rows x 31 columns]

# %% [markdown]
# Very low populations again but this time with high poverty. Both also appears to have a missing input for median income.

# %%
comb_char[comb_char['label'] == 5]
# Out:
#                       population_25_and_older  edu_high_school_and_higher_%  \
# municipality
# Abington                                11793                          94.7
# Kingston                                 4261                          97.3
# Mattapoisett Center                      2482                          98.4
# Cambridge                               79240                          95.5
# Pinehurst                                5229                          91.8
# ...                                       ...                           ...
# Madaket                                   255                         100.0
# The Pinehills                            1391                          98.8
# Upton                                    1806                          97.7
# Watertown                               27845                          95.0
# Hanscom AFB                               998                          99.8
#
#                       edu_bachelors_and_higher_%  unemployment_rate  \
# municipality
# Abington                                    39.1                4.3
# Kingston                                    39.7                2.5
# Mattapoisett Center                         50.0                2.9
# Cambridge                                   79.0                4.0
# Pinehurst                                   33.0                4.7
# ...                                          ...                ...
# Madaket                                     53.7               10.8
# The Pinehills                               69.8                4.5
# Upton                                       50.7                4.9
# Watertown                                   65.9                3.5
# Hanscom AFB                                 57.3                4.9
#
#                       median_household_income  mean_household_income  \
# municipality
# Abington                                99381                 105390
# Kingston                                90754                 110433
# Mattapoisett Center                     93826                 159992
# Cambridge                              103154                 139991
# Pinehurst                              107159                 124086
# ...                                       ...                    ...
# Madaket                                101563                 127276
# The Pinehills                          101518                 146590
# Upton                                   89507                 120387
# Watertown                              101103                 124756
# Hanscom AFB                            108056                 110557
#
#                       families_below_poverty_level_%  \
# municipality
# Abington                                         2.5
# Kingston                                         1.2
# Mattapoisett Center                              1.9
# Cambridge                                        7.3
# Pinehurst                                        2.6
# ...                                              ...
# Madaket                                          0.0
# The Pinehills                                    0.0
# Upton                                            0.0
# Watertown                                        4.9
# Hanscom AFB                                      0.0
#
#                       people_below_poverty_level_%  Total housing units  \
# municipality
# Abington                                       4.1                 6781
# Kingston                                       3.0                 2748
# Mattapoisett Center                            2.8                 1819
# Cambridge                                     12.7                51882
# Pinehurst                                      4.0                 2536
# ...                                            ...                  ...
# Madaket                                       21.9                  650
# The Pinehills                                  4.9                  874
# Upton                                          2.6                 1053
# Watertown                                      7.6                16570
# Hanscom AFB                                    0.0                  577
#
#                       occupancy_%  ...  males-to-100females  median_age  \
# municipality                       ...
# Abington                     94.3  ...                 97.7        42.2
# Kingston                     88.8  ...                 99.4        41.9
# Mattapoisett Center          76.5  ...                 88.7        52.1
# Cambridge                    90.3  ...                 99.4        30.5
# Pinehurst                    96.0  ...                105.2        42.3
# ...                           ...  ...                  ...         ...
# Madaket                      17.4  ...                 82.7        51.3
# The Pinehills                94.4  ...                 67.1        68.9
# Upton                        91.1  ...                137.0        47.9
# Watertown                    94.3  ...                 87.5        38.2
# Hanscom AFB                  96.0  ...                124.2        24.4
#
#                       demo_white_%  demo_black_aa_%  demo_american_indian_%  \
# municipality
# Abington                      93.2              3.0                     0.3
# Kingston                      99.1              2.4                     0.0
# Mattapoisett Center           98.3              0.0                     0.5
# Cambridge                     70.0             12.2                     0.8
# Pinehurst                     88.2              4.5                     0.2
# ...                            ...              ...                     ...
# Madaket                      100.0              0.0                     0.0
# The Pinehills                 94.5              0.0                     0.0
# Upton                         97.9              2.4                     0.0
# Watertown                     85.1              2.5                     0.4
# Hanscom AFB                   84.0              5.9                     0.0
#
#                       demo_asian_%  demo_native_islander%  demo_other_Race_%  \
# municipality
# Abington                       4.9                    0.0                1.4
# Kingston                       0.0                    0.0                0.9
# Mattapoisett Center            0.0                    0.0                1.7
# Cambridge                     19.1                    0.2                2.4
# Pinehurst                      9.8                    0.0                0.5
# ...                            ...                    ...                ...
# Madaket                        0.0                    0.0                0.0
# The Pinehills                  5.5                    0.0                0.0
# Upton                          0.0                    0.0                0.7
# Watertown                     11.3                    0.3                3.4
# Hanscom AFB                   16.0                    0.0                0.2
#
#                       demo_hispanic_latino_%  label
# municipality
# Abington                                 2.6      5
# Kingston                                 5.3      5
# Mattapoisett Center                      2.9      5
# Cambridge                                9.5      5
# Pinehurst                                1.8      5
# ...                                      ...    ...
# Madaket                                  0.0      5
# The Pinehills                            0.0      5
# Upton                                    7.9      5
# Watertown                                9.2      5
# Hanscom AFB                             13.7      5
#
# [79 rows x 31 columns]

# %% [markdown]
# Ah... can't remove Boston. But yes, it is the highest population by far.

# %%
mudata= pd.read_csv('data/MA_MSW_Collection_Data/musum19.csv', index_col='Municipality Name')

# %%
mudata.loc['Boston']
# Out:
# tot_households               310800
# stream_type                      ss
# tons_ss_recyclables           37050
# tons_ms_recyclables               0
# tons_recyclables_total        37050
# hh_served_by_mu_recycle      260000
# tons_recyclables/hh          0.1425
# hh_served_by_mu_trash        260000
# tons_trash_total             188113
# tons_trash/hh              0.723512
# %recycle/hh                0.164547
# total_waste/hh             0.866012
# Name: Boston, dtype: object

# %%
muns = list(mudata.index)

# %%
outliers = ['Popponesset', 'Deerfield', 'Seconsett Island', 'Popponesset Island', 'Boston']

# %%
for place in outliers:
    print(f"{place} in mun list: {place in muns}")
# Out:
# Popponesset in mun list: False
# Deerfield in mun list: True
# Seconsett Island in mun list: False
# Popponesset Island in mun list: False
# Boston in mun list: True

# %% [markdown]
# okay, I'm going to remove the 3 False values, fix the missing mean income value for Deerfield, and then repeat the kMeans Clustering. Also will remove non-relevant columns: Population of 25 years and older, % with HS edu, M:F, Med Age, and % white.

# %%
comb_char.columns
# Out:
# Index(['population_25_and_older', 'edu_high_school_and_higher_%',
#        'edu_bachelors_and_higher_%', 'unemployment_rate',
#        'median_household_income', 'mean_household_income',
#        'families_below_poverty_level_%', 'people_below_poverty_level_%',
#        'Total housing units', 'occupancy_%', '1-unit_detached_%',
#        '1-unit_attached_%', '2-units_%', '3-4_units_%', '5-9_units_%',
#        '10-19_units_%', '20+_units_%', 'mobile_home_%', 'boat_RV_van_%',
#        'owner-occupied_%', 'renter-occupied_%', 'males-to-100females',
#        'median_age', 'demo_white_%', 'demo_black_aa_%',
#        'demo_american_indian_%', 'demo_asian_%', 'demo_native_islander%',
#        'demo_other_Race_%', 'demo_hispanic_latino_%', 'label'],
#       dtype='object')

# %%
comb_char_clean = comb_char.drop(columns=['population_25_and_older','edu_high_school_and_higher_%','males-to-100females','median_age', 'demo_white_%'], 
                                 index=['Popponesset ', 'Seconsett Island ', 'Popponesset Island '])

# %%
comb_char_clean.at['Deerfield ', 'median_household_income',] = comb_char_clean.loc['Deerfield ']['mean_household_income']
comb_char_clean.loc['Deerfield ']['median_household_income']
# Out:
# 90963.0

# %%
kmeans2 = KMeans(n_clusters=6)
kmeans2.fit(comb_char_clean)
# Out:
# KMeans(n_clusters=6)

# %%
pd.Series(kmeans2.labels_).value_counts()
# Out:
# 4    80
# 0    65
# 2    52
# 5    32
# 1    12
# 3     1
# dtype: int64

# %%
comb_char_clean['label'] = kmeans2.labels_

# %%
comb_char_clean[comb_char_clean['label'] == 3]
# Out:
#               edu_bachelors_and_higher_%  unemployment_rate  \
# municipality
# Boston                              49.7                6.6
#
#               median_household_income  mean_household_income  \
# municipality
# Boston                          71115                 107608
#
#               families_below_poverty_level_%  people_below_poverty_level_%  \
# municipality
# Boston                                  14.1                          18.9
#
#               Total housing units  occupancy_%  1-unit_detached_%  \
# municipality
# Boston                     294418         91.5               11.9
#
#               1-unit_attached_%  ...  boat_RV_van_%  owner-occupied_%  \
# municipality                     ...
# Boston                      6.3  ...            0.0              35.0
#
#               renter-occupied_%  demo_black_aa_%  demo_american_indian_%  \
# municipality
# Boston                     65.0             28.9                     0.9
#
#               demo_asian_%  demo_native_islander%  demo_other_Race_%  \
# municipality
# Boston                10.7                    0.2                7.4
#
#               demo_hispanic_latino_%  label
# municipality
# Boston                          19.8      3
#
# [1 rows x 26 columns]

# %%
centers2 = pd.DataFrame(kmeans2.cluster_centers_).T
centers2['features'] = comb_char_clean.columns
centers2.set_index('features', inplace = True)
centers2
# Out:
#                                            0              1              2  \
# features
# edu_bachelors_and_higher_%         27.366154      76.658333      49.650000
# unemployment_rate                   6.069231       4.008333       3.946154
# median_household_income         52633.523077  174049.833333   96233.500000
# mean_household_income           69762.938462  240043.833333  119343.115385
# families_below_poverty_level_%      9.532308       1.466667       3.171154
# people_below_poverty_level_%       13.523077       2.483333       6.155769
# Total housing units             10428.046154    6888.083333    7063.057692
# occupancy_%                        83.392308      95.733333      87.648077
# 1-unit_detached_%                  50.966154      83.950000      63.209615
# 1-unit_attached_%                   3.450769       4.125000       6.207692
# 2-units_%                          12.598462       3.758333       8.340385
# 3-4_units_%                        13.083077       1.675000       6.628846
# 5-9_units_%                         7.398462       1.250000       4.513462
# 10-19_units_%                       3.853846       1.116667       3.428846
# 20+_units_%                         6.767692       3.866667       7.482692
# mobile_home_%                       1.833846       0.250000       0.190385
# boat_RV_van_%                       0.049231       0.000000       0.019231
# owner-occupied_%                   56.298462      87.450000      70.842308
# renter-occupied_%                  43.701538      12.550000      29.157692
# demo_black_aa_%                     6.852308       1.625000       3.363462
# demo_american_indian_%              0.883077       0.458333       0.615385
# demo_asian_%                        3.078462      12.000000       5.007692
# demo_native_islander%               0.178462       0.075000       0.090385
# demo_other_Race_%                   5.329231       0.658333       1.403846
# demo_hispanic_latino_%             11.972308       2.341667       4.307692
# label                               3.000000       0.000000       4.923077
#
#                                        3            4              5
# features
# edu_bachelors_and_higher_%          49.7     38.38000      62.187500
# unemployment_rate                    6.6      4.24875       3.859375
# median_household_income          71115.0  74593.66250  119182.125000
# mean_household_income           107608.0  93259.25000  157997.281250
# families_below_poverty_level_%      14.1      4.71375       2.521875
# people_below_poverty_level_%        18.9      8.17625       5.250000
# Total housing units             294418.0   6150.67500    4910.156250
# occupancy_%                         91.5     82.11625      85.362500
# 1-unit_detached_%                   11.9     66.24500      74.325000
# 1-unit_attached_%                    6.3      4.75750       6.053125
# 2-units_%                           13.4      7.11250       4.228125
# 3-4_units_%                         24.2      6.77750       4.525000
# 5-9_units_%                         11.0      4.54750       2.806250
# 10-19_units_%                        7.7      3.32500       1.843750
# 20+_units_%                         25.3      6.07250       6.146875
# mobile_home_%                        0.1      1.13500       0.087500
# boat_RV_van_%                        0.0      0.01875       0.003125
# owner-occupied_%                    35.0     69.81750      80.015625
# renter-occupied_%                   65.0     30.18250      19.984375
# demo_black_aa_%                     28.9      4.82500       2.809375
# demo_american_indian_%               0.9      0.73250       0.337500
# demo_asian_%                        10.7      3.51250       5.696875
# demo_native_islander%                0.2      0.15250       0.068750
# demo_other_Race_%                    7.4      2.60375       1.100000
# demo_hispanic_latino_%              19.8      5.64000       2.996875
# label                                4.0      2.98750       4.531250
