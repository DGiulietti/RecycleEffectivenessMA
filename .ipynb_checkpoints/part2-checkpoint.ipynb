# %% [markdown]
# # Recycling Effectiveness in MA
#
# ### *Part 2: Clustering of Municipalities Based on Census Data*

# %%
# add in DBScan as a clustering mechanism
# you MUST normalize your features for PCA, so redo that:
## https://stats.stackexchange.com/questions/69157/why-do-we-need-to-normalize-data-before-principal-component-analysis-pca#:~:text=2%20Answers&text=Normalization%20is%20important%20in%20PCA,have%20not%20normalized%20the%20data.
# check heatmap again for correlation with scaled data, see if there are different trends indicating which to remove
# when re-running PCA, remove pre-selected correlated datapoints, even if heatmap shows nothing. Just explain your decision
# After running PCA, retry the 3 clustering algorithms with the trimmed features for PCA, and further trimming based on feature importance (must be >5% in at least one Z), and see how they change.
# With the new and old cluster labels, try 3 dimensional plotting of Z1, Z2, and Z3 with color overlay of labels for each clustering model

# %%
# imports

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.cluster.hierarchy as sch

from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans

# %%
characteristics = pd.read_csv('data/combined_municipality_characteristics.csv', index_col='municipality')

# %%
characteristics.head(2)
# Out:
#               KEY_population_25_and_older  edu_high_school_and_higher_%  \
# municipality
# Sharon                               3833                          98.4
# Southbridge                         11439                          82.6
#
#               edu_bachelors_and_higher_%  KEY_pop_16_+  unemployment_rate_%  \
# municipality
# Sharon                              72.9          4443                  4.5
# Southbridge                         17.2         13614                  8.8
#
#               median_household_income  mean_household_income  \
# municipality
# Sharon                         144333                 173768
# Southbridge                     51270                  64448
#
#               families_below_poverty_level_%  people_below_poverty_level_%  \
# municipality
# Sharon                                   0.0                           2.0
# Southbridge                             16.7                          20.7
#
#               KEY_total_housing_units  ...  demo_black_aa_%  \
# municipality                           ...
# Sharon                           2195  ...              1.4
# Southbridge                      7368  ...              5.3
#
#               demo_american_indian_%  demo_asian_%  demo_native_islander%  \
# municipality
# Sharon                           0.5          10.3                    0.0
# Southbridge                      1.6           0.5                    0.1
#
#               demo_other_Race_%  demo_hispanic_latino_%  dem%  rep%  un%  \
# municipality
# Sharon                      1.5                     2.8    32     7   60
# Southbridge                10.9                    32.9    31    10   57
#
#               total_waste/hh
# municipality
# Sharon              1.161119
# Southbridge         0.934264
#
# [2 rows x 36 columns]

# %%
characteristics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 271 entries, Sharon to Yarmouth
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   KEY_population_25_and_older     271 non-null    int64
#  1   edu_high_school_and_higher_%    271 non-null    float64
#  2   edu_bachelors_and_higher_%      271 non-null    float64
#  3   KEY_pop_16_+                    271 non-null    int64
#  4   unemployment_rate_%             271 non-null    float64
#  5   median_household_income         271 non-null    int64
#  6   mean_household_income           271 non-null    int64
#  7   families_below_poverty_level_%  271 non-null    float64
#  8   people_below_poverty_level_%    271 non-null    float64
#  9   KEY_total_housing_units         271 non-null    int64
#  10  occupancy_%                     271 non-null    float64
#  11  1-unit_detached_%               271 non-null    float64
#  12  1-unit_attached_%               271 non-null    float64
#  13  2-units_%                       271 non-null    float64
#  14  3-4_units_%                     271 non-null    float64
#  15  5-9_units_%                     271 non-null    float64
#  16  10-19_units_%                   271 non-null    float64
#  17  20+_units_%                     271 non-null    float64
#  18  mobile_home_%                   271 non-null    float64
#  19  boat_RV_van_%                   271 non-null    float64
#  20  owner-occupied_%                271 non-null    float64
#  21  renter-occupied_%               271 non-null    float64
#  22  KEY_total_population            271 non-null    int64
#  23  males-to-100females             271 non-null    float64
#  24  median_age                      271 non-null    float64
#  25  demo_white_%                    271 non-null    float64
#  26  demo_black_aa_%                 271 non-null    float64
#  27  demo_american_indian_%          271 non-null    float64
#  28  demo_asian_%                    271 non-null    float64
#  29  demo_native_islander%           271 non-null    float64
#  30  demo_other_Race_%               271 non-null    float64
#  31  demo_hispanic_latino_%          271 non-null    float64
#  32  dem%                            271 non-null    int64
#  33  rep%                            271 non-null    int64
#  34  un%                             271 non-null    int64
#  35  total_waste/hh                  267 non-null    float64
# dtypes: float64(27), int64(9)
# memory usage: 78.3+ KB

# %%
characteristics[~(characteristics >= 0).all(1)].T
# Out:
# municipality                       Deerfield  Westminster  Lanesborough  \
# KEY_population_25_and_older     3.110000e+02       5620.0        1834.0
# edu_high_school_and_higher_%    9.840000e+01         95.7          94.3
# edu_bachelors_and_higher_%      7.460000e+01         40.4          39.9
# KEY_pop_16_+                    5.390000e+02       6237.0        2004.0
# unemployment_rate_%             8.100000e+00          4.6           8.1
# median_household_income        -6.666667e+08     100972.0       67625.0
# mean_household_income           9.096300e+04     118373.0       80318.0
# families_below_poverty_level_%  0.000000e+00          1.0           2.6
# people_below_poverty_level_%    3.890000e+01          2.6           8.1
# KEY_total_housing_units         1.550000e+02       3080.0        1558.0
# occupancy_%                     1.000000e+02         93.2          66.5
# 1-unit_detached_%               7.420000e+01         91.4          69.0
# 1-unit_attached_%               0.000000e+00          1.8           1.8
# 2-units_%                       1.680000e+01          0.7           6.0
# 3-4_units_%                     9.000000e+00          3.8           1.9
# 5-9_units_%                     0.000000e+00          0.6           9.3
# 10-19_units_%                   0.000000e+00          1.8           3.6
# 20+_units_%                     0.000000e+00          0.0           6.9
# mobile_home_%                   0.000000e+00          0.0           1.4
# boat_RV_van_%                   0.000000e+00          0.0           0.0
# owner-occupied_%                5.810000e+01         90.9          83.0
# renter-occupied_%               4.190000e+01          9.1          17.0
# KEY_total_population            6.210000e+02       7766.0        2488.0
# males-to-100females             1.210000e+02        100.6         102.6
# median_age                      4.000000e+01         44.3          51.2
# demo_white_%                    7.630000e+01         99.8          97.3
# demo_black_aa_%                 2.880000e+01          0.0           2.3
# demo_american_indian_%          0.000000e+00          0.0           0.3
# demo_asian_%                    9.000000e+00          0.5           0.2
# demo_native_islander%           0.000000e+00          0.0           0.0
# demo_other_Race_%               1.300000e+00          0.0           0.7
# demo_hispanic_latino_%          9.500000e+00          3.3           0.8
# dem%                            3.100000e+01         17.0          26.0
# rep%                            9.000000e+00         15.0          10.0
# un%                             5.900000e+01         65.0          62.0
# total_waste/hh                  6.857707e-01          NaN           NaN
#
# municipality                    Wareham  Leicester
# KEY_population_25_and_older      7601.0     4519.0
# edu_high_school_and_higher_%       92.6       91.3
# edu_bachelors_and_higher_%         28.7       29.4
# KEY_pop_16_+                     8456.0     5671.0
# unemployment_rate_%                 4.5        3.7
# median_household_income         63805.0    81042.0
# mean_household_income           78138.0    95204.0
# families_below_poverty_level_%      8.2        5.8
# people_below_poverty_level_%       11.7        8.1
# KEY_total_housing_units          5467.0     2542.0
# occupancy_%                        76.6       96.5
# 1-unit_detached_%                  79.1       77.9
# 1-unit_attached_%                   3.5        2.1
# 2-units_%                           2.2        3.1
# 3-4_units_%                         3.4        0.7
# 5-9_units_%                         4.7        3.2
# 10-19_units_%                       1.3        4.3
# 20+_units_%                         3.3        7.6
# mobile_home_%                       2.6        1.1
# boat_RV_van_%                       0.0        0.0
# owner-occupied_%                   64.6       75.8
# renter-occupied_%                  35.4       24.2
# KEY_total_population            10608.0     6654.0
# males-to-100females                88.4       89.4
# median_age                         43.5       42.3
# demo_white_%                       89.0       96.8
# demo_black_aa_%                     8.4        3.4
# demo_american_indian_%              3.1        0.1
# demo_asian_%                        1.3        1.2
# demo_native_islander%               0.8        0.1
# demo_other_Race_%                   5.2        0.0
# demo_hispanic_latino_%              4.1        2.4
# dem%                               23.0       24.0
# rep%                               12.0       11.0
# un%                                63.0       64.0
# total_waste/hh                      NaN        NaN

# %% [markdown]
# I'm not sure how the clustering will work with the NaN values in the four municipalities with no total_waste/hh information. Unfortunately, these locations did not have any trash data recorded, so I couldn't get an accurate picture of how much waste they generate. I think I'll try imputing these values or simply remove them before running the algorithms. They aren't towns with a lot of data anyways.
#
# The one thing I definitely need to fix right away is the median household income for Deerfield. I think in the census data, if they are missing information, they input a very large negative number. So it's artificially messing up my stats. I'm going to apply the mean household income for Deerfield to it's median income, as this is the best approximation that I have. It is a small town so hopefully the median wouldn't be too far from the mean.

# %%
characteristics.at['Deerfield', 'median_household_income',] = characteristics.loc['Deerfield']['mean_household_income']
characteristics.loc['Deerfield']['median_household_income']
# Out:
# 90963.0

# %%
from sklearn.impute import KNNImputer

# %%
to_impute = characteristics[~(characteristics >= 0).all(1)].index

# %%
knni = KNNImputer()
characteristics_im = characteristics.copy()
characteristics_im.loc[:,:] = knni.fit_transform(characteristics)

# %%
characteristics_im.loc[to_impute]
# Out:
#               KEY_population_25_and_older  edu_high_school_and_higher_%  \
# municipality
# Westminster                        5620.0                          95.7
# Lanesborough                       1834.0                          94.3
# Wareham                            7601.0                          92.6
# Leicester                          4519.0                          91.3
#
#               edu_bachelors_and_higher_%  KEY_pop_16_+  unemployment_rate_%  \
# municipality
# Westminster                         40.4        6237.0                  4.6
# Lanesborough                        39.9        2004.0                  8.1
# Wareham                             28.7        8456.0                  4.5
# Leicester                           29.4        5671.0                  3.7
#
#               median_household_income  mean_household_income  \
# municipality
# Westminster                  100972.0               118373.0
# Lanesborough                  67625.0                80318.0
# Wareham                       63805.0                78138.0
# Leicester                     81042.0                95204.0
#
#               families_below_poverty_level_%  people_below_poverty_level_%  \
# municipality
# Westminster                              1.0                           2.6
# Lanesborough                             2.6                           8.1
# Wareham                                  8.2                          11.7
# Leicester                                5.8                           8.1
#
#               KEY_total_housing_units  ...  demo_black_aa_%  \
# municipality                           ...
# Westminster                    3080.0  ...              0.0
# Lanesborough                   1558.0  ...              2.3
# Wareham                        5467.0  ...              8.4
# Leicester                      2542.0  ...              3.4
#
#               demo_american_indian_%  demo_asian_%  demo_native_islander%  \
# municipality
# Westminster                      0.0           0.5                    0.0
# Lanesborough                     0.3           0.2                    0.0
# Wareham                          3.1           1.3                    0.8
# Leicester                        0.1           1.2                    0.1
#
#               demo_other_Race_%  demo_hispanic_latino_%  dem%  rep%   un%  \
# municipality
# Westminster                 0.0                     3.3  17.0  15.0  65.0
# Lanesborough                0.7                     0.8  26.0  10.0  62.0
# Wareham                     5.2                     4.1  23.0  12.0  63.0
# Leicester                   0.0                     2.4  24.0  11.0  64.0
#
#               total_waste/hh
# municipality
# Westminster         0.918887
# Lanesborough        0.702077
# Wareham             0.861921
# Leicester           1.112992
#
# [4 rows x 36 columns]

# %% [markdown]
# I can't know for sure how well this fit but from my analysis in Part 1, these values for total_waste/hh all seem reasonable. I will check out these point when comparing them in their own clusters.
#
# -----

# %% [markdown]
# ## Clustering

# %% [markdown]
# ### kMeans Clustering

# %%
kmeans = KMeans(n_clusters=6)
kmeans.fit(characteristics_im)
# Out:
# KMeans(n_clusters=6)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 1.17850204e+04,  9.63918367e+01,  6.05938776e+01,
#          1.35936327e+04,  3.52653061e+00,  1.24362184e+05,
#          1.55005327e+05,  2.54285714e+00,  4.20204082e+00,
#          6.71353061e+03,  9.31285714e+01,  7.22489796e+01,
#          5.64081633e+00,  4.89387755e+00,  3.81428571e+00,
#          3.56734694e+00,  3.05714286e+00,  6.47551020e+00,
#          2.93877551e-01,  1.02040816e-02,  8.04020408e+01,
#          1.95979592e+01,  1.69690204e+04,  9.50040816e+01,
#          4.25918367e+01,  8.95448980e+01,  3.07142857e+00,
#          6.06122449e-01,  7.87346939e+00,  7.95918367e-02,
#          1.10612245e+00,  3.74081633e+00,  2.59795918e+01,
#          1.30204082e+01,  5.99183673e+01,  1.03245861e+00],
#        [ 4.73775000e+05,  8.72000000e+01,  4.97000000e+01,
#          5.86859000e+05,  6.60000000e+00,  7.11150000e+04,
#          1.07608000e+05,  1.41000000e+01,  1.89000000e+01,
#          2.94418000e+05,  9.15000000e+01,  1.19000000e+01,
#          6.30000000e+00,  1.34000000e+01,  2.42000000e+01,
#          1.10000000e+01,  7.70000000e+00,  2.53000000e+01,
#          1.00000000e-01,  0.00000000e+00,  3.50000000e+01,
#          6.50000000e+01,  6.84379000e+05,  9.23000000e+01,
#          3.22000000e+01,  5.74000000e+01,  2.89000000e+01,
#          9.00000000e-01,  1.07000000e+01,  2.00000000e-01,
#          7.40000000e+00,  1.98000000e+01,  5.10000000e+01,
#          6.00000000e+00,  4.20000000e+01,  8.66011538e-01],
#        [ 8.71089474e+03,  9.42978947e+01,  4.23210526e+01,
#          1.00015474e+04,  3.84736842e+00,  9.01088947e+04,
#          1.12186316e+05,  3.33157895e+00,  6.22842105e+00,
#          5.02445263e+03,  8.89652632e+01,  7.32315789e+01,
#          4.59263158e+00,  6.04105263e+00,  4.62526316e+00,
#          3.11684211e+00,  2.75157895e+00,  4.41684211e+00,
#          1.21684211e+00,  1.89473684e-02,  7.86905263e+01,
#          2.13105263e+01,  1.20791684e+04,  9.63884211e+01,
#          4.55347368e+01,  9.36421053e+01,  3.27368421e+00,
#          6.36842105e-01,  2.96736842e+00,  8.63157895e-02,
#          1.54000000e+00,  3.71157895e+00,  2.48736842e+01,
#          1.27157895e+01,  6.09578947e+01,  9.67850183e-01],
#        [ 5.33169231e+04,  8.61807692e+01,  3.36346154e+01,
#          6.39266538e+04,  5.53076923e+00,  6.78586154e+04,
#          8.69902308e+04,  1.04269231e+01,  1.37615385e+01,
#          3.24622308e+04,  9.26846154e+01,  3.87923077e+01,
#          5.33846154e+00,  1.43807692e+01,  1.49538462e+01,
#          6.79615385e+00,  4.93461538e+00,  1.40192308e+01,
#          7.26923077e-01,  6.15384615e-02,  5.17269231e+01,
#          4.82730769e+01,  7.74942308e+04,  9.43923077e+01,
#          3.77076923e+01,  7.47730769e+01,  1.13846154e+01,
#          8.23076923e-01,  8.03846154e+00,  1.96153846e-01,
#          8.62307692e+00,  1.87538462e+01,  3.84230769e+01,
#          8.03846154e+00,  5.19615385e+01,  1.09457686e+00],
#        [ 1.12537500e+04,  1.07540000e+02,  7.98250000e+01,
#          1.32947500e+04,  4.10500000e+00,  1.76910250e+05,
#          2.39187850e+05,  2.91500000e+00,  4.19500000e+00,
#          6.47935000e+03,  1.00045000e+02,  9.02500000e+01,
#          5.54000000e+00,  3.16000000e+00,  2.51000000e+00,
#          2.03500000e+00,  1.13500000e+00,  5.27500000e+00,
#          9.50000000e-02, -6.93889390e-18,  9.45250000e+01,
#          1.54750000e+01,  1.68497500e+04,  1.03425000e+02,
#          5.12200000e+01,  9.83850000e+01,  2.20000000e+00,
#          4.40000000e-01,  1.05650000e+01,  1.75000000e-01,
#          1.27000000e+00,  3.17000000e+00,  2.73000000e+01,
#          1.37000000e+01,  5.79000000e+01,  1.03612088e+00],
#        [ 5.04862500e+03,  9.30762500e+01,  3.38187500e+01,
#          6.04667500e+03,  4.77625000e+00,  6.20249500e+04,
#          7.84981375e+04,  6.19125000e+00,  9.84125000e+00,
#          3.47787500e+03,  7.90412500e+01,  6.93237500e+01,
#          2.70750000e+00,  8.27375000e+00,  7.74000000e+00,
#          4.43375000e+00,  2.07375000e+00,  3.15375000e+00,
#          2.29500000e+00,  3.75000000e-03,  7.22987500e+01,
#          2.77012500e+01,  7.20190000e+03,  9.52225000e+01,
#          4.78612500e+01,  9.49400000e+01,  2.96875000e+00,
#          1.22500000e+00,  2.21625000e+00,  1.20000000e-01,
#          1.56500000e+00,  4.78250000e+00,  2.63875000e+01,
#          1.06750000e+01,  6.14125000e+01,  8.70976184e-01]])

# %%
pd.Series(kmeans.labels_).value_counts()
# Out:
# 2    95
# 5    80
# 0    49
# 3    26
# 4    20
# 1     1
# dtype: int64

# %%
characteristics_im['label'] = kmeans.labels_

# %%
population_stats = characteristics_im.describe().T

# %%
population_stats
# Out:
#                                 count           mean           std  \
# KEY_population_25_and_older     271.0   14368.933579  32729.100700
# edu_high_school_and_higher_%    271.0      94.488192     12.452289
# edu_bachelors_and_higher_%      271.0      45.076753     18.132243
# KEY_pop_16_+                    271.0   17028.841328  40391.221397
# unemployment_rate_%             271.0       4.254244      2.126981
# median_household_income         271.0   92213.033210  34934.766253
# mean_household_income           271.0  116922.225092  46824.687602
# families_below_poverty_level_%  271.0       4.722878      4.257194
# people_below_poverty_level_%    271.0       7.547970      5.291165
# KEY_total_housing_units         271.0    8680.955720  20267.871472
# occupancy_%                     271.0      87.972325     16.381082
# 1-unit_detached_%               271.0      69.625830     22.434155
# 1-unit_attached_%               271.0       4.373432      3.565227
# 2-units_%                       271.0       7.107380      6.056636
# 3-4_units_%                     271.0       6.305166      6.314326
# 5-9_units_%                     271.0       3.889299      3.623656
# 10-19_units_%                   271.0       2.715129      2.966372
# 20+_units_%                     271.0       5.477860      6.243066
# mobile_home_%                   271.0       1.234317      3.080927
# boat_RV_van_%                   271.0       0.015498      0.061310
# owner-occupied_%                271.0      75.533579     17.981800
# renter-occupied_%               271.0      25.204797     15.051234
# KEY_total_population            271.0   20632.394834  47595.843220
# males-to-100females             271.0      96.106642     15.020607
# median_age                      271.0      45.308856     10.053468
# demo_white_%                    271.0      91.690406     15.015421
# demo_black_aa_%                 271.0       3.940590      5.684519
# demo_american_indian_%          271.0       0.809225      1.478647
# demo_asian_%                    271.0       4.708487      5.693710
# demo_native_islander%           271.0       0.112546      0.243260
# demo_other_Race_%               271.0       2.150185      3.889815
# demo_hispanic_latino_%          271.0       5.495572      8.340547
# dem%                            271.0      27.095941      8.871408
# rep%                            271.0      11.767528      3.879841
# un%                             271.0      59.745387      6.392540
# total_waste/hh                  271.0       0.967756      0.281187
# label                           271.0       2.763838      1.789771
#
#                                         min           25%            50%  \
# KEY_population_25_and_older        67.00000   1973.000000    6036.000000
# edu_high_school_and_higher_%       67.00000     92.000000      95.000000
# edu_bachelors_and_higher_%          9.60000     31.800000      42.800000
# KEY_pop_16_+                       71.00000   2182.500000    7154.000000
# unemployment_rate_%                 0.00000      3.000000       4.000000
# median_household_income         21000.00000  67562.500000   85200.000000
# mean_household_income           37634.00000  85539.500000  106832.000000
# families_below_poverty_level_%      0.00000      2.000000       3.500000
# people_below_poverty_level_%        0.00000      3.900000       6.300000
# KEY_total_housing_units            70.00000   1441.500000    3869.000000
# occupancy_%                        17.90000     87.450000      93.800000
# 1-unit_detached_%                   8.70000     55.600000      71.700000
# 1-unit_attached_%                   0.00000      1.750000       3.900000
# 2-units_%                           0.00000      2.450000       5.700000
# 3-4_units_%                         0.00000      1.650000       4.300000
# 5-9_units_%                         0.00000      0.900000       3.000000
# 10-19_units_%                       0.00000      0.000000       1.700000
# 20+_units_%                         0.00000      0.350000       3.300000
# mobile_home_%                       0.00000      0.000000       0.100000
# boat_RV_van_%                       0.00000      0.000000       0.000000
# owner-occupied_%                   31.00000     66.700000      78.100000
# renter-occupied_%                   0.00000     14.200000      22.200000
# KEY_total_population               87.00000   2553.000000    8824.000000
# males-to-100females                59.20000     89.050000      94.800000
# median_age                         21.40000     41.000000      43.900000
# demo_white_%                       34.70000     88.150000      93.900000
# demo_black_aa_%                     0.00000      0.950000       2.600000
# demo_american_indian_%              0.00000      0.100000       0.500000
# demo_asian_%                        0.00000      1.000000       2.800000
# demo_native_islander%               0.00000      0.000000       0.000000
# demo_other_Race_%                   0.00000      0.300000       1.100000
# demo_hispanic_latino_%              0.00000      1.550000       3.300000
# dem%                                7.00000     21.000000      25.000000
# rep%                                3.00000      9.000000      12.000000
# un%                                38.00000     57.000000      61.000000
# total_waste/hh                      0.33366      0.785477       0.963876
# label                               0.00000      2.000000       2.000000
#
#                                           75%            max
# KEY_population_25_and_older      17193.000000  473775.000000
# edu_high_school_and_higher_%        97.300000     282.900000
# edu_bachelors_and_higher_%          55.850000     116.500000
# KEY_pop_16_+                     19912.500000  586859.000000
# unemployment_rate_%                  5.100000      19.500000
# median_household_income         106794.000000  216250.000000
# mean_household_income           136861.500000  355097.000000
# families_below_poverty_level_%       6.400000      25.400000
# people_below_poverty_level_%         9.600000      38.900000
# KEY_total_housing_units           9671.500000  294418.000000
# occupancy_%                         95.900000     191.700000
# 1-unit_detached_%                   85.300000     237.200000
# 1-unit_attached_%                    6.000000      22.100000
# 2-units_%                           10.300000      32.600000
# 3-4_units_%                          9.600000      33.500000
# 5-9_units_%                          5.850000      16.700000
# 10-19_units_%                        4.650000      16.300000
# 20+_units_%                          8.650000      37.600000
# mobile_home_%                        1.000000      30.800000
# boat_RV_van_%                        0.000000       0.600000
# owner-occupied_%                    86.000000     240.500000
# renter-occupied_%                   33.900000      69.000000
# KEY_total_population             24572.000000  684379.000000
# males-to-100females                100.000000     246.700000
# median_age                          48.400000     164.500000
# demo_white_%                        97.300000     278.000000
# demo_black_aa_%                      4.800000      48.000000
# demo_american_indian_%               0.900000      15.000000
# demo_asian_%                         6.250000      32.600000
# demo_native_islander%                0.150000       2.100000
# demo_other_Race_%                    2.200000      37.600000
# demo_hispanic_latino_%               6.350000      80.600000
# dem%                                31.000000      58.000000
# rep%                                14.000000      23.000000
# un%                                 64.000000      85.000000
# total_waste/hh                       1.126953       1.970291
# label                                5.000000       5.000000

# %%
stats0 = characteristics_im[characteristics_im['label'] == 0].describe().T
stats2 = characteristics_im[characteristics_im['label'] == 2].describe().T
stats3 = characteristics_im[characteristics_im['label'] == 3].describe().T
stats4 = characteristics_im[characteristics_im['label'] == 4].describe().T
stats5 = characteristics_im[characteristics_im['label'] == 5].describe().T

# %%
sub0 = 100*(population_stats - stats0) / population_stats

sub0.drop(columns=['count', 'std', 'min', 'max'], inplace=True)
sub0[(abs(sub0['mean']) > 10) | (abs(sub0['25%']) > 10) | (abs(sub0['50%']) > 10) | (abs(sub0['75%']) > 10)]
# Out:
#                                       mean         25%         50%         75%
# KEY_population_25_and_older      17.982637 -150.380132  -57.836315    2.797650
# edu_bachelors_and_higher_%      -34.423786  -72.327044  -39.018692  -21.038496
# KEY_pop_16_+                     20.172886 -165.017182  -52.683813    3.844319
# unemployment_rate_%              17.105578    6.666667   15.000000   15.686275
# median_household_income         -34.863998  -69.181129  -45.692488  -24.286945
# mean_household_income           -32.571311  -67.862800  -40.398008  -21.753013
# families_below_poverty_level_%   46.158740   25.000000   42.857143   48.437500
# people_below_poverty_level_%     44.328865   25.641026   39.682540   51.041667
# KEY_total_housing_units          22.663692  -79.327090  -38.950633    3.675748
# 1-unit_detached_%                -3.767495  -13.669065   -2.510460    1.875733
# 1-unit_attached_%               -28.979179  -94.285714  -38.461538  -11.666667
# 2-units_%                        31.143720   38.775510   40.350877   38.834951
# 3-4_units_%                      39.505388   -3.030303   37.209302   46.875000
# 5-9_units_%                       8.277892  -22.222222    3.333333   23.076923
# 10-19_units_%                   -12.596591        -inf    0.000000   -3.225806
# 20+_units_%                     -18.212413 -385.714286  -51.515152  -15.606936
# mobile_home_%                    76.191086         NaN  100.000000   70.000000
# boat_RV_van_%                    34.159378         NaN         NaN         NaN
# owner-occupied_%                 -6.445427  -11.394303   -3.841229   -2.674419
# renter-occupied_%                22.245122   17.605634   14.864865   24.188791
# KEY_total_population             17.755449 -175.832354  -59.451496    0.936025
# demo_black_aa_%                  22.056640  -47.368421    3.846154   10.416667
# demo_american_indian_%           25.098411    0.000000   20.000000   33.333333
# demo_asian_%                    -67.218668 -120.000000 -142.857143  -69.600000
# demo_native_islander%            29.280696         NaN         NaN   33.333333
# demo_other_Race_%                48.556859  -66.666667   27.272727   22.727273
# demo_hispanic_latino_%           31.930355  -61.290323    0.000000   21.259843
# rep%                            -10.646930  -22.222222   -8.333333  -14.285714
# total_waste/hh                   -6.685886  -15.389904   -9.051904   -3.031720
# label                           100.000000  100.000000  100.000000  100.000000

# %% [markdown]
# So cluster `0` is high population, higher percentage of poverty, more multi-unit homes, more renter occupation, a much more ethnically diverse population all around, and significantly less Republican.

# %%
sub2 = 100*(population_stats - stats2) / population_stats

sub2.drop(columns=['count', 'std', 'min', 'max'], inplace=True)
sub2[(abs(sub2['mean']) > 10) | (abs(sub2['25%']) > 10) | (abs(sub2['50%']) > 10) | (abs(sub2['75%']) > 10)]
# Out:
#                                      mean         25%         50%        75%
# KEY_population_25_and_older     39.376888   -2.154080    2.302850  26.772524
# KEY_pop_16_+                    41.267012   -7.262314    7.995527  28.868801
# median_household_income          2.281823  -22.171323   -5.633803   7.646965
# mean_household_income            4.050478  -18.815284   -4.095215  11.988397
# families_below_poverty_level_%  29.458716   -5.000000   11.428571  24.218750
# people_below_poverty_level_%    17.482175    0.000000   15.873016  17.708333
# KEY_total_housing_units         42.120974    4.578564   20.031016  25.047821
# 2-units_%                       15.003101   -2.040816   12.280702  19.417476
# 3-4_units_%                     26.643278   12.121212   11.627907  27.083333
# 5-9_units_%                     19.861081   16.666667   13.333333  13.675214
# 10-19_units_%                   -1.342470         NaN   11.764706   2.150538
# 20+_units_%                     19.369201   28.571429   30.303030  13.872832
# mobile_home_%                    1.415782         NaN  100.000000   0.000000
# boat_RV_van_%                  -22.255639         NaN         NaN        NaN
# renter-occupied_%               15.450514    6.338028   12.612613  15.191740
# KEY_total_population            41.455325  -11.633373   11.128740  30.707716
# demo_black_aa_%                 16.924017   42.105263   11.538462  29.166667
# demo_american_indian_%          21.302230  100.000000   20.000000  22.222222
# demo_asian_%                    36.978304   25.000000   28.571429  36.000000
# demo_native_islander%           23.306299         NaN         NaN  33.333333
# demo_other_Race_%               28.378239    0.000000   18.181818  27.272727
# demo_hispanic_latino_%          32.462372    9.677419   21.212121  23.622047
# rep%                            -8.058292  -16.666667    0.000000  -7.142857
# label                           27.636849    0.000000    0.000000  60.000000

# %% [markdown]
# Cluster `2` is higher population (but not as high as `0`), much lower education, very high unemployment and high rate of poverty (even higher than cluster `0`), higher multi-unit homes but not ones that exceed 10 units, higher renter occupation, high ethnic diversity with the exception of Asians, and again low Republicans.

# %%
sub3 = 100*(population_stats - stats3) / population_stats

sub3.drop(columns=['count', 'std', 'min', 'max'], inplace=True)
sub3[(abs(sub3['mean']) > 10) | (abs(sub3['25%']) > 10) | (abs(sub3['50%']) > 10) | (abs(sub3['75%']) > 10)]
# Out:
#                                       mean          25%         50%  \
# KEY_population_25_and_older    -271.056925 -1881.360872 -619.880716
# edu_high_school_and_higher_%      8.792022    10.407609    7.105263
# edu_bachelors_and_higher_%       25.383677    35.062893   29.906542
# KEY_pop_16_+                   -275.402252 -1966.918671 -637.244898
# unemployment_rate_%             -30.005938   -50.000000  -37.500000
# median_household_income          26.411036    20.127290   20.901995
# mean_household_income            25.599918    17.906640   19.878875
# families_below_poverty_level_% -120.774760  -236.250000 -197.142857
# people_below_poverty_level_%    -82.321042  -136.538462 -107.142857
# KEY_total_housing_units        -273.947660 -1562.747138 -572.473507
# 1-unit_detached_%                44.284603    47.167266   51.743375
# 1-unit_attached_%               -22.065734  -121.428571  -42.307692
# 2-units_%                      -102.335728  -315.306122 -134.210526
# 3-4_units_%                    -137.168158  -504.545455 -187.209302
# 5-9_units_%                     -74.739819  -363.888889  -93.333333
# 10-19_units_%                   -81.745144         -inf -197.058824
# 20+_units_%                    -155.925331 -2028.571429 -325.757576
# mobile_home_%                    41.107278         -inf -100.000000
# boat_RV_van_%                  -297.069597          NaN        -inf
# owner-occupied_%                 31.517977    37.706147   33.930858
# renter-occupied_%               -91.523371  -174.647887 -118.018018
# KEY_total_population           -275.594939 -2020.025460 -615.718495
# median_age                       16.776331    15.792683   15.831435
# demo_white_%                     18.450490    24.220079   16.347178
# demo_black_aa_%                -188.906337  -607.894737 -232.692308
# demo_american_indian_%           -1.711740  -525.000000  -60.000000
# demo_asian_%                    -70.722812  -132.500000  -62.500000
# demo_native_islander%           -74.287516         -inf        -inf
# demo_other_Race_%              -301.038930  -783.333333 -450.000000
# demo_hispanic_latino_%         -241.253764  -456.451613 -293.939394
# dem%                            -41.803811   -53.571429  -54.000000
# rep%                             31.689461    30.555556   33.333333
# un%                              13.028368    14.035088   13.114754
# total_waste/hh                  -13.104681   -23.037507   -9.044919
# label                            -8.544726   -50.000000  -50.000000
#
#                                        75%
# KEY_population_25_and_older    -265.453964
# edu_high_school_and_higher_%      6.680370
# edu_bachelors_and_higher_%       24.709042
# KEY_pop_16_+                   -272.799749
# unemployment_rate_%             -17.156863
# median_household_income          27.390584
# mean_household_income            27.411288
# families_below_poverty_level_% -100.390625
# people_below_poverty_level_%    -70.052083
# KEY_total_housing_units        -313.563046
# 1-unit_detached_%                41.735053
# 1-unit_attached_%                -0.833333
# 2-units_%                       -54.368932
# 3-4_units_%                     -87.760417
# 5-9_units_%                     -52.991453
# 10-19_units_%                   -24.731183
# 20+_units_%                    -104.335260
# mobile_home_%                    20.000000
# boat_RV_van_%                         -inf
# owner-occupied_%                 29.069767
# renter-occupied_%               -72.418879
# KEY_total_population           -282.919583
# median_age                       17.975207
# demo_white_%                     13.283659
# demo_black_aa_%                -135.937500
# demo_american_indian_%           -8.333333
# demo_asian_%                    -73.200000
# demo_native_islander%           -83.333333
# demo_other_Race_%              -385.227273
# demo_hispanic_latino_%         -241.338583
# dem%                            -41.129032
# rep%                             30.357143
# un%                              11.718750
# total_waste/hh                   -9.871848
# label                            40.000000

# %% [markdown]
# Cluster `3` is extremely higher population, high education, low unemployment and poverty, high income, a weird mix of 1-unit "attached" (not sure what that means) and 10+ unit homes, with less of the smaller aparment buildings, less renter occupation (which means more owner occupation), highly diverse ethnically with the exception of american indians and native islanders, significantly more republican and significantly more waste generating.

# %%
sub4 = 100*(population_stats - stats4) / population_stats

sub4.drop(columns=['count', 'std', 'min', 'max'], inplace=True)
sub4[(abs(sub4['mean']) > 10) | (abs(sub4['25%']) > 10) | (abs(sub4['50%']) > 10) | (abs(sub4['75%']) > 10)]
# Out:
#                                       mean         25%         50%         75%
# KEY_population_25_and_older      21.679992  -75.316776  -10.395958   10.847438
# edu_high_school_and_higher_%    -13.813163   -6.385870   -3.736842   -1.644399
# edu_bachelors_and_higher_%      -77.086847 -141.116352  -86.214953  -47.448523
# KEY_pop_16_+                     21.928041  -79.862543   -9.421303   11.661017
# unemployment_rate_%               3.508110    8.333333    7.500000   14.215686
# median_household_income         -91.849507 -135.730250 -110.639671  -83.717952
# mean_household_income          -104.570046 -150.819797 -115.159316  -84.249405
# families_below_poverty_level_%   38.279162   37.500000   48.571429   50.390625
# people_below_poverty_level_%     44.422146   37.179487   47.619048   53.645833
# KEY_total_housing_units          25.361329  -25.251474    3.476350   13.919764
# occupancy_%                     -13.723265   -7.232704   -1.812367   -1.720542
# 1-unit_detached_%               -29.621435  -37.679856  -18.479777   -7.327081
# 1-unit_attached_%               -26.673979  -68.571429   -5.128205  -13.750000
# 2-units_%                        55.539172   61.224490   57.017544   66.747573
# 3-4_units_%                      60.191374   71.212121   60.465116   54.947917
# 5-9_units_%                      47.676945   83.333333   55.000000   53.846154
# 10-19_units_%                    58.197200         NaN   61.764706   65.053763
# 20+_units_%                       3.703267 -557.142857  -15.151515   10.982659
# mobile_home_%                    92.303438         NaN  100.000000   97.500000
# boat_RV_van_%                   100.000000         NaN         NaN         NaN
# owner-occupied_%                -25.143017  -22.188906  -12.804097   -9.912791
# renter-occupied_%                38.602957   55.985915   37.387387   41.150442
# KEY_total_population             18.333523  -89.806110  -16.704442    9.490477
# median_age                      -13.046332   -5.853659   -1.708428    3.667355
# demo_black_aa_%                  44.170803   50.000000   40.384615   38.541667
# demo_american_indian_%           45.626995  100.000000   50.000000   52.777778
# demo_asian_%                   -124.382053 -462.500000 -248.214286 -128.400000
# demo_native_islander%           -55.491803         NaN         NaN  -33.333333
# demo_other_Race_%                40.935301    8.333333   22.727273   39.772727
# demo_hispanic_latino_%           42.317196    9.677419   28.787879   22.440945
# rep%                            -16.422076  -22.222222  -16.666667  -14.285714
# total_waste/hh                   -7.064315   -1.332069   -7.475232  -10.025780
# label                           -44.726302 -100.000000 -100.000000   20.000000

# %% [markdown]
# Cluster 4 is lower populations, higher educations, lower poverty+unemployment with higher income, much more single family homes with less multi-unit options, more owner occupation, higher median age (interesting, this hasn't shown up in other clusters), almost no ethnic diversity, incredibly republican or undeclared, with much less waste generation.

# %%
sub5 = 100*(population_stats - stats5) / population_stats

sub5.drop(columns=['count', 'std', 'min', 'max'], inplace=True)
sub5[(abs(sub5['mean']) > 10) | (abs(sub5['25%']) > 10) | (abs(sub5['50%']) > 10) | (abs(sub5['75%']) > 10)]
# Out:
#                                      mean         25%         50%         75%
# KEY_population_25_and_older     64.864303   65.648758   68.870113   63.237946
# edu_bachelors_and_higher_%      24.975186   27.987421   22.429907   20.769919
# KEY_pop_16_+                    64.491565   65.864834   70.771596   63.069680
# unemployment_rate_%            -12.270253  -10.833333  -11.250000  -17.647059
# median_household_income         32.737328   19.251804   24.876761   35.262983
# mean_household_income           32.862946   17.619638   24.206698   36.624617
# families_below_poverty_level_% -31.090613  -56.250000  -55.714286  -25.390625
# people_below_poverty_level_%   -30.382730  -81.410256  -40.476190  -22.135417
# KEY_total_housing_units         59.936727   62.018730   60.118894   49.149563
# occupancy_%                     10.152141   17.009720    8.315565    3.519291
# 1-unit_attached_%               38.092094   65.714286   38.461538   28.333333
# 2-units_%                      -16.410687  -59.183673  -38.596491  -20.631068
# 3-4_units_%                    -22.756482    4.545455  -25.581395  -16.666667
# 5-9_units_%                    -13.998695   75.000000   -5.000000  -17.094017
# 10-19_units_%                   23.622418         NaN   38.235294   35.483871
# 20+_units_%                     42.427332  100.000000   74.242424   27.167630
# mobile_home_%                  -85.932735         NaN -700.000000 -152.500000
# boat_RV_van_%                   75.803571         NaN         NaN         NaN
# renter-occupied_%               -9.904674  -18.838028  -15.315315  -14.675516
# KEY_total_population            65.094212   64.531923   71.928830   64.423938
# demo_black_aa_%                 24.662305   47.368421   11.538462   11.979167
# demo_american_indian_%         -51.379389 -100.000000  -50.000000  -47.222222
# demo_asian_%                    52.930741   85.000000   50.000000   46.800000
# demo_native_islander%           -6.622951         NaN         NaN   33.333333
# demo_other_Race_%               27.215548  100.000000   18.181818   -1.136364
# demo_hispanic_latino_%          12.975391   43.548387    7.575758    9.842520
# rep%                             9.284258   11.111111    8.333333    5.357143
# total_waste/hh                  10.000396   10.975138   12.292117   13.404705
# label                          -80.907877 -150.000000 -150.000000    0.000000

# %% [markdown]
# Cluster 5 is less educated with more poverty, lots of un-occupied homes with multi-unit homes (mobile parks ahve seemed to be lumped into here), median age is lower, much higher black, american indian, and latino populations much few asians and native islanders, low republican representation, low waste.

# %% [markdown]
# Cluster 1, with only one municipality, should be Boston.

# %%
characteristics_im[characteristics_im['label'] == 1]
# Out:
#               KEY_population_25_and_older  edu_high_school_and_higher_%  \
# municipality
# Boston                           473775.0                          87.2
#
#               edu_bachelors_and_higher_%  KEY_pop_16_+  unemployment_rate_%  \
# municipality
# Boston                              49.7      586859.0                  6.6
#
#               median_household_income  mean_household_income  \
# municipality
# Boston                        71115.0               107608.0
#
#               families_below_poverty_level_%  people_below_poverty_level_%  \
# municipality
# Boston                                  14.1                          18.9
#
#               KEY_total_housing_units  ...  demo_american_indian_%  \
# municipality                           ...
# Boston                       294418.0  ...                     0.9
#
#               demo_asian_%  demo_native_islander%  demo_other_Race_%  \
# municipality
# Boston                10.7                    0.2                7.4
#
#               demo_hispanic_latino_%  dem%  rep%   un%  total_waste/hh  label
# municipality
# Boston                          19.8  51.0   6.0  42.0        0.866012      1
#
# [1 rows x 37 columns]

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

# %%
list(characteristics_im.columns)
# Out:
# ['KEY_population_25_and_older',
#  'edu_high_school_and_higher_%',
#  'edu_bachelors_and_higher_%',
#  'KEY_pop_16_+',
#  'unemployment_rate_%',
#  'median_household_income',
#  'mean_household_income',
#  'families_below_poverty_level_%',
#  'people_below_poverty_level_%',
#  'KEY_total_housing_units',
#  'occupancy_%',
#  '1-unit_detached_%',
#  '1-unit_attached_%',
#  '2-units_%',
#  '3-4_units_%',
#  '5-9_units_%',
#  '10-19_units_%',
#  '20+_units_%',
#  'mobile_home_%',
#  'boat_RV_van_%',
#  'owner-occupied_%',
#  'renter-occupied_%',
#  'KEY_total_population',
#  'males-to-100females',
#  'median_age',
#  'demo_white_%',
#  'demo_black_aa_%',
#  'demo_american_indian_%',
#  'demo_asian_%',
#  'demo_native_islander%',
#  'demo_other_Race_%',
#  'demo_hispanic_latino_%',
#  'dem%',
#  'rep%',
#  'un%',
#  'total_waste/hh',
#  'label']

# %%
# getting rid of some obviously highly correlated data (like population above certain age groups, mean income) in additional to some categories with only very few data points (mobile homes and RVs)

cols_to_include = ['edu_high_school_and_higher_%',
 'edu_bachelors_and_higher_%',
 'unemployment_rate_%',
 'median_household_income',
 'people_below_poverty_level_%',
 'occupancy_%',
 '1-unit_detached_%',
 '1-unit_attached_%',
 '2-units_%',
 '3-4_units_%',
 '5-9_units_%',
 '10-19_units_%',
 '20+_units_%',
 'owner-occupied_%',
# 'renter-occupied_%',
 'KEY_total_population',
 'median_age',
# 'demo_white_%',
 'demo_black_aa_%',
 'demo_american_indian_%',
 'demo_asian_%',
 'demo_native_islander%',
 'demo_other_Race_%',
 'demo_hispanic_latino_%',
# 'dem%',
 'rep%',
 'un%',
 'total_waste/hh']

# %%
chars_df = characteristics_im[cols_to_include]

# %%
pca = PCA(n_components=6)
characteristics_pca = pca.fit_transform(chars_df)

# %%
pca.explained_variance_ratio_
# Out:
# array([6.54948424e-01, 3.45051037e-01, 2.48786863e-07, 1.02698899e-07,
#        6.89841573e-08, 2.74354989e-08])

# %%
components = pd.DataFrame(pca.components_, columns=chars_df.columns, index=['z1', 'z2','z3','z4','z5','z6']).T
components.sort_values(by='z1', ascending=False)
# Out:
#                                         z1            z2        z3        z4  \
# KEY_total_population          9.917932e-01  1.278521e-01  0.000304 -0.000095
# renter-occupied_%             1.498632e-04 -1.474321e-04 -0.240924  0.443183
# dem%                          7.779377e-05 -1.212248e-05 -0.091652  0.009061
# demo_hispanic_latino_%        7.051476e-05 -4.498546e-05 -0.088369  0.094967
# 20+_units_%                   6.392165e-05  1.658632e-05 -0.088832  0.128113
# demo_black_aa_%               5.926637e-05 -1.392430e-05 -0.031101  0.023029
# 3-4_units_%                   5.496377e-05 -6.159254e-05 -0.099062  0.132517
# people_below_poverty_level_%  3.976528e-05 -7.176061e-05 -0.021496  0.086058
# 2-units_%                     3.773078e-05 -5.498425e-05 -0.093285  0.132739
# occupancy_%                   3.499054e-05  1.784562e-04 -0.047151  0.610601
# demo_other_Race_%             3.019984e-05 -1.834700e-05 -0.032824  0.034646
# demo_asian_%                  2.700306e-05  7.447404e-05 -0.072298  0.041884
# 5-9_units_%                   2.410755e-05 -2.401433e-05 -0.053186  0.087829
# 10-19_units_%                 1.906735e-05 -4.712978e-06 -0.039016  0.056195
# 1-unit_attached_%             8.285836e-06  2.335185e-05 -0.015794  0.073396
# unemployment_rate_%           7.777054e-06 -1.523608e-05  0.001524  0.027909
# demo_native_islander%         5.034057e-07  2.316674e-07  0.001033  0.003313
# total_waste/hh                4.109593e-07  1.242146e-06 -0.001832  0.001371
# demo_american_indian_%       -1.476377e-07 -7.860471e-06  0.006597 -0.004232
# rep%                         -2.351375e-05  2.971098e-05  0.030651 -0.010509
# edu_bachelors_and_higher_%   -3.754092e-05  4.045252e-04  0.006914  0.070764
# edu_high_school_and_higher_% -4.264037e-05  1.208472e-04  0.263178  0.388543
# median_age                   -5.283050e-05  4.863846e-06  0.257764  0.146928
# un%                          -5.432997e-05 -1.301871e-05  0.060644 -0.002840
# demo_white_%                 -1.126627e-04  2.560155e-05  0.365283  0.379128
# owner-occupied_%             -1.537810e-04  2.120261e-04  0.480063  0.012832
# 1-unit_detached_%            -2.079603e-04  1.872258e-04  0.616822 -0.143245
# median_household_income      -1.278520e-01  9.917931e-01 -0.000344 -0.000071
#
#                                     z5        z6
# KEY_total_population         -0.000049 -0.000081
# renter-occupied_%             0.211215 -0.011754
# dem%                          0.344155  0.426620
# demo_hispanic_latino_%        0.001939  0.415088
# 20+_units_%                   0.074828  0.027559
# demo_black_aa_%               0.023253  0.298040
# 3-4_units_%                   0.038168 -0.063098
# people_below_poverty_level_%  0.061289  0.153603
# 2-units_%                     0.053445 -0.024356
# occupancy_%                  -0.529192  0.267205
# demo_other_Race_%            -0.003338  0.206598
# demo_asian_%                  0.074030  0.085857
# 5-9_units_%                   0.023198 -0.062740
# 10-19_units_%                 0.005561 -0.010524
# 1-unit_attached_%             0.018393 -0.016964
# unemployment_rate_%          -0.002575  0.024045
# demo_native_islander%         0.002115  0.003275
# total_waste/hh               -0.000519  0.001975
# demo_american_indian_%        0.013739  0.016169
# rep%                         -0.098655 -0.132342
# edu_bachelors_and_higher_%    0.608170 -0.059889
# edu_high_school_and_higher_%  0.220221 -0.035149
# median_age                    0.211171 -0.058044
# un%                          -0.233226 -0.289444
# demo_white_%                  0.072210 -0.386557
# owner-occupied_%             -0.054478  0.164472
# 1-unit_detached_%            -0.028621  0.339411
# median_household_income      -0.000120 -0.000069

# %%
(abs(components) > 0.05).any(1)
# Out:
# edu_high_school_and_higher_%     True
# edu_bachelors_and_higher_%       True
# unemployment_rate_%             False
# median_household_income          True
# people_below_poverty_level_%     True
# occupancy_%                      True
# 1-unit_detached_%                True
# 1-unit_attached_%                True
# 2-units_%                        True
# 3-4_units_%                      True
# 5-9_units_%                      True
# 10-19_units_%                    True
# 20+_units_%                      True
# owner-occupied_%                 True
# renter-occupied_%                True
# KEY_total_population             True
# median_age                       True
# demo_white_%                     True
# demo_black_aa_%                  True
# demo_american_indian_%          False
# demo_asian_%                     True
# demo_native_islander%           False
# demo_other_Race_%                True
# demo_hispanic_latino_%           True
# dem%                             True
# rep%                             True
# un%                              True
# total_waste/hh                  False
# dtype: bool

# %%
# based on PCA, getting rid features that contribute less than 5% to any dimension

# cols_to_include = ['edu_high_school_and_higher_%',
#  'edu_bachelors_and_higher_%',
#  'median_household_income',
#  'people_below_poverty_level_%',
#  'occupancy_%',
#  '1-unit_detached_%',
#  '1-unit_attached_%',
#  '2-units_%',
#  '3-4_units_%',
#  '5-9_units_%',
#  '10-19_units_%',
#  '20+_units_%',
#  'owner-occupied_%',
#  'renter-occupied_%',
#  'KEY_total_population',
#  'median_age',
#  'demo_white_%',
#  'demo_black_aa_%',
#  'demo_asian_%',
#  'demo_other_Race_%',
#  'demo_hispanic_latino_%',
#  'dem%',
#  'rep%',
#  'un%']

# %%
import seaborn as sns

# %%
mask = np.zeros_like(chars_df.corr())
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(14, 14))
sns.heatmap(
    chars_df.corr(),
    cmap='coolwarm',
    annot=True,
    mask=mask,
    vmin=-1.,
    vmax=1.,
    linewidths=.01
)

plt.title('Correlation matrix');

# %%
kmeans2 = KMeans(n_clusters=6)
kmeans2.fit(chars_df)
# Out:
# KMeans(n_clusters=6)

# %%
pd.Series(kmeans2.labels_).value_counts()
# Out:
# 0    122
# 1     78
# 5     40
# 4     20
# 3     10
# 2      1
# dtype: int64

# %%
chars_df['km_label'] = kmeans2.labels_
# Out:
# <ipython-input-90-d69da9e2be8c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chars_df['km_label'] = kmeans2.labels_

# %% [markdown]
# second lowest cluster by count, `1`, appears to be highly educated, high income, lots of detached 1-unit homes, highest occupancy, highest owner-occupied, highest asian population. There seems to be good separation in the cluster's center from the others.
#
# What other clustering evaluation can I do on kMeans?

# %% [markdown]
# ## Hierarchial

# %%
# create dendrogram
dendrogram = sch.dendrogram(sch.linkage(chars_df.drop(columns='km_label'), method='ward'))
# create clusters
hc = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'ward')
# save clusters for chart
y_hc = hc.fit_predict(chars_df.drop(columns='km_label'))

# %% [markdown]
# Wow, so cool... um... looks like a natural cut off in the 300,000 distance range, which would result in 5 groups. Could also plit just above 200,000 to get 6 clusters, but this would spit and already smaller cluster.

# %%
chars_df['h_label'] = hc.labels_
chars_df['h_label'].value_counts()
# Out:
# <ipython-input-92-e49d48dc6709>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chars_df['h_label'] = hc.labels_
# 2    116
# 4     61
# 0     53
# 1     40
# 3      1
# Name: h_label, dtype: int64

# %%
chars_df.groupby(['h_label']).median().T
# Out:
# h_label                                   0             1             2  \
# edu_high_school_and_higher_%      97.500000     90.200000     94.950000
# edu_bachelors_and_higher_%        68.700000     33.450000     41.250000
# unemployment_rate_%                3.600000      5.150000      3.700000
# median_household_income       135909.000000  68876.000000  90330.500000
# people_below_poverty_level_%       3.100000     12.400000      5.250000
# occupancy_%                       95.700000     94.050000     94.200000
# 1-unit_detached_%                 81.100000     44.300000     74.750000
# 1-unit_attached_%                  4.100000      5.500000      4.200000
# 2-units_%                          2.500000     12.800000      5.100000
# 3-4_units_%                        2.400000     11.600000      3.700000
# 5-9_units_%                        1.700000      5.950000      2.600000
# 10-19_units_%                      1.000000      5.050000      1.350000
# 20+_units_%                        4.000000     12.350000      1.750000
# owner-occupied_%                  85.800000     55.250000     80.300000
# renter-occupied_%                 14.300000     44.750000     19.700000
# KEY_total_population           12894.000000  56077.500000   6810.000000
# median_age                        43.400000     39.400000     44.450000
# demo_white_%                      92.400000     81.300000     95.800000
# demo_black_aa_%                    1.700000      7.500000      2.200000
# demo_american_indian_%             0.300000      0.800000      0.400000
# demo_asian_%                       6.800000      4.800000      2.050000
# demo_native_islander%              0.000000      0.200000      0.000000
# demo_other_Race_%                  0.700000      4.400000      1.000000
# demo_hispanic_latino_%             2.800000     10.200000      2.800000
# dem%                              23.000000     38.500000     24.000000
# rep%                              14.000000      8.000000     12.500000
# un%                               60.000000     53.000000     62.000000
# total_waste/hh                     1.068928      1.031668      0.939179
# km_label                           1.000000      5.000000      0.000000
#
# h_label                                   3             4
# edu_high_school_and_higher_%      87.200000     93.400000
# edu_bachelors_and_higher_%        49.700000     33.200000
# unemployment_rate_%                6.600000      4.700000
# median_household_income        71115.000000  62500.000000
# people_below_poverty_level_%      18.900000      9.000000
# occupancy_%                       91.500000     85.300000
# 1-unit_detached_%                 11.900000     71.700000
# 1-unit_attached_%                  6.300000      2.400000
# 2-units_%                         13.400000      7.700000
# 3-4_units_%                       24.200000      6.300000
# 5-9_units_%                       11.000000      3.200000
# 10-19_units_%                      7.700000      1.000000
# 20+_units_%                       25.300000      0.600000
# owner-occupied_%                  35.000000     74.500000
# renter-occupied_%                 65.000000     25.500000
# KEY_total_population          684379.000000   1798.000000
# median_age                        32.200000     50.100000
# demo_white_%                      57.400000     95.800000
# demo_black_aa_%                   28.900000      2.300000
# demo_american_indian_%             0.900000      0.700000
# demo_asian_%                      10.700000      1.300000
# demo_native_islander%              0.200000      0.000000
# demo_other_Race_%                  7.400000      0.700000
# demo_hispanic_latino_%            19.800000      2.100000
# dem%                              51.000000     24.000000
# rep%                               6.000000     11.000000
# un%                               42.000000     63.000000
# total_waste/hh                     0.866012      0.845408
# km_label                           2.000000      0.000000

# %%
sns.pairplot(data =chars_df.loc[:,['edu_high_school_and_higher_%','edu_bachelors_and_higher_%','h_label']], hue = 'h_label', corner = True)
# Out:
# C:\Users\nanai\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\nanai\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Next steps:
#
# * do some grid searching?
# * any further cleaning or prepping of data?
# * add in amount of waste generated as an characteristic? (this would mean trimming down to just the municipalities I'm looking at.
# * find political data?

# %%
# For saving files
# chars_df.to_csv('data/cluster_data.csv', index=True)
