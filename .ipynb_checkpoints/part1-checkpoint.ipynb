# %% [markdown]
# # Final Project, Part 1: Proposal and Dataset
# *Frame your problem and data source(s)*
#
# Describe your chosen problem and state whether you have access to relevant data.
#
# ## Requirements
# 1. Draft a well-formed one sentence problem statement relevant to a business problem affecting your team, division, or organization.
# 1. Include the following elements:
#    * Hypothesis/assumptions
#    * Goals and success metrics
#    * Risks or limitations
# 1. Identify at least one relevant dataset and confirm that you have access and can share the data.

# %% [markdown]
# ## Problem Statement
#
# This project will explore the effectiveness of recycling in the state of Massachusetts.
# Factors of interest:
# * effect of recycling municipal waste handling program (service type, collection fequency, etc)
# * effect of trash municipal waste handling program (pay-to-throw,
# * effect of municipality (education level, types of homes,
# * effect of funding for solid waste handling
# ### Hypotheses
#
# 1.

# %% [markdown]
# ## Types of DS problems:
# [source](http://jtleek.com/modules/01_DataScientistToolbox/03_01_typesOfQuestions/#1)
#
# * **Descriptive**: describe set of data
#    * The first kind of data analysis performed
#    * Commonly applied to census data
#    * The description and interpretation are different steps
#    * Descriptions can usually not be generalized without additional statistical modeling
# * **Exploratory**: find relationships you didn't know about
#    * Exploratory models are good for discovering new connections
#    * They are also useful for defining future studies
#    * Exploratory analyses are usually not the final say
#    * Exploratory analyses alone should not be used for generalizing/predicting
#    * Correlation does not imply causation
# * **Inferential**: use a relatively small sample of data to say something about the population
#    * Inference is commonly the goal of statistical models
#    * Inference involves estimating both the *quantity* you care about and your *uncertainty* about your estimate
#    * Inference depends heavily on both the population and the sampling scheme
# * **Predictive**: use the data on some objects to predict values of another object
#    * If X predicts Y it does not mean that X causes Y
#    * Accurate prediction depends heavily on measuring the right variables
#    * Although there are better and worse prediction models, more data and a simple model works really well
#    * Prediction is very hard, especially about the future references
# * **Causal**: to find out what happens to one variable when another changes
#    * Usually randomized studies are required to identify causation
#    * There are approaches to inferring causation in non-randomized studies, but they are complicated and sensitive to assumptions
#    * Causal relationships are usually identified as average effects, but may not apply to every individual
#    * Causal models are usually the "gold standard" for data analysis
# * **Mechanistic**: Understand the exact changes in variables that lead to changes in other variables for individual objects.
#    * Incredibly hard to infer, except in simple situations
#    * Usually modeled by a deterministic set of equations (physical/engineering science)
#    * Generally the random component of the data is measurement error
#    * If the equations are known but the parameters are not, they may be inferred with data analysis

# %% [markdown]
# ## Descriptive Analysis

# %% [markdown]
# Data I've collected:
# * [EPA historic national statistics on end-of-life (EOL)](https://edg.epa.gov/metadata/catalog/search/resource/details.page?uuid=C9310A59-16D2-4002-B36B-2B0A1C637D4E) for various types of municipal solid waste (MSW)
#   * figures available [here](https://www.epa.gov/facts-and-figures-about-materials-waste-and-recycling/national-overview-facts-and-figures-materials)
# * [MA municipal survey data](https://www.mass.gov/lists/recycling-solid-waste-data-for-massachusetts-cities-towns) for years 2009 through 2019
#   * Program and services description
#   * Trash Disposal & Recycling Tonnage collected through municipal program, including materials collected from residents, municipal buildings, schools, and businesses
# * [MA Combustor Overall Waste Composition](https://www.mass.gov/guides/solid-waste-master-plan#-waste-characterization-&-capacity-studies-) By Primary Material Category for 2010, 2013, 2016, and 2019
# * [MA Combustor and Disposal Rate](https://www.mass.gov/guides/solid-waste-master-plan) updates per year
#   * NOT per material
#   * per county
#   * export and import processing
# * [MA MSW Capacity](https://www.mass.gov/guides/solid-waste-master-plan#-waste-characterization-&-capacity-studies-) data
# * [MA participation Survey Results](https://www.mass.gov/lists/recycling-solid-waste-data-for-massachusetts-cities-towns)
# * Cambridge Residue Rates from recent 3-year audit (raw data not for public distribution)

# %%
import pandas as pd

# %% [markdown]
# ## Cleaning a single municipality survey

# %%
muServ19 = pd.read_csv('data/MA_MSW_Collection_Data/mudata19.csv', skiprows=3, usecols=[i for i in range(61)], index_col='Municipality Name')

# %%
muServ19.drop(columns=['Food Waste Service Type', ' # of weeks collected curbside',
       'Weeks the drop-off center open to residents','Swap-Shop',
       'Reuse area at transfer station/ recycling center?',
       'Compost Bin Distribution Program'], inplace=True)

# %%
muServ19.head(5)
# Out:
#                        Contact Name  Total Number of Households  \
# Municipality Name
# Abington           Angela Dahlstrom                      6558.0
# Acton                    Corey York                      9800.0
# Acushnet                 Dan Menard                      4304.0
# Adams                  Linda Cernik                      3867.0
# Agawam                 Tracy DeMaio                     12031.0
#
#                    Households Served by Municipal Trash Program  \
# Municipality Name
# Abington                                                 4486.0
# Acton                                                    3846.0
# Acushnet                                                 3591.0
# Adams                                                     664.0
# Agawam                                                   8879.0
#
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Abington                                                     4486.0
# Acton                                                        4335.0
# Acushnet                                                     3591.0
# Adams                                                         664.0
# Agawam                                                       8879.0
#
#                   Trash Service Type Carts for Trash  Trash Cart size  \
# Municipality Name
# Abington                    Curbside             Yes             64.0
# Acton                       Drop-off             NaN              NaN
# Acushnet                    Curbside             Yes             65.0
# Adams                       Drop-off             NaN              NaN
# Agawam                      Curbside             Yes             65.0
#
#                   Recycling Service Type Recycling Collection Frequency  \
# Municipality Name
# Abington                        Curbside                         Weekly
# Acton                           Drop-off                            NaN
# Acushnet                            Both                      Bi-weekly
# Adams                           Drop-off                            NaN
# Agawam                          Curbside                      Bi-weekly
#
#                   SS Recycling  ...  \
# Municipality Name               ...
# Abington                   Yes  ...
# Acton                      NaN  ...
# Acushnet                   Yes  ...
# Adams                      NaN  ...
# Agawam                     Yes  ...
#
#                   Does trash disposal tonnage include bulky waste?  \
# Municipality Name
# Abington                                                       Yes
# Acton                                                          Yes
# Acushnet                                                        No
# Adams                                                           No
# Agawam                                                          No
#
#                    Bulky waste tonnage Fee for bulky waste?  \
# Municipality Name
# Abington                           NaN                  Yes
# Acton                              NaN                  Yes
# Acushnet                         41.00                  Yes
# Adams                             4.43                  Yes
# Agawam                          275.17                  Yes
#
#                   Annual Bulky \nWaste \nLimit Tip Fee as of 1/1/2020  \
# Municipality Name
# Abington                                   NaN                  86.50
# Acton                                      NaN                  57.16
# Acushnet                                   NaN                  64.60
# Adams                                      NaN                 110.00
# Agawam                                    30.0                  74.00
#
#                   Tons Single Stream Recyclables Newspaper Cardboard  \
# Municipality Name
# Abington                                 1413.42       NaN       NaN
# Acton                                        NaN       NaN       NaN
# Acushnet                                  879.50       3.7      20.0
# Adams                                        NaN       NaN       NaN
# Agawam                                   2238.00       NaN       NaN
#
#                   Mixed Paper Commingled
# Municipality Name
# Abington                  NaN        NaN
# Acton                  683.04     407.27
# Acushnet                16.94      27.40
# Adams                   94.13      45.48
# Agawam                    NaN        NaN
#
# [5 rows x 54 columns]

# %%
muServ19.shape
# Out:
# (352, 54)

# %%
muServ19 = muServ19[muServ19['Contact Name'] != '- - DID NOT REPORT - -']

# %%
muServ19.shape
# Out:
# (286, 54)

# %%
muServ19[muServ19.loc[:,'Households Served by Municipal Trash Program':'Households Served by Municipal Recycling Program'].sum(axis=1) == 0]
# Out:
#                       Contact Name  Total Number of Households  \
# Municipality Name
# Charlton           Kara Hmielowski                      4380.0
# Clarksburg            Linda Cernik                       720.0
# Hawley                   Jan Ameen                       166.0
# Hull                Joyce Sullivan                     10417.0
# Lee                   Peter Hofman                      2489.0
# Oakham              Ashley Sturges                       660.0
# Princeton           Terri Longtine                      1255.0
# Sunderland               Jan Ameen                       895.0
# Uxbridge             Kristin Black                      5500.0
# Wareham            Marilyn Russell                     12274.0
#
#                    Households Served by Municipal Trash Program  \
# Municipality Name
# Charlton                                                    0.0
# Clarksburg                                                  0.0
# Hawley                                                      0.0
# Hull                                                        0.0
# Lee                                                         0.0
# Oakham                                                      0.0
# Princeton                                                   0.0
# Sunderland                                                  0.0
# Uxbridge                                                    0.0
# Wareham                                                     0.0
#
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Charlton                                                        0.0
# Clarksburg                                                      0.0
# Hawley                                                          0.0
# Hull                                                            0.0
# Lee                                                             0.0
# Oakham                                                          0.0
# Princeton                                                       0.0
# Sunderland                                                      0.0
# Uxbridge                                                        0.0
# Wareham                                                         0.0
#
#                   Trash Service Type Carts for Trash  Trash Cart size  \
# Municipality Name
# Charlton                        None             NaN              NaN
# Clarksburg                      None             NaN              NaN
# Hawley                          None             NaN              NaN
# Hull                            None             NaN              NaN
# Lee                             None             NaN              NaN
# Oakham                          None             NaN              NaN
# Princeton                       None             NaN              NaN
# Sunderland                      None             NaN              NaN
# Uxbridge                        None             NaN              NaN
# Wareham                     Drop-off             NaN              NaN
#
#                   Recycling Service Type Recycling Collection Frequency  \
# Municipality Name
# Charlton                            None                            NaN
# Clarksburg                          None                            NaN
# Hawley                              None                            NaN
# Hull                                None                            NaN
# Lee                                 None                            NaN
# Oakham                              None                            NaN
# Princeton                           None                            NaN
# Sunderland                          None                            NaN
# Uxbridge                            None                            NaN
# Wareham                         Drop-off                            NaN
#
#                   SS Recycling  ...  \
# Municipality Name               ...
# Charlton                   NaN  ...
# Clarksburg                 NaN  ...
# Hawley                     NaN  ...
# Hull                       NaN  ...
# Lee                        NaN  ...
# Oakham                     NaN  ...
# Princeton                  NaN  ...
# Sunderland                 NaN  ...
# Uxbridge                   NaN  ...
# Wareham                    NaN  ...
#
#                   Does trash disposal tonnage include bulky waste?  \
# Municipality Name
# Charlton                                                        No
# Clarksburg                                                      No
# Hawley                                                         Yes
# Hull                                                           Yes
# Lee                                                             No
# Oakham                                                         Yes
# Princeton                                                       No
# Sunderland                                                      No
# Uxbridge                                                        No
# Wareham                                                         No
#
#                    Bulky waste tonnage Fee for bulky waste?  \
# Municipality Name
# Charlton                          0.00                  NaN
# Clarksburg                        1.53                  Yes
# Hawley                             NaN                  NaN
# Hull                               NaN                  NaN
# Lee                               0.00                  NaN
# Oakham                             NaN                  NaN
# Princeton                         0.00                  NaN
# Sunderland                        0.00                  NaN
# Uxbridge                          0.00                  NaN
# Wareham                           0.00                  NaN
#
#                   Annual Bulky \nWaste \nLimit Tip Fee as of 1/1/2020  \
# Municipality Name
# Charlton                                   NaN                    NaN
# Clarksburg                                 NaN                    NaN
# Hawley                                     NaN                    NaN
# Hull                                       NaN                    NaN
# Lee                                        NaN                    NaN
# Oakham                                     NaN                    NaN
# Princeton                                  NaN                    NaN
# Sunderland                                 NaN                    NaN
# Uxbridge                                   NaN                    NaN
# Wareham                                    NaN                    NaN
#
#                   Tons Single Stream Recyclables Newspaper Cardboard  \
# Municipality Name
# Charlton                                     0.0       0.0       0.0
# Clarksburg                                   NaN       NaN       NaN
# Hawley                                       NaN       NaN       NaN
# Hull                                         0.0       0.0       0.0
# Lee                                          NaN       NaN       NaN
# Oakham                                       NaN       NaN       NaN
# Princeton                                    0.0       0.0       5.0
# Sunderland                                   NaN       NaN       NaN
# Uxbridge                                     0.0       0.0       0.0
# Wareham                                      NaN       NaN      37.0
#
#                   Mixed Paper Commingled
# Municipality Name
# Charlton                  0.0        0.0
# Clarksburg                NaN        NaN
# Hawley                    NaN        NaN
# Hull                      0.0        0.0
# Lee                       NaN        NaN
# Oakham                    NaN        NaN
# Princeton                 6.4        1.4
# Sunderland                NaN        NaN
# Uxbridge                  0.0        0.0
# Wareham                  25.9       32.7
#
# [10 rows x 54 columns]

# %% [markdown]
# There isn't much I can do with towns where both their recycling service type is `None`. If they have a service specified but their households served is 0 (for either trash or recycling), I'll just default to the total number of households.

# %%
muServ19 = muServ19[muServ19['Recycling Service Type'] != 'None']
muServ19.shape
# Out:
# (277, 54)

# %%
muServ19.loc['Wareham','Households Served by Municipal Recycling Program'] = muServ19.loc['Wareham','Total Number of Households']

# %%
muServ19.loc['Wareham']
# Out:
# Contact Name                                                                                        Marilyn Russell
# Total Number of Households                                                                                    12274
# Households Served by Municipal Trash Program                                                                      0
# Households Served by Municipal Recycling Program                                                              12274
# Trash Service Type                                                                                         Drop-off
# Carts for Trash                                                                                                 NaN
# Trash Cart size                                                                                                 NaN
# Recycling Service Type                                                                                     Drop-off
# Recycling Collection Frequency                                                                                  NaN
# SS Recycling                                                                                                    NaN
# Carts for Recycling                                                                                             NaN
# Recycling Cart Size                                                                                             NaN
# Municipal Buildings Trash and Recycling Service                                                                Both
# School Trash and Recycling Service                                                                             Both
# Business Trash and Recycling Service                                                                        Neither
# Non-resident Trash and Recycling Service                                                                    Neither
# Solid Waste program funded by property tax?                                                                     NaN
# Solid Waste program funded by annual fee?                                                                       NaN
# Solid Waste program funded by transfer station access fee?                                                      NaN
# Solid Waste program funded by per-visit fee?                                                                    NaN
# Solid Waste program funded by PAYT/ SMART revenue?                                                              NaN
# What is the annual fee?                                                                                         NaN
# What is the transfer station access fee?                                                                        NaN
# What is the per-visit fee?                                                                                      NaN
# PAYT/ SMART                                                                                                     NaN
# Enforced Trash Limits at Curb                                                                                   NaN
# Maximum # bags/ barrels per week                                                                                NaN
# Barrel size in gallons (eg 32 64 etc)                                                                           NaN
# Trash Enforced by Muni                                                                                          NaN
# Trash Enforced by Hauler                                                                                        NaN
# Dedicated Trash Enforcement Personnel                                                                           NaN
# Enforced Mandatory Recycling                                                                                    NaN
# Applies to Residential Generators Eligible to be Served by Municipal Program                                    NaN
# Applies to Residential Generators not Eligible to be Served by the Municipal Program                            NaN
# Applies to Commercial Generators                                                                                NaN
# Recycling Enforced by Muni                                                                                      NaN
# Recycling Enforced by Hauler                                                                                    NaN
# Dedicated Mandatory Recycling Enforcement Personnel                                                             NaN
# # Hours Enforcement Personnel on Street                                                                         NaN
# Private Hauler regulations that require recycling                                                               Yes
# Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program                    Yes
# Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program                NaN
# Applies to Commercial Generators.1                                                                              NaN
# Trash Disposal Tonnage                                                                                            0
# Does trash disposal tonnage include bulky waste?                                                                 No
# Bulky waste tonnage                                                                                               0
# Fee for bulky waste?                                                                                            NaN
# Annual Bulky \nWaste \nLimit                                                                                    NaN
# Tip Fee as of 1/1/2020                                                                                          NaN
# Tons Single Stream Recyclables                                                                                  NaN
# Newspaper                                                                                                       NaN
# Cardboard                                                                                                        37
# Mixed Paper                                                                                                    25.9
# Commingled                                                                                                     32.7
# Name: Wareham, dtype: object

# %%
muServ19.columns
# Out:
# Index(['Contact Name', 'Total Number of Households',
#        'Households Served by Municipal Trash Program',
#        'Households Served by Municipal Recycling Program',
#        'Trash Service Type', 'Carts for Trash', 'Trash Cart size',
#        'Recycling Service Type', 'Recycling Collection Frequency',
#        'SS Recycling', 'Carts for Recycling', 'Recycling Cart Size',
#        'Municipal Buildings Trash and Recycling Service',
#        'School Trash and Recycling Service',
#        'Business Trash and Recycling Service',
#        'Non-resident Trash and Recycling Service',
#        'Solid Waste program funded by property tax?',
#        'Solid Waste program funded by annual fee?',
#        'Solid Waste program funded by transfer station access fee?',
#        'Solid Waste program funded by per-visit fee?',
#        'Solid Waste program funded by PAYT/ SMART revenue?',
#        'What is the annual fee?', 'What is the transfer station access fee?',
#        'What is the per-visit fee?', 'PAYT/ SMART',
#        'Enforced Trash Limits at Curb', 'Maximum # bags/ barrels per week',
#        'Barrel size in gallons (eg 32 64 etc)', 'Trash Enforced by Muni',
#        'Trash Enforced by Hauler', 'Dedicated Trash Enforcement Personnel',
#        'Enforced Mandatory Recycling',
#        'Applies to Residential Generators Eligible to be Served by Municipal Program',
#        'Applies to Residential Generators not Eligible to be Served by the Municipal Program',
#        'Applies to Commercial Generators', 'Recycling Enforced by Muni',
#        'Recycling Enforced by Hauler',
#        'Dedicated Mandatory Recycling Enforcement Personnel',
#        '# Hours Enforcement Personnel on Street',
#        'Private Hauler regulations that require recycling',
#        'Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
#        'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program',
#        'Applies to Commercial Generators.1', 'Trash Disposal Tonnage',
#        'Does trash disposal tonnage include bulky waste?',
#        'Bulky waste tonnage', 'Fee for bulky waste?',
#        'Annual Bulky \nWaste \nLimit', 'Tip Fee as of 1/1/2020',
#        'Tons Single Stream Recyclables', 'Newspaper', 'Cardboard',
#        'Mixed Paper', 'Commingled'],
#       dtype='object')

# %%
serv_fund = ['Solid Waste program funded by property tax?',
       'Solid Waste program funded by annual fee?',
       'Solid Waste program funded by transfer station access fee?',
       'Solid Waste program funded by per-visit fee?',
       'Solid Waste program funded by PAYT/ SMART revenue?',
       'What is the annual fee?', 'What is the transfer station access fee?',
       'What is the per-visit fee?', 'PAYT/ SMART',]

# %%
gen_serv = ['Municipal Buildings Trash and Recycling Service',
       'School Trash and Recycling Service',
       'Business Trash and Recycling Service',
       'Non-resident Trash and Recycling Service', ]

# %%
trash_serv = ['Households Served by Municipal Trash Program', 'Trash Service Type', 'Carts for Trash', 'Trash Cart size', 'Does trash disposal tonnage include bulky waste?','Fee for bulky waste?',
       'Annual Bulky \nWaste \nLimit', 'Tip Fee as of 1/1/2020', 'Enforced Trash Limits at Curb', 'Maximum # bags/ barrels per week',
       'Barrel size in gallons (eg 32 64 etc)', 'Trash Enforced by Muni',
       'Trash Enforced by Hauler', 'Dedicated Trash Enforcement Personnel', ]

# %%
trash_tonnage_data = ['Households Served by Municipal Trash Program', 'Trash Disposal Tonnage', 'Bulky waste tonnage', ]

# %%
recycle_serv= ['Households Served by Municipal Recycling Program', 'Recycling Service Type', 'Recycling Collection Frequency',
       'SS Recycling', 'Carts for Recycling', 'Recycling Cart Size', 'Enforced Mandatory Recycling',
       'Applies to Residential Generators Eligible to be Served by Municipal Program',
       'Applies to Residential Generators not Eligible to be Served by the Municipal Program',
       'Applies to Commercial Generators', 'Recycling Enforced by Muni',
       'Recycling Enforced by Hauler',
       'Dedicated Mandatory Recycling Enforcement Personnel',
       '# Hours Enforcement Personnel on Street', 'Private Hauler regulations that require recycling',
       'Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program',
       'Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program',
       'Applies to Commercial Generators.1']

# %%
recycle_tonnage_data = ['Households Served by Municipal Recycling Program', 'Tons Single Stream Recyclables', 'Newspaper', 'Cardboard',
       'Mixed Paper', 'Commingled']

# %%
muServ19.loc[:,recycle_serv]
# Out:
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Abington                                                     4486.0
# Acton                                                        4335.0
# Acushnet                                                     3591.0
# Adams                                                         664.0
# Agawam                                                       8879.0
# ...                                                             ...
# Woburn                                                      11240.0
# Worcester                                                   67000.0
# Worthington                                                   362.0
# Wrentham                                                     4048.0
# Yarmouth                                                    10143.0
#
#                   Recycling Service Type Recycling Collection Frequency  \
# Municipality Name
# Abington                        Curbside                         Weekly
# Acton                           Drop-off                            NaN
# Acushnet                            Both                      Bi-weekly
# Adams                           Drop-off                            NaN
# Agawam                          Curbside                      Bi-weekly
# ...                                  ...                            ...
# Woburn                          Curbside                      Bi-weekly
# Worcester                           Both                         Weekly
# Worthington                     Drop-off                            NaN
# Wrentham                        Curbside                      Bi-weekly
# Yarmouth                        Drop-off                            NaN
#
#                   SS Recycling Carts for Recycling  Recycling Cart Size  \
# Municipality Name
# Abington                   Yes                 Yes                 64.0
# Acton                      NaN                 NaN                  NaN
# Acushnet                   Yes                 Yes                 96.0
# Adams                      NaN                 NaN                  NaN
# Agawam                     Yes                 Yes                 95.0
# ...                        ...                 ...                  ...
# Woburn                     Yes                 NaN                  NaN
# Worcester                  Yes                 NaN                  NaN
# Worthington                NaN                 NaN                  NaN
# Wrentham                   Yes                 Yes                 96.0
# Yarmouth                   Yes                 NaN                  NaN
#
#                   Enforced Mandatory Recycling  \
# Municipality Name
# Abington                                   Yes
# Acton                                      Yes
# Acushnet                                   Yes
# Adams                                      Yes
# Agawam                                      No
# ...                                        ...
# Woburn                                     NaN
# Worcester                                  Yes
# Worthington                                Yes
# Wrentham                                   Yes
# Yarmouth                                   NaN
#
#                   Applies to Residential Generators Eligible to be Served by Municipal Program  \
# Municipality Name
# Abington                                                         Yes
# Acton                                                            Yes
# Acushnet                                                         Yes
# Adams                                                            Yes
# Agawam                                                           Yes
# ...                                                              ...
# Woburn                                                           NaN
# Worcester                                                        Yes
# Worthington                                                      Yes
# Wrentham                                                         Yes
# Yarmouth                                                         NaN
#
#                   Applies to Residential Generators not Eligible to be Served by the Municipal Program  \
# Municipality Name
# Abington                                                         NaN
# Acton                                                            Yes
# Acushnet                                                         NaN
# Adams                                                            NaN
# Agawam                                                           NaN
# ...                                                              ...
# Woburn                                                           NaN
# Worcester                                                        NaN
# Worthington                                                      Yes
# Wrentham                                                         NaN
# Yarmouth                                                         NaN
#
#                   Applies to Commercial Generators Recycling Enforced by Muni  \
# Municipality Name
# Abington                                       NaN                        Yes
# Acton                                          Yes                        Yes
# Acushnet                                       NaN                        Yes
# Adams                                          Yes                        Yes
# Agawam                                         NaN                        NaN
# ...                                            ...                        ...
# Woburn                                         NaN                        NaN
# Worcester                                      NaN                        Yes
# Worthington                                    Yes                        Yes
# Wrentham                                       NaN                        Yes
# Yarmouth                                       NaN                        NaN
#
#                   Recycling Enforced by Hauler  \
# Municipality Name
# Abington                                   Yes
# Acton                                      NaN
# Acushnet                                   Yes
# Adams                                      Yes
# Agawam                                     NaN
# ...                                        ...
# Woburn                                     NaN
# Worcester                                  Yes
# Worthington                                NaN
# Wrentham                                   Yes
# Yarmouth                                   NaN
#
#                   Dedicated Mandatory Recycling Enforcement Personnel  \
# Municipality Name
# Abington                                                         Yes
# Acton                                                             No
# Acushnet                                                          No
# Adams                                                             No
# Agawam                                                           NaN
# ...                                                              ...
# Woburn                                                           NaN
# Worcester                                                        Yes
# Worthington                                                       No
# Wrentham                                                          No
# Yarmouth                                                         NaN
#
#                    # Hours Enforcement Personnel on Street  \
# Municipality Name
# Abington                                              20.0
# Acton                                                  NaN
# Acushnet                                               NaN
# Adams                                                  NaN
# Agawam                                                 NaN
# ...                                                    ...
# Woburn                                                 NaN
# Worcester                                             40.0
# Worthington                                            NaN
# Wrentham                                               NaN
# Yarmouth                                               NaN
#
#                   Private Hauler regulations that require recycling  \
# Municipality Name
# Abington                                                        Yes
# Acton                                                           NaN
# Acushnet                                                        Yes
# Adams                                                           Yes
# Agawam                                                          NaN
# ...                                                             ...
# Woburn                                                          NaN
# Worcester                                                       NaN
# Worthington                                                     NaN
# Wrentham                                                        NaN
# Yarmouth                                                        NaN
#
#                   Applies to Haulers Serving Residential Generators Eligible to be Served by Municipal Program  \
# Municipality Name
# Abington                                                         Yes
# Acton                                                            NaN
# Acushnet                                                         Yes
# Adams                                                            Yes
# Agawam                                                           NaN
# ...                                                              ...
# Woburn                                                           NaN
# Worcester                                                        NaN
# Worthington                                                      NaN
# Wrentham                                                         NaN
# Yarmouth                                                         NaN
#
#                   Applies to Haulers Serving Residential Generators Not Eligible to be Served by Municipal Program  \
# Municipality Name
# Abington                                                         Yes
# Acton                                                            NaN
# Acushnet                                                         NaN
# Adams                                                            NaN
# Agawam                                                           NaN
# ...                                                              ...
# Woburn                                                           NaN
# Worcester                                                        NaN
# Worthington                                                      NaN
# Wrentham                                                         NaN
# Yarmouth                                                         NaN
#
#                   Applies to Commercial Generators.1
# Municipality Name
# Abington                                         Yes
# Acton                                            NaN
# Acushnet                                         NaN
# Adams                                            Yes
# Agawam                                           NaN
# ...                                              ...
# Woburn                                           NaN
# Worcester                                        NaN
# Worthington                                      NaN
# Wrentham                                         NaN
# Yarmouth                                         NaN
#
# [277 rows x 18 columns]

# %% [markdown]
# ## Mini-EDA on Recycling for 2019

# %% [markdown]
# ### Just looking at recycle tonnage data...

# %%
recycle19 = muServ19.loc[:,recycle_tonnage_data]
recycle19
# Out:
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Abington                                                     4486.0
# Acton                                                        4335.0
# Acushnet                                                     3591.0
# Adams                                                         664.0
# Agawam                                                       8879.0
# ...                                                             ...
# Woburn                                                      11240.0
# Worcester                                                   67000.0
# Worthington                                                   362.0
# Wrentham                                                     4048.0
# Yarmouth                                                    10143.0
#
#                    Tons Single Stream Recyclables  Newspaper  Cardboard  \
# Municipality Name
# Abington                                  1413.42        NaN        NaN
# Acton                                         NaN        NaN        NaN
# Acushnet                                   879.50        3.7       20.0
# Adams                                         NaN        NaN        NaN
# Agawam                                    2238.00        NaN        NaN
# ...                                           ...        ...        ...
# Woburn                                    2071.74        NaN        NaN
# Worcester                                10289.57        NaN        NaN
# Worthington                                   NaN        NaN        NaN
# Wrentham                                  1276.02        NaN        NaN
# Yarmouth                                      NaN      156.0      369.0
#
#                    Mixed Paper  Commingled
# Municipality Name
# Abington                   NaN         NaN
# Acton                   683.04      407.27
# Acushnet                 16.94       27.40
# Adams                    94.13       45.48
# Agawam                     NaN         NaN
# ...                        ...         ...
# Woburn                     NaN         NaN
# Worcester                  NaN         NaN
# Worthington              47.47       43.08
# Wrentham                   NaN         NaN
# Yarmouth                204.00      460.00
#
# [277 rows x 6 columns]

# %%
recycle19['tons_total'] = recycle19.loc[:,'Tons Single Stream Recyclables':'Commingled'].sum(axis=1)
recycle19.head()
# Out:
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Abington                                                     4486.0
# Acton                                                        4335.0
# Acushnet                                                     3591.0
# Adams                                                         664.0
# Agawam                                                       8879.0
#
#                    Tons Single Stream Recyclables  Newspaper  Cardboard  \
# Municipality Name
# Abington                                  1413.42        NaN        NaN
# Acton                                         NaN        NaN        NaN
# Acushnet                                   879.50        3.7       20.0
# Adams                                         NaN        NaN        NaN
# Agawam                                    2238.00        NaN        NaN
#
#                    Mixed Paper  Commingled  tons_total
# Municipality Name
# Abington                   NaN         NaN     1413.42
# Acton                   683.04      407.27     1090.31
# Acushnet                 16.94       27.40      947.54
# Adams                    94.13       45.48      139.61
# Agawam                     NaN         NaN     2238.00

# %%
recycle19['tons/hh'] = recycle19['tons_total'] / recycle19['Households Served by Municipal Recycling Program']
recycle19.head()
# Out:
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Abington                                                     4486.0
# Acton                                                        4335.0
# Acushnet                                                     3591.0
# Adams                                                         664.0
# Agawam                                                       8879.0
#
#                    Tons Single Stream Recyclables  Newspaper  Cardboard  \
# Municipality Name
# Abington                                  1413.42        NaN        NaN
# Acton                                         NaN        NaN        NaN
# Acushnet                                   879.50        3.7       20.0
# Adams                                         NaN        NaN        NaN
# Agawam                                    2238.00        NaN        NaN
#
#                    Mixed Paper  Commingled  tons_total   tons/hh
# Municipality Name
# Abington                   NaN         NaN     1413.42  0.315074
# Acton                   683.04      407.27     1090.31  0.251513
# Acushnet                 16.94       27.40      947.54  0.263865
# Adams                    94.13       45.48      139.61  0.210256
# Agawam                     NaN         NaN     2238.00  0.252055

# %%
recycle19.fillna(value=0, inplace=True)

# %%
recycle19.describe()
# Out:
#        Households Served by Municipal Recycling Program  \
# count                                        277.000000
# mean                                        6985.324910
# std                                        17314.802057
# min                                           51.000000
# 25%                                         1002.000000
# 50%                                         3450.000000
# 75%                                         7995.000000
# max                                       260000.000000
#
#        Tons Single Stream Recyclables   Newspaper    Cardboard  Mixed Paper  \
# count                      277.000000  277.000000   277.000000   277.000000
# mean                      1295.037762    5.370325    62.169675   128.432924
# std                       2841.260496   22.690371   232.305061   305.208449
# min                          0.000000    0.000000     0.000000     0.000000
# 25%                          0.000000    0.000000     0.000000     0.000000
# 50%                        107.560000    0.000000     0.000000     1.000000
# 75%                       1807.020000    0.000000    24.000000    90.000000
# max                      37050.000000  179.090000  3000.000000  1969.100000
#
#         Commingled    tons_total     tons/hh
# count   277.000000    277.000000  277.000000
# mean    132.101697   1623.112383    0.249578
# std     340.411181   2815.436063    0.094329
# min       0.000000      3.250000    0.007789
# 25%       0.000000    194.000000    0.188834
# 50%      13.000000    806.290000    0.247423
# 75%      96.310000   2136.000000    0.302714
# max    3300.000000  37050.000000    0.758979

# %%
import plotly.express as px

# %%
px.histogram(recycle19['tons/hh'])

# %% [markdown]
# The mean tons of recycling collected per household was 0.25. Min tons is 0.078, max is 0.759. Quite a range. Afterlooking at the histogram, it seems that the IQR is most representative of the distribution. It looks like there are 5 outliter above 0.46 tons/hh. I'll confirm through a boxplot.

# %%
px.box(recycle19['tons/hh'], orientation='h')

# %% [markdown]
# Yeah, 5 outliers. These outliers may be of particular interest. Why are they so much higher than the rest of the population? How do these municipalities faire with trash collection; will their trash tonnages also be higher? Or perhaps their trash tonnages are perportionally lower? I'll record these outlier municipalities.

# %%
recycle19_outliers = recycle19[recycle19['tons/hh'] > 0.46]
recycle19_outliers
# Out:
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Bourne                                                       8135.0
# Concord                                                      3800.0
# Devens                                                        145.0
# Needham                                                      5349.0
# Provincetown                                                 2348.0
#
#                    Tons Single Stream Recyclables  Newspaper  Cardboard  \
# Municipality Name
# Bourne                                    5646.89        0.0      412.0
# Concord                                      0.00        0.0     1307.0
# Devens                                       0.00        0.0        0.0
# Needham                                    232.00        0.0      422.0
# Provincetown                              1244.00        0.0      192.0
#
#                    Mixed Paper  Commingled  tons_total   tons/hh
# Municipality Name
# Bourne                    0.00         0.0     6058.89  0.744793
# Concord                 965.82       611.3     2884.12  0.758979
# Devens                   44.00        43.2       87.20  0.601379
# Needham                1172.00       726.0     2552.00  0.477099
# Provincetown              0.00         0.0     1436.00  0.611584

# %% [markdown]
# It's strange that 3 of these municipalities have SS values recorded in addition to separated materials like cardboard. Needham even has a mix of SS and Commingled streams... I wonder how common that is.
#
# Devens is very small, so I wonder how useful it is to look at their data.

# %%
ss_plus_recycle19 = recycle19[(recycle19['Tons Single Stream Recyclables'] > 0) & (recycle19.loc[:,'Newspaper':'Commingled'].sum(axis=1) > 0)]
ss_plus_recycle19.describe()
# Out:
#        Households Served by Municipal Recycling Program  \
# count                                         45.000000
# mean                                        8926.422222
# std                                         9803.471647
# min                                          939.000000
# 25%                                         2687.000000
# 50%                                         5349.000000
# 75%                                         9810.000000
# max                                        44700.000000
#
#        Tons Single Stream Recyclables   Newspaper    Cardboard  Mixed Paper  \
# count                       45.000000   45.000000    45.000000    45.000000
# mean                      2197.342222   10.096444   164.244444    49.180222
# std                       2403.916565   28.874841   453.703105   176.530217
# min                          2.500000    0.000000     0.000000     0.000000
# 25%                        394.000000    0.000000     7.000000     0.000000
# 50%                       1289.000000    0.000000    45.000000     0.000000
# 75%                       3028.000000    0.000000   161.000000    27.130000
# max                       9274.920000  136.020000  3000.000000  1172.000000
#
#        Commingled   tons_total    tons/hh
# count   45.000000    45.000000  45.000000
# mean    44.455778  2465.319111   0.280873
# std    117.565176  2546.254116   0.121731
# min      0.000000   124.230000   0.089544
# 25%      0.000000   663.600000   0.211984
# 50%      2.960000  1436.000000   0.274047
# 75%     30.400000  3113.000000   0.333962
# max    726.000000  9517.920000   0.744793

# %% [markdown]
# So 45/277 municipalities have both single stream and separate stream data. This group's mean tons/hh is 0.281 which is slightly higher than the total population (0.250). I wonder how purly multi-stream and purly single-stream municipalities compare.

# %%
ms_recycle19 = recycle19[(recycle19['Tons Single Stream Recyclables'] == 0) & (recycle19.loc[:,'Newspaper':'Commingled'].sum(axis=1) > 0)]
ss_recycle19 = recycle19[(recycle19['Tons Single Stream Recyclables'] > 0) & (recycle19.loc[:,'Newspaper':'Commingled'].sum(axis=1) == 0)]

# %%
print(ms_recycle19.shape, ss_recycle19.shape)
# Out:
# (127, 8) (105, 8)

# %%
import plotly.graph_objects as go
from plotly.graph_objs import *

layout = Layout(
    boxgap=0.1,
    height = 600
)
fig = go.Figure(layout=layout)
fig.add_trace(go.Box(
    x=ss_recycle19['tons/hh'],
    name='SS',
    marker_color='#AA22AA'
))
fig.add_trace(go.Box(
    x=ms_recycle19['tons/hh'],
    name='MS',
    marker_color='#FF851B'
))
fig.add_trace(go.Box(
    x=ss_plus_recycle19['tons/hh'],
    name='SS+',
    marker_color='#FF4136'
))
fig.add_trace(go.Box(
    x=recycle19['tons/hh'],
    name='All',
    marker_color='#3D9970'
))

fig.update_layout(
    xaxis=dict(title='recycling tons/hh', zeroline=False),
    boxmode='overlay'
)

fig.update_traces(orientation='h') # horizontal box plots

fig.show()

# %% [markdown]
# So the single stream and single stream + (with some separate recycables) appear to have higher quantities of recycables per household than the total population, with ss+ being slightly higher than them all. Multistream-only has lower rates of recycling.

# %% [markdown]
# ### Factoring in trash tonnage data...

# %%
trash19 = muServ19.loc[:,trash_tonnage_data]
trash19
# Out:
#                    Households Served by Municipal Trash Program  \
# Municipality Name
# Abington                                                 4486.0
# Acton                                                    3846.0
# Acushnet                                                 3591.0
# Adams                                                     664.0
# Agawam                                                   8879.0
# ...                                                         ...
# Woburn                                                  11240.0
# Worcester                                               53000.0
# Worthington                                               362.0
# Wrentham                                                 4048.0
# Yarmouth                                                 9434.0
#
#                    Trash Disposal Tonnage  Bulky waste tonnage
# Municipality Name
# Abington                          3826.66                  NaN
# Acton                             2148.67                  NaN
# Acushnet                          3405.38                41.00
# Adams                              130.04                 4.43
# Agawam                            6442.00               275.17
# ...                                   ...                  ...
# Woburn                           13368.65                  NaN
# Worcester                        21899.33                 0.00
# Worthington                        181.94                80.55
# Wrentham                          3082.25                 0.00
# Yarmouth                          8428.00                 0.00
#
# [277 rows x 3 columns]

# %%
trash19.fillna(value=0, inplace=True)

# %%
trash19
# Out:
#                    Households Served by Municipal Trash Program  \
# Municipality Name
# Abington                                                 4486.0
# Acton                                                    3846.0
# Acushnet                                                 3591.0
# Adams                                                     664.0
# Agawam                                                   8879.0
# ...                                                         ...
# Woburn                                                  11240.0
# Worcester                                               53000.0
# Worthington                                               362.0
# Wrentham                                                 4048.0
# Yarmouth                                                 9434.0
#
#                    Trash Disposal Tonnage  Bulky waste tonnage
# Municipality Name
# Abington                          3826.66                 0.00
# Acton                             2148.67                 0.00
# Acushnet                          3405.38                41.00
# Adams                              130.04                 4.43
# Agawam                            6442.00               275.17
# ...                                   ...                  ...
# Woburn                           13368.65                 0.00
# Worcester                        21899.33                 0.00
# Worthington                        181.94                80.55
# Wrentham                          3082.25                 0.00
# Yarmouth                          8428.00                 0.00
#
# [277 rows x 3 columns]

# %%
trash19['tons_total'] = trash19.loc[:,'Trash Disposal Tonnage':'Bulky waste tonnage'].sum(axis=1)
trash19.head()
# Out:
#                    Households Served by Municipal Trash Program  \
# Municipality Name
# Abington                                                 4486.0
# Acton                                                    3846.0
# Acushnet                                                 3591.0
# Adams                                                     664.0
# Agawam                                                   8879.0
#
#                    Trash Disposal Tonnage  Bulky waste tonnage  tons_total
# Municipality Name
# Abington                          3826.66                 0.00     3826.66
# Acton                             2148.67                 0.00     2148.67
# Acushnet                          3405.38                41.00     3446.38
# Adams                              130.04                 4.43      134.47
# Agawam                            6442.00               275.17     6717.17

# %%
trash19['tons/hh'] = trash19['tons_total'] / trash19['Households Served by Municipal Trash Program']
trash19.head()
# Out:
#                    Households Served by Municipal Trash Program  \
# Municipality Name
# Abington                                                 4486.0
# Acton                                                    3846.0
# Acushnet                                                 3591.0
# Adams                                                     664.0
# Agawam                                                   8879.0
#
#                    Trash Disposal Tonnage  Bulky waste tonnage  tons_total  \
# Municipality Name
# Abington                          3826.66                 0.00     3826.66
# Acton                             2148.67                 0.00     2148.67
# Acushnet                          3405.38                41.00     3446.38
# Adams                              130.04                 4.43      134.47
# Agawam                            6442.00               275.17     6717.17
#
#                     tons/hh
# Municipality Name
# Abington           0.853023
# Acton              0.558677
# Acushnet           0.959727
# Adams              0.202515
# Agawam             0.756523

# %%
trash19.describe()
# Out:
#        Households Served by Municipal Trash Program  Trash Disposal Tonnage  \
# count                                    277.000000              277.000000
# mean                                    6717.931408             5144.469964
# std                                    17003.364009            12625.504709
# min                                        0.000000                0.000000
# 25%                                      885.000000              496.060000
# 50%                                     3309.000000             2149.680000
# 75%                                     7856.000000             5926.880000
# max                                   260000.000000           188113.000000
#
#        Bulky waste tonnage     tons_total     tons/hh
# count           277.000000     277.000000  274.000000
# mean             78.264404    5222.734368         inf
# std             276.130182   12639.313586         NaN
# min               0.000000       0.000000    0.124967
# 25%               0.000000     575.880000    0.548730
# 50%               0.000000    2182.650000    0.710989
# 75%              29.100000    6195.800000    0.860657
# max            2501.000000  188113.000000         inf

# %%
trash19.sort_values(by='tons/hh')
# Out:
#                    Households Served by Municipal Trash Program  \
# Municipality Name
# Blandford                                                 300.0
# Hampden                                                   600.0
# Adams                                                     664.0
# Mount Washington                                          146.0
# Sturbridge                                               1882.0
# ...                                                         ...
# Lanesborough                                                0.0
# Westminster                                                 0.0
# Leicester                                                   0.0
# New Ashford                                                 0.0
# Wareham                                                     0.0
#
#                    Trash Disposal Tonnage  Bulky waste tonnage  tons_total  \
# Municipality Name
# Blandford                           37.49                 0.00       37.49
# Hampden                            100.50                 0.00      100.50
# Adams                              130.04                 4.43      134.47
# Mount Washington                    25.11                 6.04       31.15
# Sturbridge                         420.00                 0.00      420.00
# ...                                   ...                  ...         ...
# Lanesborough                         0.00                 2.33        2.33
# Westminster                       2566.00                 0.00     2566.00
# Leicester                            0.00                 0.00        0.00
# New Ashford                          0.00                 0.00        0.00
# Wareham                              0.00                 0.00        0.00
#
#                     tons/hh
# Municipality Name
# Blandford          0.124967
# Hampden            0.167500
# Adams              0.202515
# Mount Washington   0.213356
# Sturbridge         0.223167
# ...                     ...
# Lanesborough            inf
# Westminster             inf
# Leicester               NaN
# New Ashford             NaN
# Wareham                 NaN
#
# [277 rows x 5 columns]

# %%
trash19[(trash19['Households Served by Municipal Trash Program'] == 0) & (trash19['tons_total'] > 0)]
# Out:
#                    Households Served by Municipal Trash Program  \
# Municipality Name
# Devens                                                      0.0
# Lanesborough                                                0.0
# Westminster                                                 0.0
#
#                    Trash Disposal Tonnage  Bulky waste tonnage  tons_total  \
# Municipality Name
# Devens                              79.66                 0.00       79.66
# Lanesborough                         0.00                 2.33        2.33
# Westminster                       2566.00                 0.00     2566.00
#
#                    tons/hh
# Municipality Name
# Devens                 inf
# Lanesborough           inf
# Westminster            inf

# %% [markdown]
# I don't want to remove these three municipalities from the total dataset because they do include recycling data which I am ultimately interested in. However, I will manually remove them from the trash19 dataframe. Actually, I'm going to remove any that are not serving any households.

# %%
trash19 = trash19[trash19['Households Served by Municipal Trash Program'] != 0]

# %%
trash19.describe()
# Out:
#        Households Served by Municipal Trash Program  Trash Disposal Tonnage  \
# count                                    271.000000              271.000000
# mean                                    6866.667897             5248.607085
# std                                    17161.411511            12744.530842
# min                                       73.000000               25.110000
# 25%                                      985.500000              518.115000
# 50%                                     3450.000000             2258.000000
# 75%                                     7997.500000             6061.520000
# max                                   260000.000000           188113.000000
#
#        Bulky waste tonnage     tons_total     tons/hh
# count           271.000000     271.000000  271.000000
# mean             79.988598    5328.595683    0.715124
# std             278.934586   12757.857492    0.245459
# min               0.000000      31.150000    0.124967
# 25%               0.000000     606.350000    0.547107
# 50%               0.000000    2258.000000    0.709091
# 75%              31.080000    6222.130000    0.856209
# max            2501.000000  188113.000000    1.626437

# %%
px.histogram(trash19['tons/hh'])

# %%
px.box(trash19['tons/hh'],orientation='h')

# %% [markdown]
# The average tonnage of trash per household is 0.715, the min is 0.125 and the max is 1.626. The IQR of 0.567-0.857 is wider than that of the recycling's IQR (0.189-0.303).
#
# There's two things I could do to compare the trash tonnage to the recycling tonnage: **1)** I could make a column of the ratio of trash tonnage to recycling tonnage and **2)** I can make a box plot grouping similarly to what I did for the recycling-only EDA. I think I'll do both.

# %%
recycle19['recycle:trash_ratio_hh'] = recycle19['tons/hh'] / trash19['tons/hh']
recycle19.head()
# Out:
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Abington                                                     4486.0
# Acton                                                        4335.0
# Acushnet                                                     3591.0
# Adams                                                         664.0
# Agawam                                                       8879.0
#
#                    Tons Single Stream Recyclables  Newspaper  Cardboard  \
# Municipality Name
# Abington                                  1413.42        0.0        0.0
# Acton                                        0.00        0.0        0.0
# Acushnet                                   879.50        3.7       20.0
# Adams                                        0.00        0.0        0.0
# Agawam                                    2238.00        0.0        0.0
#
#                    Mixed Paper  Commingled  tons_total   tons/hh  \
# Municipality Name
# Abington                  0.00        0.00     1413.42  0.315074
# Acton                   683.04      407.27     1090.31  0.251513
# Acushnet                 16.94       27.40      947.54  0.263865
# Adams                    94.13       45.48      139.61  0.210256
# Agawam                    0.00        0.00     2238.00  0.252055
#
#                    recycle:trash_ratio_hh
# Municipality Name
# Abington                         0.369361
# Acton                            0.450195
# Acushnet                         0.274938
# Adams                            1.038224
# Agawam                           0.333176

# %%
recycle19['recycle:trash_ratio_hh'].describe()
# Out:
# count    271.000000
# mean       0.391683
# std        0.208610
# min        0.061090
# 25%        0.269808
# 50%        0.363858
# 75%        0.465475
# max        2.185970
# Name: recycle:trash_ratio_hh, dtype: float64

# %%
recycle19.loc[recycle19_outliers.index]
# Out:
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Bourne                                                       8135.0
# Concord                                                      3800.0
# Devens                                                        145.0
# Needham                                                      5349.0
# Provincetown                                                 2348.0
#
#                    Tons Single Stream Recyclables  Newspaper  Cardboard  \
# Municipality Name
# Bourne                                    5646.89        0.0      412.0
# Concord                                      0.00        0.0     1307.0
# Devens                                       0.00        0.0        0.0
# Needham                                    232.00        0.0      422.0
# Provincetown                              1244.00        0.0      192.0
#
#                    Mixed Paper  Commingled  tons_total   tons/hh  \
# Municipality Name
# Bourne                    0.00         0.0     6058.89  0.744793
# Concord                 965.82       611.3     2884.12  0.758979
# Devens                   44.00        43.2       87.20  0.601379
# Needham                1172.00       726.0     2552.00  0.477099
# Provincetown              0.00         0.0     1436.00  0.611584
#
#                    recycle:trash_ratio_hh
# Municipality Name
# Bourne                           0.774470
# Concord                          1.045633
# Devens                                NaN
# Needham                          0.561515
# Provincetown                     0.474711

# %% [markdown]
# Interesting, these recycling tonnage outliers definitelly all exceed the IQR for recycle:trash tonnage ratio, meaning they're not merely generating more waste per household. They are actually recycling more of their waste. I'd like to see if there are any additional outliers in the ratio data.

# %%
px.box(recycle19['recycle:trash_ratio_hh'], orientation='h')

# %%
recycle19[recycle19['recycle:trash_ratio_hh'] > 0.75].sort_values(by='recycle:trash_ratio_hh')
# Out:
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Aquinnah                                                      230.0
# Bourne                                                       8135.0
# Dunstable                                                     277.0
# Northampton                                                  2947.0
# Adams                                                         664.0
# Concord                                                      3800.0
# Blandford                                                     300.0
# Hampden                                                       600.0
#
#                    Tons Single Stream Recyclables  Newspaper  Cardboard  \
# Municipality Name
# Aquinnah                                    72.00       0.00        0.0
# Bourne                                    5646.89       0.00      412.0
# Dunstable                                   73.00       0.00        0.0
# Northampton                                  0.00       0.00        0.0
# Adams                                        0.00       0.00        0.0
# Concord                                      0.00       0.00     1307.0
# Blandford                                    0.00       5.46       29.0
# Hampden                                      0.00       0.00        0.0
#
#                    Mixed Paper  Commingled  tons_total   tons/hh  \
# Municipality Name
# Aquinnah                  0.00        0.00       72.00  0.313043
# Bourne                    0.00        0.00     6058.89  0.744793
# Dunstable                 0.00        0.00       73.00  0.263538
# Northampton             505.11      301.18      806.29  0.273597
# Adams                    94.13       45.48      139.61  0.210256
# Concord                 965.82      611.30     2884.12  0.758979
# Blandford                 5.71       24.89       65.06  0.216867
# Hampden                 126.68       93.01      219.69  0.366150
#
#                    recycle:trash_ratio_hh
# Municipality Name
# Aquinnah                         0.765957
# Bourne                           0.774470
# Dunstable                        0.820225
# Northampton                      0.853370
# Adams                            1.038224
# Concord                          1.045633
# Blandford                        1.735396
# Hampden                          2.185970

# %% [markdown]
# Now I'm interest to know which municipalities generate the most total waste. It is impressive that municipalities like Concord recycle more waste than they do throwing out. However, they also seem to be generating more tons of recycling than other outliers, which means they're probably on the higher end of how much total waste they're generating.

# %%
recycle19['total_tons_waste/hh'] = recycle19['tons/hh'] + trash19['tons/hh']

# %%
recycle19.sort_values(by='total_tons_waste/hh', ascending=False).head(10)
# Out:
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Chatham                                                      3160.0
# Provincetown                                                 2348.0
# Edgartown                                                    1750.0
# Bourne                                                       8135.0
# Avon                                                         1445.0
# Nantucket                                                    8871.0
# Lawrence                                                    21723.0
# Florida                                                       211.0
# Carlisle                                                     1600.0
# Concord                                                      3800.0
#
#                    Tons Single Stream Recyclables  Newspaper  Cardboard  \
# Municipality Name
# Chatham                                    287.97      68.95      261.0
# Provincetown                              1244.00       0.00      192.0
# Edgartown                                  525.00       0.00        0.0
# Bourne                                    5646.89       0.00      412.0
# Avon                                       532.49       0.00        0.0
# Nantucket                                    0.00       0.00     1116.0
# Lawrence                                  3318.05       0.00      161.0
# Florida                                      0.00       0.00        0.0
# Carlisle                                     0.00       0.00      183.0
# Concord                                      0.00       0.00     1307.0
#
#                    Mixed Paper  Commingled  tons_total   tons/hh  \
# Municipality Name
# Chatham                 188.02      280.64     1086.58  0.343854
# Provincetown              0.00        0.00     1436.00  0.611584
# Edgartown                 0.00        0.00      525.00  0.300000
# Bourne                    0.00        0.00     6058.89  0.744793
# Avon                      0.00        0.00      532.49  0.368505
# Nantucket                 0.00     2021.25     3137.25  0.353652
# Lawrence                  0.00        0.00     3479.05  0.160155
# Florida                  19.10       15.18       34.28  0.162464
# Carlisle                201.15      189.92      574.07  0.358794
# Concord                 965.82      611.30     2884.12  0.758979
#
#                    recycle:trash_ratio_hh  total_tons_waste/hh
# Municipality Name
# Chatham                          0.211416             1.970291
# Provincetown                     0.474711             1.899915
# Edgartown                        0.190909             1.871429
# Bourne                           0.774470             1.706473
# Avon                             0.288383             1.646339
# Nantucket                        0.275252             1.638483
# Lawrence                         0.112210             1.587435
# Florida                          0.116270             1.559763
# Carlisle                         0.318312             1.485969
# Concord                          1.045633             1.484835

# %%
recycle19.sort_values(by='total_tons_waste/hh', ascending=False).tail(10)
# Out:
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Becket                                                       1779.0
# Mount Washington                                              146.0
# Blandford                                                     300.0
# Halifax                                                      3184.0
# Devens                                                        145.0
# Lanesborough                                                 1322.0
# Leicester                                                    3587.0
# New Ashford                                                    51.0
# Wareham                                                     12274.0
# Westminster                                                  2987.0
#
#                    Tons Single Stream Recyclables  Newspaper  Cardboard  \
# Municipality Name
# Becket                                       0.00       0.00        0.0
# Mount Washington                             0.00       0.00        0.0
# Blandford                                    0.00       5.46       29.0
# Halifax                                    290.72       0.00       45.0
# Devens                                       0.00       0.00        0.0
# Lanesborough                                 0.00       0.00        0.0
# Leicester                                    0.00       0.00        0.0
# New Ashford                                  0.00       0.00        0.0
# Wareham                                      0.00       0.00       37.0
# Westminster                                183.45     136.02      161.0
#
#                    Mixed Paper  Commingled  tons_total   tons/hh  \
# Municipality Name
# Becket                   52.85       52.40      105.25  0.059162
# Mount Washington         10.54        9.49       20.03  0.137192
# Blandford                 5.71       24.89       65.06  0.216867
# Halifax                   0.00        0.00      335.72  0.105440
# Devens                   44.00       43.20       87.20  0.601379
# Lanesborough             45.38       22.29       67.67  0.051188
# Leicester                69.00       51.00      120.00  0.033454
# New Ashford               4.01        3.94        7.95  0.155882
# Wareham                  25.90       32.70       95.60  0.007789
# Westminster               0.00        0.00      480.47  0.160854
#
#                    recycle:trash_ratio_hh  total_tons_waste/hh
# Municipality Name
# Becket                           0.201787             0.352355
# Mount Washington                 0.643018             0.350548
# Blandford                        1.735396             0.341833
# Halifax                          0.462007             0.333660
# Devens                                NaN                  NaN
# Lanesborough                          NaN                  NaN
# Leicester                             NaN                  NaN
# New Ashford                           NaN                  NaN
# Wareham                               NaN                  NaN
# Westminster                           NaN                  NaN

# %% [markdown]
# So...Bourne and Concord are two of the top 10 produces of waste in general. So although their recycle rate are high, they also are producing more waste total. This in interesting when compairing to a place like Becket or Halifax, two municipalities with a relatively high population to serve, they have low recycling tonnages per household but they also produce less waste total per household... you could almost make a different metric like:
#
# (total_tons)/(recycle:trash) --> higher trash rates and high total tonnage would produce a higher "score"

# %%
recycle19['score'] = recycle19['total_tons_waste/hh'] / recycle19['recycle:trash_ratio_hh']

# %%
recycle19.sort_values(by='score').head(20)
# Out:
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Blandford                                                     300.0
# Hampden                                                       600.0
# Adams                                                         664.0
# Sturbridge                                                   1882.0
# Mount Washington                                              146.0
# Northampton                                                  2947.0
# Dunstable                                                     277.0
# Halifax                                                      3184.0
# Oak Bluffs                                                   2005.0
# Chilmark                                                      450.0
# Gill                                                          511.0
# Sutton                                                       1200.0
# Aquinnah                                                      230.0
# Merrimac                                                     1934.0
# Shutesbury                                                    850.0
# Heath                                                         350.0
# Buckland                                                      620.0
# Monterey                                                      740.0
# Westport                                                     1889.0
# Bolton                                                       2130.0
#
#                    Tons Single Stream Recyclables  Newspaper  Cardboard  \
# Municipality Name
# Blandford                                    0.00       5.46       29.0
# Hampden                                      0.00       0.00        0.0
# Adams                                        0.00       0.00        0.0
# Sturbridge                                   0.00      12.00       50.0
# Mount Washington                             0.00       0.00        0.0
# Northampton                                  0.00       0.00        0.0
# Dunstable                                   73.00       0.00        0.0
# Halifax                                    290.72       0.00       45.0
# Oak Bluffs                                   0.00      75.00       68.0
# Chilmark                                    55.00       0.00        0.0
# Gill                                         0.00       0.00        0.0
# Sutton                                       0.00       0.00       85.0
# Aquinnah                                    72.00       0.00        0.0
# Merrimac                                   550.36       0.00        0.0
# Shutesbury                                   0.00       0.00        0.0
# Heath                                        0.00       0.00        0.0
# Buckland                                     0.00       0.00        0.0
# Monterey                                     0.00       0.00        0.0
# Westport                                     0.00      25.27      107.0
# Bolton                                       6.51      17.39      102.0
#
#                    Mixed Paper  Commingled  tons_total   tons/hh  \
# Municipality Name
# Blandford                 5.71       24.89       65.06  0.216867
# Hampden                 126.68       93.01      219.69  0.366150
# Adams                    94.13       45.48      139.61  0.210256
# Sturbridge               53.00      200.00      315.00  0.167375
# Mount Washington         10.54        9.49       20.03  0.137192
# Northampton             505.11      301.18      806.29  0.273597
# Dunstable                 0.00        0.00       73.00  0.263538
# Halifax                   0.00        0.00      335.72  0.105440
# Oak Bluffs                0.00      122.00      265.00  0.132170
# Chilmark                  0.00        0.00       55.00  0.122222
# Gill                     63.25       53.74      116.99  0.228943
# Sutton                   70.00       82.00      237.00  0.197500
# Aquinnah                  0.00        0.00       72.00  0.313043
# Merrimac                  0.00        0.00      550.36  0.284571
# Shutesbury               99.58       76.21      175.79  0.206812
# Heath                    32.54       31.71       64.25  0.183571
# Buckland                 59.41       54.93      114.34  0.184419
# Monterey                 79.83       52.09      131.92  0.178270
# Westport                 68.08      244.62      444.97  0.235558
# Bolton                   85.09       81.53      292.52  0.137333
#
#                    recycle:trash_ratio_hh  total_tons_waste/hh     score
# Municipality Name
# Blandford                        1.735396             0.341833  0.196977
# Hampden                          2.185970             0.533650  0.244125
# Adams                            1.038224             0.412771  0.397574
# Sturbridge                       0.750000             0.390542  0.520723
# Mount Washington                 0.643018             0.350548  0.545161
# Northampton                      0.853370             0.594204  0.696303
# Dunstable                        0.820225             0.584838  0.713021
# Halifax                          0.462007             0.333660  0.722197
# Oak Bluffs                       0.510261             0.391193  0.766652
# Chilmark                         0.447154             0.395556  0.884606
# Gill                             0.642802             0.585108  0.910245
# Sutton                           0.576082             0.540333  0.937946
# Aquinnah                         0.765957             0.721739  0.942271
# Merrimac                         0.714805             0.682680  0.955058
# Shutesbury                       0.561863             0.574894  1.023193
# Heath                            0.516106             0.539257  1.044858
# Buckland                         0.512391             0.544339  1.062351
# Monterey                         0.502000             0.533391  1.062532
# Westport                         0.591747             0.633632  1.070781
# Bolton                           0.427886             0.458291  1.071059

# %%
recycle19.sort_values(by='score').tail(20)
# Out:
#                    Households Served by Municipal Recycling Program  \
# Municipality Name
# Peabody                                                     14000.0
# West Bridgewater                                             1823.0
# Yarmouth                                                    10143.0
# Pittsfield                                                  17522.0
# Quincy                                                      45000.0
# Woburn                                                      11240.0
# Paxton                                                       1578.0
# Chatham                                                      3160.0
# Methuen                                                     14754.0
# Edgartown                                                    1750.0
# North Adams                                                  5366.0
# Monroe                                                         73.0
# Florida                                                       211.0
# Lawrence                                                    21723.0
# Devens                                                        145.0
# Lanesborough                                                 1322.0
# Leicester                                                    3587.0
# New Ashford                                                    51.0
# Wareham                                                     12274.0
# Westminster                                                  2987.0
#
#                    Tons Single Stream Recyclables  Newspaper  Cardboard  \
# Municipality Name
# Peabody                                      0.00       0.00        0.0
# West Bridgewater                           339.62       0.00        0.0
# Yarmouth                                     0.00     156.00      369.0
# Pittsfield                                   0.00       0.00        0.0
# Quincy                                    4646.93       0.00        0.0
# Woburn                                    2071.74       0.00        0.0
# Paxton                                       2.50       0.00        0.0
# Chatham                                    287.97      68.95      261.0
# Methuen                                   2541.14       0.00        0.0
# Edgartown                                  525.00       0.00        0.0
# North Adams                                  0.00       0.00        0.0
# Monroe                                       3.25       0.00        0.0
# Florida                                      0.00       0.00        0.0
# Lawrence                                  3318.05       0.00      161.0
# Devens                                       0.00       0.00        0.0
# Lanesborough                                 0.00       0.00        0.0
# Leicester                                    0.00       0.00        0.0
# New Ashford                                  0.00       0.00        0.0
# Wareham                                      0.00       0.00       37.0
# Westminster                                183.45     136.02      161.0
#
#                    Mixed Paper  Commingled  tons_total   tons/hh  \
# Municipality Name
# Peabody                1818.11     1499.81     3317.92  0.236994
# West Bridgewater          0.00        0.00      339.62  0.186297
# Yarmouth                204.00      460.00     1189.00  0.117224
# Pittsfield             1176.63      743.20     1919.83  0.109567
# Quincy                    0.00        0.00     4646.93  0.103265
# Woburn                    0.00        0.00     2071.74  0.184319
# Paxton                    1.80      137.00      141.30  0.089544
# Chatham                 188.02      280.64     1086.58  0.343854
# Methuen                   0.00        0.00     2541.14  0.172234
# Edgartown                 0.00        0.00      525.00  0.300000
# North Adams             158.66       87.97      246.63  0.045962
# Monroe                    0.00        0.00        3.25  0.044521
# Florida                  19.10       15.18       34.28  0.162464
# Lawrence                  0.00        0.00     3479.05  0.160155
# Devens                   44.00       43.20       87.20  0.601379
# Lanesborough             45.38       22.29       67.67  0.051188
# Leicester                69.00       51.00      120.00  0.033454
# New Ashford               4.01        3.94        7.95  0.155882
# Wareham                  25.90       32.70       95.60  0.007789
# Westminster               0.00        0.00      480.47  0.160854
#
#                    recycle:trash_ratio_hh  total_tons_waste/hh      score
# Municipality Name
# Peabody                          0.199778             1.423280   7.124293
# West Bridgewater                 0.171957             1.269693   7.383786
# Yarmouth                         0.131216             1.010588   7.701715
# Pittsfield                       0.125898             0.979850   7.782892
# Quincy                           0.115846             0.994668   8.586154
# Woburn                           0.154970             1.373700   8.864296
# Paxton                           0.105605             0.937452   8.876938
# Chatham                          0.211416             1.970291   9.319507
# Methuen                          0.143033             1.376387   9.622850
# Edgartown                        0.190909             1.871429   9.802721
# North Adams                      0.063527             0.769456  12.112214
# Monroe                           0.061090             0.773288  12.658124
# Florida                          0.116270             1.559763  13.414963
# Lawrence                         0.112210             1.587435  14.146995
# Devens                                NaN                  NaN        NaN
# Lanesborough                          NaN                  NaN        NaN
# Leicester                             NaN                  NaN        NaN
# New Ashford                           NaN                  NaN        NaN
# Wareham                               NaN                  NaN        NaN
# Westminster                           NaN                  NaN        NaN

# %% [markdown]
# at brief glance, it appears that municipalities with higher burden "scores" also have higher populations while municipalities with lower burden scors have lower populations generally. I am interested in the municipalities with higher populations but lower burden scores like: Sturbridge, Northhampton, Halifax. I could compare things to other higher populated municipalities with high burden scores like: Lawrence, North Adams, and Edgartown.

# %%
ss_plus_trash19 = trash19[(recycle19['Tons Single Stream Recyclables'] > 0) & (recycle19.loc[:,'Newspaper':'Commingled'].sum(axis=1) > 0)]
ms_trash19 = trash19[(recycle19['Tons Single Stream Recyclables'] == 0) & (recycle19.loc[:,'Newspaper':'Commingled'].sum(axis=1) > 0)]
ss_trash19 = trash19[(recycle19['Tons Single Stream Recyclables'] > 0) & (recycle19.loc[:,'Newspaper':'Commingled'].sum(axis=1) == 0)]
# Out:
# <ipython-input-229-bf5af30ab61a>:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# <ipython-input-229-bf5af30ab61a>:2: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# <ipython-input-229-bf5af30ab61a>:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
layout = Layout(
    boxgap=0.1,
    height = 600
)
fig = go.Figure(layout=layout)
fig.add_trace(go.Box(
    x=ss_trash19['tons/hh'],
    name='SS',
    marker_color='#AA22AA'
))
fig.add_trace(go.Box(
    x=ms_trash19['tons/hh'],
    name='MS',
    marker_color='#FF851B'
))
fig.add_trace(go.Box(
    x=ss_plus_trash19['tons/hh'],
    name='SS+',
    marker_color='#FF4136'
))
fig.add_trace(go.Box(
    x=trash19['tons/hh'],
    name='All',
    marker_color='#3D9970'
))
# fig.add_trace(go.Box(
#     x=ss_recycle19['tons/hh'],
#     name='SS',
#     marker_color='#AA22AA'
# ))
# fig.add_trace(go.Box(
#     x=ms_recycle19['tons/hh'],
#     name='MS',
#     marker_color='#FF851B'
# ))
# fig.add_trace(go.Box(
#     x=ss_plus_recycle19['tons/hh'],
#     name='SS+',
#     marker_color='#FF4136'
# ))
# fig.add_trace(go.Box(
#     x=recycle19['tons/hh'],
#     name='All',
#     marker_color='#3D9970'
# ))

fig.update_layout(
    xaxis=dict(title='trash tons/hh', zeroline=False),
    boxmode='overlay' #or group
)

fig.update_traces(orientation='h') # horizontal box plots

fig.show()

# %% [markdown]
# This is suggesting that muncipalities with single stream also generate more trash, in addition to recycling...

# %%
ss_plus_total19 = recycle19[(recycle19['Tons Single Stream Recyclables'] > 0) & (recycle19.loc[:,'Newspaper':'Commingled'].sum(axis=1) > 0)]
ms_total19 = recycle19[(recycle19['Tons Single Stream Recyclables'] == 0) & (recycle19.loc[:,'Newspaper':'Commingled'].sum(axis=1) > 0)]
ss_total19 = recycle19[(recycle19['Tons Single Stream Recyclables'] > 0) & (recycle19.loc[:,'Newspaper':'Commingled'].sum(axis=1) == 0)]

# %%
layout = Layout(
    boxgap=0.1,
    height = 600
)
fig = go.Figure(layout=layout)
fig.add_trace(go.Box(
    x=ss_total19['total_tons_waste/hh'],
    name='SS',
    marker_color='#AA22AA'
))
fig.add_trace(go.Box(
    x=ms_total19['total_tons_waste/hh'],
    name='MS',
    marker_color='#FF851B'
))
fig.add_trace(go.Box(
    x=ss_plus_total19['total_tons_waste/hh'],
    name='SS+',
    marker_color='#FF4136'
))
fig.add_trace(go.Box(
    x=recycle19['total_tons_waste/hh'],
    name='All',
    marker_color='#3D9970'
))

fig.update_layout(
    xaxis=dict(title='total waste tons/hh', zeroline=False),
    boxmode='overlay' #or group
)

fig.update_traces(orientation='h') # horizontal box plots

fig.show()

# %%
layout = Layout(
    boxgap=0.1,
    height = 600
)
fig = go.Figure(layout=layout)
fig.add_trace(go.Box(
    x=ss_total19['score'],
    name='SS',
    marker_color='#AA22AA'
))
fig.add_trace(go.Box(
    x=ms_total19['score'],
    name='MS',
    marker_color='#FF851B'
))
fig.add_trace(go.Box(
    x=ss_plus_total19['score'],
    name='SS+',
    marker_color='#FF4136'
))
fig.add_trace(go.Box(
    x=recycle19['score'],
    name='All',
    marker_color='#3D9970'
))

fig.update_layout(
    xaxis=dict(title='burden score', zeroline=False),
    boxmode='overlay' #or group
)

fig.update_traces(orientation='h') # horizontal box plots

fig.show()

# %% [markdown]
# So I'm definitely a little confused at this point. the scores doesn't seem to trend with the rest of the data. But it does seem like the burden score is higher for single stream municipalities and is lower for the Multi-stream and single stream +.
#
# Next steps would be:
# * looking at other attributes in the municipality survey that contributes to (decide if you're going to look at recycle ratio or "burden" score), like:
#   * Population size
#   * recycle service correlations
#   * trash service correlations
# * Historical data of municipality survey (will need some level of automation)
# * Find way to classify different municipalities (by attributes like political leaning, population size, most common type of housing and other demographics). See if success rates are influence by different factors in these different classification demographics.
